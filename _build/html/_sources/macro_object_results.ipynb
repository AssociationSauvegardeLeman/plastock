# %%
# %load_ext watermark
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from myst_nb import glue
from slugify import slugify

from plastockconf import name_zones, name_frequentation, name_situation
from plastockconf import name_substrate, name_distance, table_css_styles

from plastock import add_table_to_page, capitalize_x_tick_labels, capitalize_x_and_y_axis_labels, capitalize_legend_components, attribute_summary

import reportclass as rc
import setvariables as conf_


import matplotlib as mpl


format_kwargs = dict(precision=2, thousands="'", decimal=",")
def make_exportable(data, file_name, cmap='YlOrBr'):
    data.fillna(0, inplace=True)
    fig, ax = plt.subplots(figsize=(12,8))
    sns.heatmap(data=data, vmin=0, vmax=1, cmap=cmap, annot=True, fmt='.2', annot_kws={'size':10}, ax=ax, cbar=False)
    plt.tight_layout()
    ax.tick_params(which='both', axis='both', bottom=False, left=False)
    plt.savefig(file_name, dpi=300)

    plt.close()

glue('blank_caption', " ", display=False)

# %% [markdown]
# # Déchets Sauvages
#
# Les déchets sauvages sur les plages du Lac Léman font l'objet d'une surveillance depuis 2015. La campagne la plus récente avant Plastock a été parrainée par l'Office fédéral de l'environnement (OFEV) de 2020 à 2021. Les directives européennes sur la surveillance des déchets sauvages sur les plages ont été publiées en 2013 [Guidance on Monitoring Marine Litter](https://mcc.jrc.ec.europa.eu/documents/201702074014.pdf). Les méthodes utilisées pour surveiller les déchets sauvages sur le lac Léman suivent les directives de l'UE, tout en tenant compte des contraintes liées aux différences de topographie entre le littoral maritime et le littoral lacustre.
#
# ## Le système de mesure.
#
# Les déchets sauvages sur les plages sont mesurés en unités de déchets par mètre linéaire de rivage. Les relevés sont effectués entre la ligne d'eau (là où l'eau et la terre se rejoignent) et la ligne de dérive (la distance la plus éloignée de la ligne d'eau atteinte par les vagues). Cette méthode a été adoptée dès le début en Suisse, ce qui signifie que les 250 échantillons précédents du lac Léman ont été collectés et mesurés selon la méthode précédemment décrite.
#
# __Dans cette section, les unités sont des déchets par mètre de rivage: (pcs/m)__
#
# ### Exigences particulières données plastock
#
# La quantité de déchets sauvages par mètre de plage correspond au nombre total d'objets identifiés divisé par la longueur du rivage. Pour les données Plastock, cela signifie que nous devons considérer la position un (ligne d'eau) et la position deux (plage sèche) ensemble. De plus, il y a __douze échantillons où le substrat était différent entre la position un et la position deux__. Par conséquent, ces 12 échantillons ont tous été classés dans la catégorie Sables grossiers.

# %%
new_data = pd.read_csv("data/end_pipe/macro_current.csv")
beach_data = pd.read_csv("data/pstock_beaches_current.csv")
codes = pd.read_csv('data/end_pipe/codes.csv').set_index('code')

new_column_names = {
    "Position":"position",
    "Substrat":"substrat",
    "Date":"date",
    "Code":"code",
    "Quantité":"quantité",
    "Aire":"area"
}

length_key = beach_data[["Plage","length"]].drop_duplicates("Plage").set_index("Plage")
work_data = new_data[["Plage", *new_column_names.keys()]].copy()
work_data.rename(columns=new_column_names, inplace=True)
work_data["length"] = work_data.Plage.apply(lambda x: length_key.loc[x, "length"])
work_data["slug"] = work_data.Plage.apply(lambda x: slugify(x))
work_data["echantillon"] = list(zip(work_data.slug, work_data['date']))
work_data['date'] = pd.to_datetime(work_data["date"], format="mixed", dayfirst=True)
work_data.dropna(inplace=True)
work_data[["position", "substrat"]] = work_data[["position", "substrat"]].astype("int")
work_data['échantillon'] = work_data['echantillon']
work_data.drop(['echantillon'], inplace=True, axis=1)
work_data = work_data.groupby(['échantillon', 'Plage', 'substrat', 'date', 'length', 'slug', 'code'], as_index=False).agg({'quantité':'sum'})
work_data['pcs/m'] = work_data['quantité']/work_data['length']


voi = 'substrat'
vals = "pcs/m"
some_data = work_data.copy()
groupby = ['échantillon', voi]
data = some_data.groupby(groupby, as_index=False)[vals].sum()
dd = data[data['échantillon'].duplicated()].copy()

# duplicates = work_data[work_data['échantillon'].isin(ddd)].copy()
duplicated = work_data[work_data['échantillon'].isin(dd['échantillon'].unique())].copy()
duplicated['substrat'] = 2 

# notduplicated
not_duplicated = work_data[~(work_data['échantillon'].isin(dd['échantillon'].unique()))].copy()

# put it back to gether again
work_data = pd.concat([duplicated, not_duplicated])
work_data = work_data.groupby(['échantillon', 'Plage', 'substrat', 'date', 'length', 'slug', 'code'], as_index=False).agg({'quantité':'sum'})
work_data['pcs/m'] = work_data['quantité']/work_data['length']

# accounting for objects not found at a sample:
# the codes that were indentified
codes_ip = work_data.code.unique()
# the unique samples
loc_dates = work_data['échantillon'].unique()

# a copy for itterating
wd = work_data.copy()

# for each sample (échantillon) indentify the codes that were not
# found by indentifying all the codes that were found in all surveys
# and removing the codes that were not identified at that sample.
# for each unidentified code per sample, add a row with the sample
# id and the code. give the row a quantity of zero.
rows = []
for a_loc in loc_dates:
    r = wd.loc[wd['échantillon'] == a_loc].copy()
    r.reset_index(inplace=True, drop=True)
    
    t = r.loc[0][['échantillon', 'Plage', 'substrat', 'date', 'length', 'slug']].values
    asamp = [x for x in t]
    used_codes = r.code.unique()
    unused = [x for x in codes_ip if x not in used_codes]
    for element in unused:
        arow = [*asamp, element, 0, 0]
        rows.append(arow)
        

work_x = pd.DataFrame(rows, columns=['échantillon', 'Plage', 'substrat', 'date', 'length', 'slug', 'code', 'quantité', 'pcs/m'])
work_data = pd.concat([work_x, work_data])

# %% [markdown]
# La distribution de la variable de substrat après la réattribution des 12 échantillons en question.
#
# 1. Sables fins : 27%
# 2. Sables Grossiers : 32%
# 3. Graviers : 16%
# 4. Cailloux : 25%

# %%
repartition_substrat = work_data.groupby('substrat')['échantillon'].nunique()/work_data['échantillon'].nunique()

# %%
new_names = {x: " " for x in work_data.columns}
new_names = {
    'échantillon': 'loc_date',
    'pcs/m': 'pcs_m'
}

change_names = ['preverenges', 'tolochenaz', 'versoix', 'vidy', 'cully']

changeus = work_data[work_data.slug.isin(change_names)].copy()
donotchange = work_data[~work_data.slug.isin(change_names)].copy()

new_slug = {
    'cully': 'cully-p',
    'preverenges': 'preverenges-p',
    'tolochenaz': 'tolochenaz-p',
    'versoix':'versoix-p',
    'vidy': 'vidy-p'}

# they have the same name as locations in iqaasl
changeus['new_slug'] = changeus.slug.apply(lambda x: new_slug[x])
changeus['slug'] = changeus.new_slug
changeus.drop('new_slug', inplace=True, axis=1)
wd_nn = pd.concat([changeus, donotchange])

# codes in the plastock data
pcodes = wd_nn.code.unique()

# identify and remove codes for which there is no defintion
t = [x for x in pcodes if x not in codes.index]
wd_ni = wd_nn[~wd_nn.code.isin(t)].copy()

# aggregate to grfags, gfoams, gcaps
ti = rc.use_gfrags_gfoams_gcaps(wd_ni, codes)

# aggregate along all land-use and topo variables.
ti = ti.groupby(['échantillon', 'Plage', 'date', 'substrat', 'length', 'slug', 'code'], as_index=False).agg({'quantité':'sum'})

# make city map and format plastock data to work with report class
f = pd.read_csv('data/u_pstk.csv')
city_map = f[["slug", "city"]].drop_duplicates()
city_map.loc[city_map.slug == 'savoniere', 'slug'] = 'savonniere'
city_map.set_index('slug', inplace=True)

# adding and renaming columns according to reportclass requirements
ti['city'] = ti.slug.apply(lambda x: city_map.loc[x])
ti['feature_name'] = 'lac-leman'
ti['feature_type'] = 'l'
ti['parent_boundary'] = 'rhone'
ti.rename(columns={**new_names,'quantité': 'quantity'}, inplace=True)
ti['pcs_m'] = ti.quantity/ti.length


twork_cols = ['loc_date', 'date','slug', 'project',
       'code', 'quantity', 'city', 'feature_name', 'feature_type',
       'parent_boundary', 'pcs_m']

sing_cols = ['loc_date', 'date','slug', 'Plage', 'substrat',
       'code', 'quantity', 'city', 'feature_name', 'feature_type',
       'parent_boundary', 'pcs_m']
ti_work = ti[sing_cols].copy()

# previous results
ghi = pd.read_csv('data/end_pipe/iqaasl.csv')

ti_work['project']='Plastock'
# combine zones and substrat
# comb_cols = ['loc_date', 'date', 'slug',
#         'city','feature_name', 'feature_type',
#        'parent_boundary','code']


ti_work = ti_work.groupby(sing_cols, as_index=False).agg(conf_.unit_agg)
ti_work['project']='Plastock'
txi = pd.concat([ghi, ti_work[twork_cols ].copy()])
txi.reset_index(inplace=True)
txi = txi[txi.code.isin(ti_work.code.unique())]

language_maps = rc.language_maps()
boundaries = dict(start_date="2021-12-31", end_date="2023-01-01", feature_name="lac-leman", language="fr")
top_label= ['feature_name', 'lac-leman']

tiii = rc.ReportClass(ti_work.copy(), boundaries=boundaries, language="fr", lang_maps=language_maps, top_label=top_label)
header = tiii.a_short_description.fillna('.')
comp_summary = tiii.summarize_feature_labels(feature='feature_name')
most_common, weight = tiii.most_common

boundaries = dict(start_date="2019-12-31", end_date="2023-01-01", feature_name="lac-leman", language="fr")
combined = rc.ReportClass(txi.copy(), boundaries=boundaries, language="fr", lang_maps=language_maps, top_label=top_label)

# %% [markdown]
# ## Situation
#
# Les déchets sauvages ont été collectés dans 25 emplacements différents autour du Léman. Soixante-sept sur 98 de ces emplacements se trouvaient dans des zones urbaines, avec un taux d'utilisation élevé de 55 sur 98, et 83 sur 98 étaient situés à moins de 500 mètres d'un parking. Les caractéristiques ont été notées par les personnes chargées de la collecte des déchets sauvages [Macro déchets plage et attribut](macro-attributes).
#
# ### Les résultats

# %%
t = rc.translated_and_style_for_display(comp_summary.copy(),  tiii.lang_maps[tiii.language], tiii.language, gradient=False)
rep_res_one = "L'échantillonnage était planifié trimestriellement, commençant en janvier 2022. À quelques exceptions près, chaque emplacement était échantillonné quatre fois au cours de la période de 12 mois. Les études précédentes sur le lac étaient mensuelles ou aléatoires."
rep_res_two = "La médiane du total des échantillons était de 2 pièces/mètre avec une variance de 3,6 pièces/mètre."

glue('rep_results_one',rep_res_one , display=False)
glue('rep_results_two',rep_res_two , display=False)
glue('rep_results', t, display=False)

# %% [markdown]
# <style>
# table th:first-of-type {
#     width: 50%;
# }
# table th:nth-of-type(2) {
#     width: 50%;
# }
#
# </style>
#
#
# | |La répartition des résultats|
# |:---:|:---|
# |{glue}`rep_results`|<br>{glue:text}`rep_results_two`<br><br>{glue:text}`rep_results_one`|

# %%
comb_dt = tiii.w_df
comb_dt = comb_dt.groupby(['loc_date', 'date', 'project'], as_index=False).pcs_m.sum()

fig, ax = plt.subplots(2,2, figsize=(8,8))

sns.scatterplot(data=comb_dt, x="date", y="pcs_m", hue='project', ax=ax[0,0])
ax[0,0].set_title("Total par échantillon", loc="left")
ax[0,0].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[0,0].xaxis.set_major_formatter(mdates.DateFormatter('%m-%y'))
ax[0,0].set_ylabel("")
capitalize_x_and_y_axis_labels(ax[0,0])
capitalize_legend_components(ax[0, 0])

sns.boxplot(data=comb_dt, y="pcs_m", x='project', hue='project', dodge=False, width=.9, ax=ax[0,1])
ax[0,1].set_title("Boîte de Tukey", loc="left")
capitalize_x_and_y_axis_labels(ax[0,1])
ax[0, 1].get_legend().remove()
ax[0,1].set_xlabel("")

sns.histplot(data=comb_dt, x="pcs_m", ax=ax[1,0], stat="probability", hue='project', kde=True)
ax[1,0].yaxis.set_major_formatter('{x:.2f}')
ax[1,0].set_ylabel("Probabilité")
ax[1,0].set_title("Histogramme", loc="left")
capitalize_x_and_y_axis_labels(ax[1,0])
ax[1, 0].get_legend().remove()

sns.ecdfplot(data=comb_dt, x="pcs_m", hue='project', ax=ax[1,1])
ax[1,1].set_title("Fonction de répartition", loc="left")
capitalize_x_and_y_axis_labels(ax[1,1])
sns.move_legend(ax[1, 1], title=" ", loc='best')

plt.subplots_adjust(wspace=.3, hspace=.3)

glue('fig-D1', fig, display=False)
plt.close()

# %% [markdown]
# ```{glue:figure} fig-D1
# ---
# name: fig-D1
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# ## Les objets les plus courants Plastock
#
# ### Définition des _objets les plus courants_
#
# Les _objets les plus courants_ peuvent être sélectionnés de plusieurs manières. On peut également les appeler les _objets d'intérêt_. Dans le cadre de ce rapport, nous nous concentrons sur les objets qui représentent une proportion plus importante des résultats que les autres. Nous avons utilisé deux critères de sélection : i. la quantité, ii. le taux d'échec.
#
# 1. Quanité: Si un objet a une quantité totale qui le place dans les dix premiers, il est considéré comme 'courant'.
# 2. Taux d'échec: Si un objet a été trouvé dans au moins la moitié des échantillons, il est ÉGALEMENT considéré comme 'courant'.
#
# Par conséquent, pour cette étude, les 'objets les plus courants' sont ceux qui se trouvent soit dans les dix premiers en termes de nombre total de pièces de déchets ET/OU qui ont été trouvés dans au moins 50% des enquêtes. Pour Plastock, les objets les plus courants représentent 89% du montant total ou 24'156/27'493.
#
# ```{note}
# Les équipes peuvent avoir d'autres critères pour s'intéresser à l'occurrence d'un objet dans l'environnement. Il s'agit d'un sujet qui devrait être largement développé au sein des équipes.
# ```

# %%
# pd.set_option('max_colwidth',50)
xi = rc.translated_and_style_for_display(most_common.copy(),  tiii.lang_maps[tiii.language], tiii.language, gradient=False)
xi.set_caption("Les objets les plus courants Plastock")
glue('mc_pstock', xi, display=False)

# %% [markdown]
# <!-- <style>
# table th:first-of-type {
#     width: 25%;
# }
# table th:nth-of-type(2) {
#     width: 25%;
# }
#     table th:nth-of-type(3) {
#     width: 25%;
# }
#     table th:nth-of-type(4) {
#     width: 25%;
# }
#
# </style> -->
#
#
# ```{glue} mc_pstock
# ```

# %% [markdown]
# ### Correspondance avec les résultats d'OSPAR
#
# La Suisse et la France sont toutes deux parties contractantes de la convention [OSPAR](https://www.ospar.org/organisation/contracting-parties). Parmi les objets les plus courants identifiés à partir des données Plastock, six peuvent également être retrouvés dans le rapport d'état de qualité le plus récent d'OSPAR concernant l'Abondance, la Composition et les Tendances des [déchets sauvages](https://www.ospar.org/work-areas/eiha/marine-litter/assessment-of-marine-litter/beach-litter).
#
# 1. Fragments de plastique : g80, g79, g78, g77, g76, g75
# 2. Fragments de polystyrène expansé : g81, g82, g83
# 3. Couvercles en plastique de bouteille : g21, g22, g23, g24
# 4. Coton-tige
# 5. Emballages de bonbons, de snacks
# 6. Déchets de construction en plastique
#
# ```{note}
# Les directives de surveillance d'OSPAR n'incluent pas les objets de moins de 5 mm. Par conséquent, des objets tels que les granulés industriels  (GPI) ou de petits morceaux de 5 mm ou moins ne figureront pas dans la liste des objets les plus courants d'OSPAR.
#
# Selon le _Document de référence d'OSPAR sur les granulés plastiques pré-production_, [granulés OSPAR](https://www.ospar.org/documents?v=39764), entre 16 et 167 tonnes par an.
# ```
#
# ### Correspondance avec l'IQAASL
#
# Les objets les plus courants répertoriés pour le lac Léman en 2021 comprennent tous les objets les plus courants de Plastock à l'exception des 'Fragments de plastique angulaires <5 mm', [Lac Léman, IQAASL](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/).
#
# ```{note}
# Les protections féminines et applicateurs de tampons, des éléments importants parmi les objets les plus courants d'OSPAR et d'IQAASL, n'ont pas été identifiées lors des enquêtes Plastock.
# ```

# %%
t = rc.a_cumulative_report(combined.w_df[combined.w_df.code.isin(most_common.index)], feature_name='project', object_column='code')
rc.translated_and_style_for_display(t, tiii.lang_maps[tiii.language], tiii.language, gradient=True).set_caption("Les objets les plus courants de Plastock et les résultats pour les mêmes objets de l'IQAASL")
# Out:
# <style type="text/css">
# #T_1c1f1 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_1c1f1 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_1c1f1 tr {
#   font-size: 10px;
# }
# #T_1c1f1 th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_1c1f1 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_1c1f1 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_1c1f1_row0_col0, #T_1c1f1_row0_col1, #T_1c1f1_row0_col2, #T_1c1f1_row1_col0, #T_1c1f1_row1_col1, #T_1c1f1_row1_col2, #T_1c1f1_row5_col1, #T_1c1f1_row6_col1, #T_1c1f1_row6_col2 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_1c1f1_row2_col0 {
#   background-color: rgba(254,239,224, .5);
#   color: black;
# }
# #T_1c1f1_row2_col1 {
#   background-color: rgba(198,198,198, .5);
#   color: black;
# }
# #T_1c1f1_row2_col2 {
#   background-color: rgba(106,106,106, .5);
#   color: black;
# }
# #T_1c1f1_row3_col0 {
#   background-color: rgba(153,153,153, .5);
#   color: black;
# }
# #T_1c1f1_row3_col1 {
#   background-color: rgba(200,200,200, .5);
#   color: black;
# }
# #T_1c1f1_row3_col2 {
#   background-color: rgba(179,179,179, .5);
#   color: black;
# }
# #T_1c1f1_row4_col0 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_1c1f1_row4_col1 {
#   background-color: rgba(250,250,250, .5);
#   color: black;
# }
# #T_1c1f1_row4_col2, #T_1c1f1_row5_col2 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_1c1f1_row5_col0 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_1c1f1_row6_col0 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_1c1f1_row7_col0 {
#   background-color: rgba(208,208,208, .5);
#   color: black;
# }
# #T_1c1f1_row7_col1 {
#   background-color: rgba(246,246,246, .5);
#   color: black;
# }
# #T_1c1f1_row7_col2 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_1c1f1_row8_col0 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_1c1f1_row8_col1 {
#   background-color: rgba(245,245,245, .5);
#   color: black;
# }
# #T_1c1f1_row8_col2 {
#   background-color: rgba(232,232,232, .5);
#   color: black;
# }
# #T_1c1f1_row9_col0 {
#   background-color: rgba(140,140,140, .5);
#   color: black;
# }
# #T_1c1f1_row9_col1 {
#   background-color: rgba(236,236,236, .5);
#   color: black;
# }
# #T_1c1f1_row9_col2 {
#   background-color: rgba(217,217,217, .5);
#   color: black;
# }
# #T_1c1f1_row10_col0 {
#   background-color: rgba(251,137,56, .5);
#   color: black;
# }
# #T_1c1f1_row10_col1 {
#   background-color: rgba(244,115,30, .5);
#   color: black;
# }
# #T_1c1f1_row10_col2 {
#   background-color: rgba(250,133,50, .5);
#   color: black;
# }
# </style>
# <table id="T_1c1f1">
#   <caption>Les objets les plus courants de Plastock et les résultats pour les mêmes objets de l'IQAASL</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c1f1_level0_col0" class="col_heading level0 col0" >Iqaasl</th>
#       <th id="T_1c1f1_level0_col1" class="col_heading level0 col1" >Plastock</th>
#       <th id="T_1c1f1_level0_col2" class="col_heading level0 col2" >Cumulé</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c1f1_level0_row0" class="row_heading level0 row0" >Fragments de plastique angulaires <5mm</th>
#       <td id="T_1c1f1_row0_col0" class="data row0 col0" >0,00</td>
#       <td id="T_1c1f1_row0_col1" class="data row0 col1" >0,00</td>
#       <td id="T_1c1f1_row0_col2" class="data row0 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row1" class="row_heading level0 row1" >Pellets industriels (gpi)</th>
#       <td id="T_1c1f1_row1_col0" class="data row1 col0" >0,00</td>
#       <td id="T_1c1f1_row1_col1" class="data row1 col1" >0,00</td>
#       <td id="T_1c1f1_row1_col2" class="data row1 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row2" class="row_heading level0 row2" >Mégots et filtres à cigarettes</th>
#       <td id="T_1c1f1_row2_col0" class="data row2 col0" >0,47</td>
#       <td id="T_1c1f1_row2_col1" class="data row2 col1" >0,15</td>
#       <td id="T_1c1f1_row2_col2" class="data row2 col2" >0,30</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row3" class="row_heading level0 row3" >Emballages de bonbons, de snacks</th>
#       <td id="T_1c1f1_row3_col0" class="data row3 col0" >0,22</td>
#       <td id="T_1c1f1_row3_col1" class="data row3 col1" >0,15</td>
#       <td id="T_1c1f1_row3_col2" class="data row3 col2" >0,18</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row4" class="row_heading level0 row4" >Bâtonnets de sucette</th>
#       <td id="T_1c1f1_row4_col0" class="data row4 col0" >0,03</td>
#       <td id="T_1c1f1_row4_col1" class="data row4 col1" >0,02</td>
#       <td id="T_1c1f1_row4_col2" class="data row4 col2" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row5" class="row_heading level0 row5" >Mousse de plastique pour l'isolation thermique</th>
#       <td id="T_1c1f1_row5_col0" class="data row5 col0" >0,10</td>
#       <td id="T_1c1f1_row5_col1" class="data row5 col1" >0,00</td>
#       <td id="T_1c1f1_row5_col2" class="data row5 col2" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row6" class="row_heading level0 row6" >Déchets de construction en plastique</th>
#       <td id="T_1c1f1_row6_col0" class="data row6 col0" >0,06</td>
#       <td id="T_1c1f1_row6_col1" class="data row6 col1" >0,00</td>
#       <td id="T_1c1f1_row6_col2" class="data row6 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row7" class="row_heading level0 row7" >Coton-tige</th>
#       <td id="T_1c1f1_row7_col0" class="data row7 col0" >0,13</td>
#       <td id="T_1c1f1_row7_col1" class="data row7 col1" >0,03</td>
#       <td id="T_1c1f1_row7_col2" class="data row7 col2" >0,08</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row8" class="row_heading level0 row8" >Couvercles en plastique bouteille:  g21, g22, g23, g24</th>
#       <td id="T_1c1f1_row8_col0" class="data row8 col0" >0,11</td>
#       <td id="T_1c1f1_row8_col1" class="data row8 col1" >0,04</td>
#       <td id="T_1c1f1_row8_col2" class="data row8 col2" >0,08</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row9" class="row_heading level0 row9" >Fragments de polystyrène expansé: g81, g82, g83</th>
#       <td id="T_1c1f1_row9_col0" class="data row9 col0" >0,24</td>
#       <td id="T_1c1f1_row9_col1" class="data row9 col1" >0,07</td>
#       <td id="T_1c1f1_row9_col2" class="data row9 col2" >0,11</td>
#     </tr>
#     <tr>
#       <th id="T_1c1f1_level0_row10" class="row_heading level0 row10" >Fragments de plastique: g80, g79, g78, g77, g76, g75</th>
#       <td id="T_1c1f1_row10_col0" class="data row10 col0" >0,68</td>
#       <td id="T_1c1f1_row10_col1" class="data row10 col1" >0,72</td>
#       <td id="T_1c1f1_row10_col2" class="data row10 col2" >0,69</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = 'resources/images/most_common_iqaasl.jpg'
make_exportable(t, file_name)

# %% [markdown]
# ### Les plus courants par ville
#
# La densité médiane des objets les plus courants n'est pas la même pour chaque emplacement/municipalité, ce qui suggère une répartition géographiquement inégale de ces objets.
#
# Résultats de Amphion à Hermance :

# %%
w_df = tiii.w_df.copy()
cities = w_df.city.unique()
cone = cities[:12]
ctwo = cities[12:]

t = rc.a_cumulative_report(w_df[(w_df.code.isin(most_common.index))], feature_name='city', object_column='code', table_split=cone)

rc.translated_and_style_for_display(t, tiii.lang_maps[tiii.language], tiii.language, gradient=True).set_caption("Les résultats des objets les plus courants de Plastock pour chaque ville du projet: Amphion à Hemance")
# Out:
# <style type="text/css">
# #T_5b1fe tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_5b1fe tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_5b1fe tr {
#   font-size: 10px;
# }
# #T_5b1fe th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_5b1fe td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_5b1fe caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_5b1fe_row0_col0, #T_5b1fe_row0_col1, #T_5b1fe_row0_col4, #T_5b1fe_row0_col5, #T_5b1fe_row0_col6, #T_5b1fe_row0_col9, #T_5b1fe_row0_col11, #T_5b1fe_row0_col12, #T_5b1fe_row1_col0, #T_5b1fe_row1_col2, #T_5b1fe_row1_col5, #T_5b1fe_row1_col6, #T_5b1fe_row1_col11, #T_5b1fe_row1_col12, #T_5b1fe_row2_col5, #T_5b1fe_row3_col1, #T_5b1fe_row3_col6, #T_5b1fe_row3_col9, #T_5b1fe_row4_col5, #T_5b1fe_row4_col6, #T_5b1fe_row4_col8, #T_5b1fe_row4_col9, #T_5b1fe_row4_col10, #T_5b1fe_row4_col11, #T_5b1fe_row5_col1, #T_5b1fe_row5_col2, #T_5b1fe_row5_col5, #T_5b1fe_row5_col6, #T_5b1fe_row5_col7, #T_5b1fe_row5_col9, #T_5b1fe_row5_col11, #T_5b1fe_row5_col12, #T_5b1fe_row6_col0, #T_5b1fe_row6_col1, #T_5b1fe_row6_col2, #T_5b1fe_row6_col5, #T_5b1fe_row6_col6, #T_5b1fe_row6_col7, #T_5b1fe_row6_col9, #T_5b1fe_row6_col11, #T_5b1fe_row6_col12, #T_5b1fe_row7_col2, #T_5b1fe_row7_col5, #T_5b1fe_row7_col6, #T_5b1fe_row7_col7, #T_5b1fe_row7_col11, #T_5b1fe_row8_col1, #T_5b1fe_row8_col5, #T_5b1fe_row8_col9, #T_5b1fe_row8_col11, #T_5b1fe_row9_col5, #T_5b1fe_row9_col6, #T_5b1fe_row9_col11 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_5b1fe_row0_col2, #T_5b1fe_row9_col2 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_5b1fe_row0_col3 {
#   background-color: rgba(251,137,55, .5);
#   color: black;
# }
# #T_5b1fe_row0_col7 {
#   background-color: rgba(132,41,3, .5);
#   color: black;
# }
# #T_5b1fe_row0_col8 {
#   background-color: rgba(254,243,231, .5);
#   color: black;
# }
# #T_5b1fe_row0_col10 {
#   background-color: rgba(97,97,97, .5);
#   color: black;
# }
# #T_5b1fe_row1_col1, #T_5b1fe_row4_col1, #T_5b1fe_row5_col8, #T_5b1fe_row9_col1 {
#   background-color: rgba(253,253,253, .5);
#   color: black;
# }
# #T_5b1fe_row1_col3 {
#   background-color: rgba(18,18,18, .5);
#   color: black;
# }
# #T_5b1fe_row1_col4, #T_5b1fe_row6_col4, #T_5b1fe_row7_col9 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_5b1fe_row1_col7 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_5b1fe_row1_col8, #T_5b1fe_row1_col10 {
#   background-color: rgba(120,120,120, .5);
#   color: black;
# }
# #T_5b1fe_row1_col9, #T_5b1fe_row9_col7 {
#   background-color: rgba(227,227,227, .5);
#   color: black;
# }
# #T_5b1fe_row2_col0, #T_5b1fe_row2_col11 {
#   background-color: rgba(210,210,210, .5);
#   color: black;
# }
# #T_5b1fe_row2_col1 {
#   background-color: rgba(238,238,238, .5);
#   color: black;
# }
# #T_5b1fe_row2_col2 {
#   background-color: rgba(174,174,174, .5);
#   color: black;
# }
# #T_5b1fe_row2_col3 {
#   background-color: rgba(15,15,15, .5);
#   color: black;
# }
# #T_5b1fe_row2_col4, #T_5b1fe_row3_col10, #T_5b1fe_row9_col10, #T_5b1fe_row10_col0, #T_5b1fe_row10_col3, #T_5b1fe_row10_col4, #T_5b1fe_row10_col7, #T_5b1fe_row10_col10 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_5b1fe_row2_col6, #T_5b1fe_row8_col6 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_5b1fe_row2_col7 {
#   background-color: rgba(61,61,61, .5);
#   color: black;
# }
# #T_5b1fe_row2_col8 {
#   background-color: rgba(65,65,65, .5);
#   color: black;
# }
# #T_5b1fe_row2_col9 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_5b1fe_row2_col10 {
#   background-color: rgba(79,79,79, .5);
#   color: black;
# }
# #T_5b1fe_row2_col12 {
#   background-color: rgba(198,198,198, .5);
#   color: black;
# }
# #T_5b1fe_row3_col0 {
#   background-color: rgba(10,10,10, .5);
#   color: black;
# }
# #T_5b1fe_row3_col2 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_5b1fe_row3_col3 {
#   background-color: rgba(12,12,12, .5);
#   color: black;
# }
# #T_5b1fe_row3_col4, #T_5b1fe_row10_col2 {
#   background-color: rgba(140,140,140, .5);
#   color: black;
# }
# #T_5b1fe_row3_col5, #T_5b1fe_row4_col4, #T_5b1fe_row8_col4 {
#   background-color: rgba(242,242,242, .5);
#   color: black;
# }
# #T_5b1fe_row3_col7 {
#   background-color: rgba(206,206,206, .5);
#   color: black;
# }
# #T_5b1fe_row3_col8 {
#   background-color: rgba(193,193,193, .5);
#   color: black;
# }
# #T_5b1fe_row3_col11 {
#   background-color: rgba(248,248,248, .5);
#   color: black;
# }
# #T_5b1fe_row3_col12, #T_5b1fe_row4_col3 {
#   background-color: rgba(200,200,200, .5);
#   color: black;
# }
# #T_5b1fe_row4_col0 {
#   background-color: rgba(212,212,212, .5);
#   color: black;
# }
# #T_5b1fe_row4_col2 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_5b1fe_row4_col7, #T_5b1fe_row8_col7, #T_5b1fe_row8_col8 {
#   background-color: rgba(237,237,237, .5);
#   color: black;
# }
# #T_5b1fe_row4_col12, #T_5b1fe_row5_col0, #T_5b1fe_row5_col3, #T_5b1fe_row7_col1 {
#   background-color: rgba(250,250,250, .5);
#   color: black;
# }
# #T_5b1fe_row5_col4 {
#   background-color: rgba(99,99,99, .5);
#   color: black;
# }
# #T_5b1fe_row5_col10 {
#   background-color: rgba(251,136,54, .5);
#   color: black;
# }
# #T_5b1fe_row6_col3 {
#   background-color: rgba(254,234,213, .5);
#   color: black;
# }
# #T_5b1fe_row6_col8, #T_5b1fe_row7_col8 {
#   background-color: rgba(251,251,251, .5);
#   color: black;
# }
# #T_5b1fe_row6_col10 {
#   background-color: rgba(139,139,139, .5);
#   color: black;
# }
# #T_5b1fe_row7_col0 {
#   background-color: rgba(246,122,39, .5);
#   color: black;
# }
# #T_5b1fe_row7_col3 {
#   background-color: rgba(177,177,177, .5);
#   color: black;
# }
# #T_5b1fe_row7_col4 {
#   background-color: rgba(122,122,122, .5);
#   color: black;
# }
# #T_5b1fe_row7_col10 {
#   background-color: rgba(253,214,175, .5);
#   color: black;
# }
# #T_5b1fe_row7_col12 {
#   background-color: rgba(246,246,246, .5);
#   color: black;
# }
# #T_5b1fe_row8_col0 {
#   background-color: rgba(253,153,77, .5);
#   color: black;
# }
# #T_5b1fe_row8_col2 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_5b1fe_row8_col3 {
#   background-color: rgba(29,29,29, .5);
#   color: black;
# }
# #T_5b1fe_row8_col10 {
#   background-color: rgba(84,84,84, .5);
#   color: black;
# }
# #T_5b1fe_row8_col12, #T_5b1fe_row9_col8 {
#   background-color: rgba(245,245,245, .5);
#   color: black;
# }
# #T_5b1fe_row9_col0 {
#   background-color: rgba(254,244,234, .5);
#   color: black;
# }
# #T_5b1fe_row9_col3 {
#   background-color: rgba(105,105,105, .5);
#   color: black;
# }
# #T_5b1fe_row9_col4 {
#   background-color: rgba(159,159,159, .5);
#   color: black;
# }
# #T_5b1fe_row9_col9 {
#   background-color: rgba(254,237,220, .5);
#   color: black;
# }
# #T_5b1fe_row9_col12 {
#   background-color: rgba(236,236,236, .5);
#   color: black;
# }
# #T_5b1fe_row10_col1 {
#   background-color: rgba(103,103,103, .5);
#   color: black;
# }
# #T_5b1fe_row10_col5 {
#   background-color: rgba(201,201,201, .5);
#   color: black;
# }
# #T_5b1fe_row10_col6 {
#   background-color: rgba(203,203,203, .5);
#   color: black;
# }
# #T_5b1fe_row10_col8 {
#   background-color: rgba(169,55,2, .5);
#   color: black;
# }
# #T_5b1fe_row10_col9 {
#   background-color: rgba(253,167,97, .5);
#   color: black;
# }
# #T_5b1fe_row10_col11 {
#   background-color: rgba(134,134,134, .5);
#   color: black;
# }
# #T_5b1fe_row10_col12 {
#   background-color: rgba(244,115,30, .5);
#   color: black;
# }
# </style>
# <table id="T_5b1fe">
#   <caption>Les résultats des objets les plus courants de Plastock pour chaque ville du projet: Amphion à Hemance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b1fe_level0_col0" class="col_heading level0 col0" >Amphion</th>
#       <th id="T_5b1fe_level0_col1" class="col_heading level0 col1" >Anthy</th>
#       <th id="T_5b1fe_level0_col2" class="col_heading level0 col2" >Aubonne</th>
#       <th id="T_5b1fe_level0_col3" class="col_heading level0 col3" >Bouveret</th>
#       <th id="T_5b1fe_level0_col4" class="col_heading level0 col4" >Clarens</th>
#       <th id="T_5b1fe_level0_col5" class="col_heading level0 col5" >Crans</th>
#       <th id="T_5b1fe_level0_col6" class="col_heading level0 col6" >Cully</th>
#       <th id="T_5b1fe_level0_col7" class=

# %%
file_name = 'resources/images/most_common_one.jpg'
make_exportable(t, file_name)

# %% [markdown]
# <br>
# <br>
# Résultats de Lugrin à Vidy :

# %%
t = rc.a_cumulative_report(w_df[(w_df.code.isin(most_common.index))], feature_name='city', object_column='code', table_split=ctwo)

rc.translated_and_style_for_display(t, tiii.lang_maps[tiii.language], tiii.language, gradient=True).set_caption("Les résultats des objets les plus courants de Plastock pour chaque ville du projet: Lugirn à Vevey")
# Out:
# <style type="text/css">
# #T_df646 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_df646 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_df646 tr {
#   font-size: 10px;
# }
# #T_df646 th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_df646 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_df646 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_df646_row0_col0, #T_df646_row0_col1, #T_df646_row0_col3, #T_df646_row0_col6, #T_df646_row0_col7, #T_df646_row0_col9, #T_df646_row0_col10, #T_df646_row0_col12, #T_df646_row1_col0, #T_df646_row1_col1, #T_df646_row1_col2, #T_df646_row1_col4, #T_df646_row1_col5, #T_df646_row1_col6, #T_df646_row1_col7, #T_df646_row1_col8, #T_df646_row1_col9, #T_df646_row1_col10, #T_df646_row1_col12, #T_df646_row2_col1, #T_df646_row2_col7, #T_df646_row2_col9, #T_df646_row3_col2, #T_df646_row4_col2, #T_df646_row4_col9, #T_df646_row4_col10, #T_df646_row5_col0, #T_df646_row5_col1, #T_df646_row5_col3, #T_df646_row5_col4, #T_df646_row5_col6, #T_df646_row5_col7, #T_df646_row5_col8, #T_df646_row5_col10, #T_df646_row5_col12, #T_df646_row6_col1, #T_df646_row6_col2, #T_df646_row6_col4, #T_df646_row6_col6, #T_df646_row6_col7, #T_df646_row6_col8, #T_df646_row6_col9, #T_df646_row6_col10, #T_df646_row6_col11, #T_df646_row6_col12, #T_df646_row7_col1, #T_df646_row7_col4, #T_df646_row7_col7, #T_df646_row7_col10, #T_df646_row8_col2, #T_df646_row8_col7, #T_df646_row8_col8, #T_df646_row9_col10 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_df646_row0_col2, #T_df646_row8_col1 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_df646_row0_col4 {
#   background-color: rgba(253,177,113, .5);
#   color: black;
# }
# #T_df646_row0_col5, #T_df646_row0_col8, #T_df646_row4_col0, #T_df646_row5_col2, #T_df646_row7_col2 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_df646_row0_col11 {
#   background-color: rgba(179,179,179, .5);
#   color: black;
# }
# #T_df646_row1_col3 {
#   background-color: rgba(191,62,2, .5);
#   color: black;
# }
# #T_df646_row1_col11 {
#   background-color: rgba(199,199,199, .5);
#   color: black;
# }
# #T_df646_row2_col0, #T_df646_row5_col9 {
#   background-color: rgba(228,228,228, .5);
#   color: black;
# }
# #T_df646_row2_col2 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_df646_row2_col3 {
#   background-color: rgba(22,22,22, .5);
#   color: black;
# }
# #T_df646_row2_col4 {
#   background-color: rgba(253,147,69, .5);
#   color: black;
# }
# #T_df646_row2_col5 {
#   background-color: rgba(75,75,75, .5);
#   color: black;
# }
# #T_df646_row2_col6 {
#   background-color: rgba(173,173,173, .5);
#   color: black;
# }
# #T_df646_row2_col8 {
#   background-color: rgba(253,217,180, .5);
#   color: black;
# }
# #T_df646_row2_col10, #T_df646_row8_col12 {
#   background-color: rgba(245,245,245, .5);
#   color: black;
# }
# #T_df646_row2_col11, #T_df646_row10_col1, #T_df646_row10_col3, #T_df646_row10_col4, #T_df646_row10_col5, #T_df646_row10_col9, #T_df646_row10_col11 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_df646_row2_col12 {
#   background-color: rgba(198,198,198, .5);
#   color: black;
# }
# #T_df646_row3_col0 {
#   background-color: rgba(95,95,95, .5);
#   color: black;
# }
# #T_df646_row3_col1, #T_df646_row9_col8 {
#   background-color: rgba(242,242,242, .5);
#   color: black;
# }
# #T_df646_row3_col3 {
#   background-color: rgba(125,125,125, .5);
#   color: black;
# }
# #T_df646_row3_col4 {
#   background-color: rgba(157,157,157, .5);
#   color: black;
# }
# #T_df646_row3_col5 {
#   background-color: rgba(253,173,105, .5);
#   color: black;
# }
# #T_df646_row3_col6 {
#   background-color: rgba(109,109,109, .5);
#   color: black;
# }
# #T_df646_row3_col7 {
#   background-color: rgba(223,223,223, .5);
#   color: black;
# }
# #T_df646_row3_col8 {
#   background-color: rgba(221,221,221, .5);
#   color: black;
# }
# #T_df646_row3_col9, #T_df646_row9_col2 {
#   background-color: rgba(167,167,167, .5);
#   color: black;
# }
# #T_df646_row3_col10, #T_df646_row10_col10 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_df646_row3_col11 {
#   background-color: rgba(253,152,76, .5);
#   color: black;
# }
# #T_df646_row3_col12, #T_df646_row7_col6, #T_df646_row9_col5 {
#   background-color: rgba(200,200,200, .5);
#   color: black;
# }
# #T_df646_row4_col1 {
#   background-color: rgba(134,134,134, .5);
#   color: black;
# }
# #T_df646_row4_col3, #T_df646_row4_col4, #T_df646_row8_col4 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_df646_row4_col5, #T_df646_row5_col5, #T_df646_row8_col9 {
#   background-color: rgba(232,232,232, .5);
#   color: black;
# }
# #T_df646_row4_col6, #T_df646_row8_col0 {
#   background-color: rgba(233,233,233, .5);
#   color: black;
# }
# #T_df646_row4_col7, #T_df646_row6_col3, #T_df646_row8_col10, #T_df646_row9_col7, #T_df646_row9_col11 {
#   background-color: rgba(251,251,251, .5);
#   color: black;
# }
# #T_df646_row4_col8, #T_df646_row4_col12, #T_df646_row9_col6 {
#   background-color: rgba(250,250,250, .5);
#   color: black;
# }
# #T_df646_row4_col11 {
#   background-color: rgba(237,237,237, .5);
#   color: black;
# }
# #T_df646_row5_col11 {
#   background-color: rgba(239,239,239, .5);
#   color: black;
# }
# #T_df646_row6_col0, #T_df646_row6_col5, #T_df646_row7_col8, #T_df646_row9_col9 {
#   background-color: rgba(253,253,253, .5);
#   color: black;
# }
# #T_df646_row7_col0, #T_df646_row8_col6 {
#   background-color: rgba(205,205,205, .5);
#   color: black;
# }
# #T_df646_row7_col3 {
#   background-color: rgba(238,238,238, .5);
#   color: black;
# }
# #T_df646_row7_col5 {
#   background-color: rgba(146,146,146, .5);
#   color: black;
# }
# #T_df646_row7_col9 {
#   background-color: rgba(197,197,197, .5);
#   color: black;
# }
# #T_df646_row7_col11 {
#   background-color: rgba(106,106,106, .5);
#   color: black;
# }
# #T_df646_row7_col12 {
#   background-color: rgba(246,246,246, .5);
#   color: black;
# }
# #T_df646_row8_col3 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_df646_row8_col5 {
#   background-color: rgba(98,98,98, .5);
#   color: black;
# }
# #T_df646_row8_col11 {
#   background-color: rgba(192,192,192, .5);
#   color: black;
# }
# #T_df646_row9_col0 {
#   background-color: rgba(254,241,227, .5);
#   color: black;
# }
# #T_df646_row9_col1 {
#   background-color: rgba(225,225,225, .5);
#   color: black;
# }
# #T_df646_row9_col3 {
#   background-color: rgba(178,178,178, .5);
#   color: black;
# }
# #T_df646_row9_col4 {
#   background-color: rgba(191,191,191, .5);
#   color: black;
# }
# #T_df646_row9_col12 {
#   background-color: rgba(236,236,236, .5);
#   color: black;
# }
# #T_df646_row10_col0 {
#   background-color: rgba(254,233,212, .5);
#   color: black;
# }
# #T_df646_row10_col2 {
#   background-color: rgba(181,181,181, .5);
#   color: black;
# }
# #T_df646_row10_col6 {
#   background-color: rgba(219,75,2, .5);
#   color: black;
# }
# #T_df646_row10_col7 {
#   background-color: rgba(161,161,161, .5);
#   color: black;
# }
# #T_df646_row10_col8 {
#   background-color: rgba(99,99,99, .5);
#   color: black;
# }
# #T_df646_row10_col12 {
#   background-color: rgba(244,115,30, .5);
#   color: black;
# }
# </style>
# <table id="T_df646">
#   <caption>Les résultats des objets les plus courants de Plastock pour chaque ville du projet: Lugirn à Vevey</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df646_level0_col0" class="col_heading level0 col0" >Lugrin</th>
#       <th id="T_df646_level0_col1" class="col_heading level0 col1" >Lutry</th>
#       <th id="T_df646_level0_col2" class="col_heading level0 col2" >Meillerie</th>
#       <th id="T_df646_level0_col3" class="col_heading level0 col3" >Préverenges</th>
#       <th id="T_df646_level0_col4" class="col_heading level0 col4" >Rolle</th>
#       <th id="T_df646_level0_col5" class="col_heading level0 col5" >Saint-disdille</th>
#       <th id="T_df646_level0_col6" class="col_heading level0 col6" >Savonière</th>
#       <th id="T_df646_level0_col7" class="col_heading level0 col7" >Tolochenaz</th>
#       <th id="T_df646_level0_col8" class="col_heading level0 col8" >Tougues</th>
#       <th id="T_df646_level0_col9" class="col_heading level0 col9" >Versoix</th>
#       <th id="T_df646_level0_col10" class="col_heading level0 col10" >Ve

# %%
file_name = 'resources/images/most_common_two.jpg'
make_exportable(t, file_name)

# %% [markdown]
# ## Les objets trouvés en fonction de leur utilisation
#
# Le type d'utilité est basé sur l'utilisation de l'objet avant qu'il ne soit jeté ou sur la description de l'objet si l'utilisation initiale est indéterminée. Les objets identifiés sont classés dans l'une des 260 catégories prédéfinies. Les catégories sont regroupées en fonction de leur utilisation ou de leur description.
#
# - Eaux usées : objets rejetés par les stations d'épuration, y compris les objets susceptibles d'être jetés dans les toilettes.
# - Microplastiques (< 5 mm) : plastiques fragmentés et résines plastiques de préproduction.
# - Infrastructure : objets liés à la construction et à l'entretien des bâtiments, des routes et des réseaux d'eau et d'électricité.
# - Alimentation et boisson : tous les matériaux liés à la consommation de nourriture et de boissons.
# - Agriculture : principalement des feuilles industrielles, par exemple, paillis et bâches de culture, serres, fumigation du sol, films d'emballage de balles. Comprend les plastiques durs pour les clôtures agricoles, les pots de fleurs, etc.
# - Tabac : principalement des filtres de cigarettes, y compris tous les matériaux liés au tabagisme.
# - Loisirs : objets liés au sport et aux loisirs, par exemple, pêche, chasse, randonnée, etc.
# - Emballages non alimentaires et non liés au tabac : matériaux d'emballage non identifiés comme étant liés à la nourriture, aux boissons ou au tabac.
# - Fragments de plastique : morceaux de plastique d'origine ou d'utilisation indéterminée.
# - Objets personnels : accessoires, articles d'hygiène et vêtements.
#
# Pour des informations détaillées sur la composition des groupes, consultez [IQAASL - DE](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/code_groups.html) ou [IQAASL - EN](https://www.plagespropres.ch/code_groups.html).
# <br>

# %%
groups_df = tiii.w_df.copy()
group_name_map = codes['groupname']
groups_df['groupname'] = groups_df.code.apply(lambda x: group_name_map.loc[x])
tg1 = rc.a_cumulative_report(groups_df, feature_name='city', object_column='groupname', table_split=cone)
rc.translated_and_style_for_display(tg1, tiii.lang_maps[tiii.language], tiii.language, gradient=True).set_caption("Les résultats des objets par utilisation pour chaque ville du projet: Amphion à Hemance")
# Out:
# <style type="text/css">
# #T_18ad1 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_18ad1 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_18ad1 tr {
#   font-size: 10px;
# }
# #T_18ad1 th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_18ad1 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_18ad1 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_18ad1_row0_col0, #T_18ad1_row0_col1, #T_18ad1_row0_col2, #T_18ad1_row0_col3, #T_18ad1_row0_col4, #T_18ad1_row0_col5, #T_18ad1_row0_col6, #T_18ad1_row0_col7, #T_18ad1_row0_col8, #T_18ad1_row0_col9, #T_18ad1_row0_col11, #T_18ad1_row0_col12, #T_18ad1_row1_col6, #T_18ad1_row2_col5, #T_18ad1_row2_col6, #T_18ad1_row3_col5, #T_18ad1_row3_col11, #T_18ad1_row4_col1, #T_18ad1_row4_col5, #T_18ad1_row4_col9, #T_18ad1_row5_col2, #T_18ad1_row5_col5, #T_18ad1_row5_col9, #T_18ad1_row7_col5, #T_18ad1_row7_col9, #T_18ad1_row7_col11, #T_18ad1_row8_col5, #T_18ad1_row9_col0, #T_18ad1_row9_col1, #T_18ad1_row9_col2, #T_18ad1_row9_col3, #T_18ad1_row9_col4, #T_18ad1_row9_col5, #T_18ad1_row9_col6, #T_18ad1_row9_col7, #T_18ad1_row9_col8, #T_18ad1_row9_col9, #T_18ad1_row9_col10, #T_18ad1_row9_col11, #T_18ad1_row9_col12, #T_18ad1_row10_col2, #T_18ad1_row10_col5, #T_18ad1_row10_col6, #T_18ad1_row10_col11 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_18ad1_row0_col10, #T_18ad1_row1_col1, #T_18ad1_row2_col1, #T_18ad1_row3_col1 {
#   background-color: rgba(253,253,253, .5);
#   color: black;
# }
# #T_18ad1_row1_col0 {
#   background-color: rgba(246,122,39, .5);
#   color: black;
# }
# #T_18ad1_row1_col2 {
#   background-color: rgba(188,188,188, .5);
#   color: black;
# }
# #T_18ad1_row1_col3 {
#   background-color: rgba(168,55,2, .5);
#   color: black;
# }
# #T_18ad1_row1_col4 {
#   background-color: rgba(99,99,99, .5);
#   color: black;
# }
# #T_18ad1_row1_col5, #T_18ad1_row3_col4, #T_18ad1_row4_col4, #T_18ad1_row7_col4 {
#   background-color: rgba(242,242,242, .5);
#   color: black;
# }
# #T_18ad1_row1_col7 {
#   background-color: rgba(158,158,158, .5);
#   color: black;
# }
# #T_18ad1_row1_col8 {
#   background-color: rgba(164,164,164, .5);
#   color: black;
# }
# #T_18ad1_row1_col9, #T_18ad1_row5_col7 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_18ad1_row1_col10, #T_18ad1_row2_col3, #T_18ad1_row2_col10, #T_18ad1_row3_col3, #T_18ad1_row3_col7, #T_18ad1_row3_col8, #T_18ad1_row3_col10, #T_18ad1_row6_col0, #T_18ad1_row6_col3, #T_18ad1_row6_col4, #T_18ad1_row6_col7, #T_18ad1_row6_col10, #T_18ad1_row8_col4 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_18ad1_row1_col11, #T_18ad1_row5_col4, #T_18ad1_row10_col12 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_18ad1_row1_col12 {
#   background-color: rgba(155,155,155, .5);
#   color: black;
# }
# #T_18ad1_row2_col0 {
#   background-color: rgba(253,228,202, .5);
#   color: black;
# }
# #T_18ad1_row2_col2, #T_18ad1_row4_col2 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_18ad1_row2_col4 {
#   background-color: rgba(253,159,85, .5);
#   color: black;
# }
# #T_18ad1_row2_col7 {
#   background-color: rgba(223,223,223, .5);
#   color: black;
# }
# #T_18ad1_row2_col8 {
#   background-color: rgba(220,220,220, .5);
#   color: black;
# }
# #T_18ad1_row2_col9 {
#   background-color: rgba(253,154,79, .5);
#   color: black;
# }
# #T_18ad1_row2_col11, #T_18ad1_row4_col11, #T_18ad1_row5_col1, #T_18ad1_row7_col1, #T_18ad1_row10_col7, #T_18ad1_row10_col8 {
#   background-color: rgba(250,250,250, .5);
#   color: black;
# }
# #T_18ad1_row2_col12 {
#   background-color: rgba(216,216,216, .5);
#   color: black;
# }
# #T_18ad1_row3_col0 {
#   background-color: rgba(28,28,28, .5);
#   color: black;
# }
# #T_18ad1_row3_col2 {
#   background-color: rgba(198,198,198, .5);
#   color: black;
# }
# #T_18ad1_row3_col6, #T_18ad1_row4_col6, #T_18ad1_row7_col6, #T_18ad1_row8_col6 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_18ad1_row3_col9 {
#   background-color: rgba(227,227,227, .5);
#   color: black;
# }
# #T_18ad1_row3_col12 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_18ad1_row4_col0 {
#   background-color: rgba(231,92,12, .5);
#   color: black;
# }
# #T_18ad1_row4_col3 {
#   background-color: rgba(23,23,23, .5);
#   color: black;
# }
# #T_18ad1_row4_col7 {
#   background-color: rgba(237,237,237, .5);
#   color: black;
# }
# #T_18ad1_row4_col8 {
#   background-color: rgba(232,232,232, .5);
#   color: black;
# }
# #T_18ad1_row4_col10 {
#   background-color: rgba(84,84,84, .5);
#   color: black;
# }
# #T_18ad1_row4_col12, #T_18ad1_row10_col9 {
#   background-color: rgba(243,243,243, .5);
#   color: black;
# }
# #T_18ad1_row5_col0 {
#   background-color: rgba(236,236,236, .5);
#   color: black;
# }
# #T_18ad1_row5_col3, #T_18ad1_row7_col12 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_18ad1_row5_col6, #T_18ad1_row7_col2, #T_18ad1_row10_col1 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_18ad1_row5_col8 {
#   background-color: rgba(205,205,205, .5);
#   color: black;
# }
# #T_18ad1_row5_col10 {
#   background-color: rgba(219,219,219, .5);
#   color: black;
# }
# #T_18ad1_row5_col11 {
#   background-color: rgba(248,248,248, .5);
#   color: black;
# }
# #T_18ad1_row5_col12 {
#   background-color: rgba(246,246,246, .5);
#   color: black;
# }
# #T_18ad1_row6_col1 {
#   background-color: rgba(103,103,103, .5);
#   color: black;
# }
# #T_18ad1_row6_col2 {
#   background-color: rgba(140,140,140, .5);
#   color: black;
# }
# #T_18ad1_row6_col5 {
#   background-color: rgba(201,201,201, .5);
#   color: black;
# }
# #T_18ad1_row6_col6 {
#   background-color: rgba(203,203,203, .5);
#   color: black;
# }
# #T_18ad1_row6_col8 {
#   background-color: rgba(169,55,2, .5);
#   color: black;
# }
# #T_18ad1_row6_col9 {
#   background-color: rgba(253,167,97, .5);
#   color: black;
# }
# #T_18ad1_row6_col11, #T_18ad1_row10_col3 {
#   background-color: rgba(134,134,134, .5);
#   color: black;
# }
# #T_18ad1_row6_col12 {
#   background-color: rgba(244,115,30, .5);
#   color: black;
# }
# #T_18ad1_row7_col0 {
#   background-color: rgba(187,187,187, .5);
#   color: black;
# }
# #T_18ad1_row7_col3 {
#   background-color: rgba(204,204,204, .5);
#   color: black;
# }
# #T_18ad1_row7_col7 {
#   background-color: rgba(239,239,239, .5);
#   color: black;
# }
# #T_18ad1_row7_col8 {
#   background-color: rgba(202,202,202, .5);
#   color: black;
# }
# #T_18ad1_row7_col10 {
#   background-color: rgba(190,190,190, .5);
#   color: black;
# }
# #T_18ad1_row8_col0 {
#   background-color: rgba(207,207,207, .5);
#   color: black;
# }
# #T_18ad1_row8_col1 {
#   background-color: rgba(238,238,238, .5);
#   color: black;
# }
# #T_18ad1_row8_col2 {
#   background-color: rgba(174,174,174, .5);
#   color: black;
# }
# #T_18ad1_row8_col3 {
#   background-color: rgba(12,12,12, .5);
#   color: black;
# }
# #T_18ad1_row8_col7 {
#   background-color: rgba(58,58,58, .5);
#   color: black;
# }
# #T_18ad1_row8_col8 {
#   background-color: rgba(65,65,65, .5);
#   color: black;
# }
# #T_18ad1_row8_col9 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_18ad1_row8_col10 {
#   background-color: rgba(79,79,79, .5);
#   color: black;
# }
# #T_18ad1_row8_col11 {
#   background-color: rgba(210,210,210, .5);
#   color: black;
# }
# #T_18ad1_row8_col12 {
#   background-color: rgba(196,196,196, .5);
#   color: black;
# }
# #T_18ad1_row10_col0 {
#   background-color: rgba(160,51,3, .5);
#   color: black;
# }
# #T_18ad1_row10_col4 {
#   background-color: rgba(116,116,116, .5);
#   color: black;
# }
# #T_18ad1_row10_col10 {
#   background-color: rgba(253,150,73, .5);
#   color: black;
# }
# </style>
# <table id="T_18ad1">
#   <caption>Les résultats des objets par utilisation pour chaque ville du projet: Amphion à Hemance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18ad1_level0_col0" class="col_heading level0 col0" >Amphion</th>
#       <th id="T_18ad1_level0_col1" class="col_heading level0 col1" >Anthy</th>
#       <th id="T_18ad1_level0_col2" class="col_heading level0 col2" >Aubonne</th>
#       <th id="T_18ad1_level0_col3" class="col_heading level0 col3" >Bouveret</th>
#       <th id="T_18ad1_level0_col4" class="col_heading level0 col4" >Clarens</th>
#       <th id="T_18ad1_level0_col5" class="col_heading level0 col5" >Crans</th>

# %%
file_name = 'resources/images/group_names_one.jpg'
make_exportable(tg1, file_name)

# %%
tg2 = rc.a_cumulative_report(groups_df, feature_name='city', object_column='groupname', table_split=ctwo)
rc.translated_and_style_for_display(tg2, tiii.lang_maps[tiii.language], tiii.language, gradient=True).set_caption("Les résultats des objets par utilisation pour chaque ville du projet: Lugirn à Vevey")
# Out:
# <style type="text/css">
# #T_6f400 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6f400 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6f400 tr {
#   font-size: 10px;
# }
# #T_6f400 th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_6f400 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_6f400 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_6f400_row0_col0, #T_6f400_row2_col7, #T_6f400_row4_col3 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_6f400_row0_col1, #T_6f400_row0_col2, #T_6f400_row0_col3, #T_6f400_row0_col4, #T_6f400_row0_col6, #T_6f400_row0_col7, #T_6f400_row0_col8, #T_6f400_row0_col9, #T_6f400_row0_col10, #T_6f400_row0_col11, #T_6f400_row0_col12, #T_6f400_row1_col2, #T_6f400_row2_col10, #T_6f400_row3_col0, #T_6f400_row3_col9, #T_6f400_row4_col2, #T_6f400_row4_col7, #T_6f400_row4_col8, #T_6f400_row5_col1, #T_6f400_row5_col2, #T_6f400_row7_col2, #T_6f400_row7_col7, #T_6f400_row8_col1, #T_6f400_row8_col7, #T_6f400_row8_col9, #T_6f400_row9_col0, #T_6f400_row9_col1, #T_6f400_row9_col2, #T_6f400_row9_col3, #T_6f400_row9_col4, #T_6f400_row9_col5, #T_6f400_row9_col6, #T_6f400_row9_col7, #T_6f400_row9_col8, #T_6f400_row9_col9, #T_6f400_row9_col10, #T_6f400_row9_col11, #T_6f400_row9_col12, #T_6f400_row10_col7, #T_6f400_row10_col10 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_6f400_row0_col5 {
#   background-color: rgba(92,92,92, .5);
#   color: black;
# }
# #T_6f400_row1_col0 {
#   background-color: rgba(66,66,66, .5);
#   color: black;
# }
# #T_6f400_row1_col1 {
#   background-color: rgba(93,93,93, .5);
#   color: black;
# }
# #T_6f400_row1_col3 {
#   background-color: rgba(115,115,115, .5);
#   color: black;
# }
# #T_6f400_row1_col4 {
#   background-color: rgba(157,157,157, .5);
#   color: black;
# }
# #T_6f400_row1_col5 {
#   background-color: rgba(218,73,1, .5);
#   color: black;
# }
# #T_6f400_row1_col6 {
#   background-color: rgba(14,14,14, .5);
#   color: black;
# }
# #T_6f400_row1_col7 {
#   background-color: rgba(223,223,223, .5);
#   color: black;
# }
# #T_6f400_row1_col8 {
#   background-color: rgba(209,209,209, .5);
#   color: black;
# }
# #T_6f400_row1_col9, #T_6f400_row2_col5 {
#   background-color: rgba(103,103,103, .5);
#   color: black;
# }
# #T_6f400_row1_col10, #T_6f400_row2_col6, #T_6f400_row5_col6 {
#   background-color: rgba(237,237,237, .5);
#   color: black;
# }
# #T_6f400_row1_col11 {
#   background-color: rgba(171,55,2, .5);
#   color: black;
# }
# #T_6f400_row1_col12 {
#   background-color: rgba(155,155,155, .5);
#   color: black;
# }
# #T_6f400_row2_col0 {
#   background-color: rgba(253,176,111, .5);
#   color: black;
# }
# #T_6f400_row2_col1, #T_6f400_row3_col12 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_6f400_row2_col2 {
#   background-color: rgba(153,153,153, .5);
#   color: black;
# }
# #T_6f400_row2_col3 {
#   background-color: rgba(164,164,164, .5);
#   color: black;
# }
# #T_6f400_row2_col4 {
#   background-color: rgba(131,131,131, .5);
#   color: black;
# }
# #T_6f400_row2_col8, #T_6f400_row10_col3 {
#   background-color: rgba(236,236,236, .5);
#   color: black;
# }
# #T_6f400_row2_col9 {
#   background-color: rgba(202,202,202, .5);
#   color: black;
# }
# #T_6f400_row2_col11, #T_6f400_row2_col12 {
#   background-color: rgba(216,216,216, .5);
#   color: black;
# }
# #T_6f400_row3_col1, #T_6f400_row5_col9, #T_6f400_row5_col10 {
#   background-color: rgba(248,248,248, .5);
#   color: black;
# }
# #T_6f400_row3_col2 {
#   background-color: rgba(203,203,203, .5);
#   color: black;
# }
# #T_6f400_row3_col3, #T_6f400_row6_col1, #T_6f400_row6_col3, #T_6f400_row6_col4, #T_6f400_row6_col5, #T_6f400_row6_col9, #T_6f400_row6_col11, #T_6f400_row8_col11 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_6f400_row3_col4 {
#   background-color: rgba(149,47,3, .5);
#   color: black;
# }
# #T_6f400_row3_col5, #T_6f400_row4_col9 {
#   background-color: rgba(232,232,232, .5);
#   color: black;
# }
# #T_6f400_row3_col6 {
#   background-color: rgba(250,250,250, .5);
#   color: black;
# }
# #T_6f400_row3_col7 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_6f400_row3_col8, #T_6f400_row7_col0 {
#   background-color: rgba(228,228,228, .5);
#   color: black;
# }
# #T_6f400_row3_col10, #T_6f400_row5_col11, #T_6f400_row8_col10 {
#   background-color: rgba(245,245,245, .5);
#   color: black;
# }
# #T_6f400_row3_col11 {
#   background-color: rgba(42,42,42, .5);
#   color: black;
# }
# #T_6f400_row4_col0 {
#   background-color: rgba(233,233,233, .5);
#   color: black;
# }
# #T_6f400_row4_col1, #T_6f400_row10_col12 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_6f400_row4_col4, #T_6f400_row5_col8 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_6f400_row4_col5 {
#   background-color: rgba(89,89,89, .5);
#   color: black;
# }
# #T_6f400_row4_col6 {
#   background-color: rgba(205,205,205, .5);
#   color: black;
# }
# #T_6f400_row4_col10, #T_6f400_row5_col7, #T_6f400_row7_col8, #T_6f400_row7_col10 {
#   background-color: rgba(251,251,251, .5);
#   color: black;
# }
# #T_6f400_row4_col11 {
#   background-color: rgba(192,192,192, .5);
#   color: black;
# }
# #T_6f400_row4_col12, #T_6f400_row5_col3 {
#   background-color: rgba(243,243,243, .5);
#   color: black;
# }
# #T_6f400_row5_col0, #T_6f400_row7_col6, #T_6f400_row8_col0 {
#   background-color: rgba(225,225,225, .5);
#   color: black;
# }
# #T_6f400_row5_col4 {
#   background-color: rgba(206,206,206, .5);
#   color: black;
# }
# #T_6f400_row5_col5, #T_6f400_row8_col2 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_6f400_row5_col12, #T_6f400_row7_col9 {
#   background-color: rgba(246,246,246, .5);
#   color: black;
# }
# #T_6f400_row6_col0 {
#   background-color: rgba(254,233,212, .5);
#   color: black;
# }
# #T_6f400_row6_col2 {
#   background-color: rgba(181,181,181, .5);
#   color: black;
# }
# #T_6f400_row6_col6 {
#   background-color: rgba(219,75,2, .5);
#   color: black;
# }
# #T_6f400_row6_col7 {
#   background-color: rgba(161,161,161, .5);
#   color: black;
# }
# #T_6f400_row6_col8 {
#   background-color: rgba(99,99,99, .5);
#   color: black;
# }
# #T_6f400_row6_col10, #T_6f400_row7_col12 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_6f400_row6_col12 {
#   background-color: rgba(244,115,30, .5);
#   color: black;
# }
# #T_6f400_row7_col1 {
#   background-color: rgba(238,238,238, .5);
#   color: black;
# }
# #T_6f400_row7_col3 {
#   background-color: rgba(235,235,235, .5);
#   color: black;
# }
# #T_6f400_row7_col4 {
#   background-color: rgba(221,221,221, .5);
#   color: black;
# }
# #T_6f400_row7_col5 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_6f400_row7_col11 {
#   background-color: rgba(199,199,199, .5);
#   color: black;
# }
# #T_6f400_row8_col3 {
#   background-color: rgba(22,22,22, .5);
#   color: black;
# }
# #T_6f400_row8_col4 {
#   background-color: rgba(253,147,69, .5);
#   color: black;
# }
# #T_6f400_row8_col5 {
#   background-color: rgba(75,75,75, .5);
#   color: black;
# }
# #T_6f400_row8_col6 {
#   background-color: rgba(167,167,167, .5);
#   color: black;
# }
# #T_6f400_row8_col8 {
#   background-color: rgba(253,217,180, .5);
#   color: black;
# }
# #T_6f400_row8_col12 {
#   background-color: rgba(196,196,196, .5);
#   color: black;
# }
# #T_6f400_row10_col0 {
#   background-color: rgba(201,201,201, .5);
#   color: black;
# }
# #T_6f400_row10_col1, #T_6f400_row10_col8 {
#   background-color: rgba(253,253,253, .5);
#   color: black;
# }
# #T_6f400_row10_col2, #T_6f400_row10_col4 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_6f400_row10_col5 {
#   background-color: rgba(134,134,134, .5);
#   color: black;
# }
# #T_6f400_row10_col6 {
#   background-color: rgba(200,200,200, .5);
#   color: black;
# }
# #T_6f400_row10_col9 {
#   background-color: rgba(197,197,197, .5);
#   color: black;
# }
# #T_6f400_row10_col11 {
#   background-color: rgba(70,70,70, .5);
#   color: black;
# }
# </style>
# <table id="T_6f400">
#   <caption>Les résultats des objets par utilisation pour chaque ville du projet: Lugirn à Vevey</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f400_level0_col0" class="col_heading level0 col0" >Lugrin</th>
#       <th id="T_6f400_level0_col1" class="col_heading level0 col1" >Lutry</th>
#       <th id="T_6f400_leve

# %%
file_name = 'resources/images/group_names_two.jpg'
make_exportable(tg2, file_name)

# %% [markdown]
# ## Plastock - IQAASL
#
# Plastock et IQAASL étaient deux projets distincts qui ont mesuré la même chose. En les combinant, ils offrent une représentation des conditions sur le littoral du lac pour la période allant d'avril 2020 à décembre 2022.
#
# Dans cette section, nous comparons les résultats d'un projet à l'autre et les combinons pour définir les perspectives pour 2024.

# %%
rep_res_one = "Il y a eu 101 échantillons collectés dans 24 endroits différents de 13 villes différentes entre 2020 et 2021 sur le lac Léman. La médiane, la moyenne et l'écart type étaient tous plus élevés lors de l'exercice 2020-2021 par rapport à Plastock (2022)."
rep_res_two = "La longueur du littoral était en moyenne plus longue et plus large pour les enquêtes Plastock."
t = combined.summarize_feature_labels(feature='project')
ti = rc.translated_and_style_for_display(t, tiii.lang_maps[tiii.language], tiii.language, gradient=False)
glue('pstock_iqaasl_one',rep_res_one , display=False)
glue('pstock_iqaasl_two',rep_res_two , display=False)
glue('mc_pstock_results', ti, display=False)

# %% [markdown]
# <style>
# table th:first-of-type {
#     width: 50%;
# }
# table th:nth-of-type(2) {
#     width: 50%;
# }
#
# </style>
#
#
# | |La répartition des résultats|
# |:---:|:---|
# |{glue}`mc_pstock_results`|<br>{glue:text}`pstock_iqaasl_one`<br><br>{glue:text}`pstock_iqaasl_two`|

# %%
comb_dt = combined.w_df
comb_dt = comb_dt.groupby(['loc_date', 'date', 'project'], as_index=False).pcs_m.sum()



fig, ax = plt.subplots(2,2, figsize=(8,8))

sns.scatterplot(data=comb_dt, x="date", y="pcs_m", hue='project', ax=ax[0,0])
ax[0,0].set_title("Total par échantillon", loc="left")
ax[0,0].xaxis.set_major_locator(mdates.MonthLocator(interval=6))
ax[0,0].xaxis.set_major_formatter(mdates.DateFormatter('%m-%y'))
ax[0,0].set_ylabel("")
capitalize_x_and_y_axis_labels(ax[0,0])
capitalize_legend_components(ax[0, 0])

sns.boxplot(data=comb_dt, y="pcs_m", x='project', hue='project', dodge=False, width=.9, ax=ax[0,1])
ax[0,1].set_title("Boîte de Tukey", loc="left")
capitalize_x_and_y_axis_labels(ax[0,1])
ax[0, 1].get_legend().remove()
ax[0,1].set_xlabel("")

sns.histplot(data=comb_dt, x="pcs_m", ax=ax[1,0], stat="probability", hue='project', kde=True)
ax[1,0].yaxis.set_major_formatter('{x:.2f}')
ax[1,0].set_ylabel("Probabilité")
ax[1,0].set_title("Histogramme", loc="left")
capitalize_x_and_y_axis_labels(ax[1,0])
ax[1, 0].get_legend().remove()

sns.ecdfplot(data=comb_dt, x="pcs_m", hue='project', ax=ax[1,1])
ax[1,1].set_title("Fonction de répartition", loc="left")
capitalize_x_and_y_axis_labels(ax[1,1])
sns.move_legend(ax[1, 1], title=" ", loc='best')

plt.subplots_adjust(wspace=.3, hspace=.3)

glue('fig-D2', fig, display=False)
plt.close()

# %% [markdown]
# ```{glue:figure} fig-D2
# ---
# name: fig-D2
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# ### Les objets les plus courants Plastock + Iqaasl
#
# Les objets les plus courants des données combinées sont identifiés avec la même méthode que dans la section précédente. Les objets les plus courants ci-dessous représentent 87 % de l'ensemble des données, soit 46 003 sur 52 777.

# %%
com_mc, weight = combined.most_common
caption = "Les objets les plus courants des données combinées de Plastock et IQAASL"
rc.translated_and_style_for_display(com_mc.copy(), tiii.lang_maps[tiii.language], tiii.language, gradient=False).set_caption(caption)
# Out:
# <style type="text/css">
# #T_767cb tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_767cb tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_767cb tr {
#   font-size: 10px;
# }
# #T_767cb th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_767cb td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_767cb caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# </style>
# <table id="T_767cb">
#   <caption>Les objets les plus courants des données combinées de Plastock et IQAASL</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_767cb_level0_col0" class="col_heading level0 col0" >Quantité</th>
#       <th id="T_767cb_level0_col1" class="col_heading level0 col1" >% du total</th>
#       <th id="T_767cb_level0_col2" class="col_heading level0 col2" >Pcs/m</th>
#       <th id="T_767cb_level0_col3" class="col_heading level0 col3" >Taux d'échec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_767cb_level0_row0" class="row_heading level0 row0" >Fragments de plastique: g80, g79, g78, g77, g76, g75</th>
#       <td id="T_767cb_row0_col0" class="data row0 col0" >15'996</td>
#       <td id="T_767cb_row0_col1" class="data row0 col1" >0,30</td>
#       <td id="T_767cb_row0_col2" class="data row0 col2" >0,69</td>
#       <td id="T_767cb_row0_col3" class="data row0 col3" >0,97</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row1" class="row_heading level0 row1" >Mégots et filtres à cigarettes</th>
#       <td id="T_767cb_row1_col0" class="data row1 col0" >6'255</td>
#       <td id="T_767cb_row1_col1" class="data row1 col1" >0,12</td>
#       <td id="T_767cb_row1_col2" class="data row1 col2" >0,30</td>
#       <td id="T_767cb_row1_col3" class="data row1 col3" >0,87</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row2" class="row_heading level0 row2" >Fragments de polystyrène expansé: g81, g82, g83</th>
#       <td id="T_767cb_row2_col0" class="data row2 col0" >5'040</td>
#       <td id="T_767cb_row2_col1" class="data row2 col1" >0,10</td>
#       <td id="T_767cb_row2_col2" class="data row2 col2" >0,11</td>
#       <td id="T_767cb_row2_col3" class="data row2 col3" >0,78</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row3" class="row_heading level0 row3" >Emballages de bonbons, de snacks</th>
#       <td id="T_767cb_row3_col0" class="data row3 col0" >3'917</td>
#       <td id="T_767cb_row3_col1" class="data row3 col1" >0,07</td>
#       <td id="T_767cb_row3_col2" class="data row3 col2" >0,18</td>
#       <td id="T_767cb_row3_col3" class="data row3 col3" >0,85</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row4" class="row_heading level0 row4" >Pellets industriels (gpi)</th>
#       <td id="T_767cb_row4_col0" class="data row4 col0" >2'966</td>
#       <td id="T_767cb_row4_col1" class="data row4 col1" >0,06</td>
#       <td id="T_767cb_row4_col2" class="data row4 col2" >0,00</td>
#       <td id="T_767cb_row4_col3" class="data row4 col3" >0,42</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row5" class="row_heading level0 row5" >Fragments de plastique angulaires <5mm</th>
#       <td id="T_767cb_row5_col0" class="data row5 col0" >2'357</td>
#       <td id="T_767cb_row5_col1" class="data row5 col1" >0,04</td>
#       <td id="T_767cb_row5_col2" class="data row5 col2" >0,00</td>
#       <td id="T_767cb_row5_col3" class="data row5 col3" >0,33</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row6" class="row_heading level0 row6" >Couvercles en plastique bouteille:  g21, g22, g23, g24</th>
#       <td id="T_767cb_row6_col0" class="data row6 col0" >2'345</td>
#       <td id="T_767cb_row6_col1" class="data row6 col1" >0,04</td>
#       <td id="T_767cb_row6_col2" class="data row6 col2" >0,08</td>
#       <td id="T_767cb_row6_col3" class="data row6 col3" >0,77</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row7" class="row_heading level0 row7" >Coton-tige</th>
#       <td id="T_767cb_row7_col0" class="data row7 col0" >2'234</td>
#       <td id="T_767cb_row7_col1" class="data row7 col1" >0,04</td>
#       <td id="T_767cb_row7_col2" class="data row7 col2" >0,08</td>
#       <td id="T_767cb_row7_col3" class="data row7 col3" >0,68</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row8" class="row_heading level0 row8" >Mousse de plastique pour l'isolation thermique</th>
#       <td id="T_767cb_row8_col0" class="data row8 col0" >1'531</td>
#       <td id="T_767cb_row8_col1" class="data row8 col1" >0,03</td>
#       <td id="T_767cb_row8_col2" class="data row8 col2" >0,02</td>
#       <td id="T_767cb_row8_col3" class="data row8 col3" >0,58</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row9" class="row_heading level0 row9" >Bâche, feuille plastique industrielle</th>
#       <td id="T_767cb_row9_col0" class="data row9 col0" >1'279</td>
#       <td id="T_767cb_row9_col1" class="data row9 col1" >0,02</td>
#       <td id="T_767cb_row9_col2" class="data row9 col2" >0,00</td>
#       <td id="T_767cb_row9_col3" class="data row9 col3" >0,43</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row10" class="row_heading level0 row10" >Polystyrène < 5mm</th>
#       <td id="T_767cb_row10_col0" class="data row10 col0" >1'002</td>
#       <td id="T_767cb_row10_col1" class="data row10 col1" >0,02</td>
#       <td id="T_767cb_row10_col2" class="data row10 col2" >0,00</td>
#       <td id="T_767cb_row10_col3" class="data row10 col3" >0,32</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row11" class="row_heading level0 row11" >Bâtonnets de sucette</th>
#       <td id="T_767cb_row11_col0" class="data row11 col0" >632</td>
#       <td id="T_767cb_row11_col1" class="data row11 col1" >0,01</td>
#       <td id="T_767cb_row11_col2" class="data row11 col2" >0,02</td>
#       <td id="T_767cb_row11_col3" class="data row11 col3" >0,61</td>
#     </tr>
#     <tr>
#       <th id="T_767cb_level0_row12" class="row_heading level0 row12" >Pailles et agitateurs</th>
#       <td id="T_767cb_row12_col0" class="data row12 col0" >449</td>
#       <td id="T_767cb_row12_col1" class="data row12 col1" >0,01</td>
#       <td id="T_767cb_row12_col2" class="data row12 col2" >0,02</td>
#       <td id="T_767cb_row12_col3" class="data row12 col3" >0,57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Distribution des plus courants pour chaque projet.

# %%
t = rc.a_cumulative_report(combined.w_df[combined.w_df.code.isin(com_mc.index)], feature_name='project', object_column='code')
rc.translated_and_style_for_display(t, tiii.lang_maps[tiii.language], tiii.language, gradient=True).set_caption("Les résultats des objets les plus courants séparés par projet.")
# Out:
# <style type="text/css">
# #T_30d2a tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_30d2a tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_30d2a tr {
#   font-size: 10px;
# }
# #T_30d2a th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_30d2a td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_30d2a caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_30d2a_row0_col0, #T_30d2a_row0_col1, #T_30d2a_row0_col2, #T_30d2a_row1_col0, #T_30d2a_row1_col1, #T_30d2a_row1_col2, #T_30d2a_row2_col0, #T_30d2a_row2_col1, #T_30d2a_row2_col2, #T_30d2a_row6_col1, #T_30d2a_row7_col1, #T_30d2a_row7_col2, #T_30d2a_row8_col1 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_30d2a_row3_col0 {
#   background-color: rgba(254,239,224, .5);
#   color: black;
# }
# #T_30d2a_row3_col1 {
#   background-color: rgba(198,198,198, .5);
#   color: black;
# }
# #T_30d2a_row3_col2 {
#   background-color: rgba(106,106,106, .5);
#   color: black;
# }
# #T_30d2a_row4_col0 {
#   background-color: rgba(153,153,153, .5);
#   color: black;
# }
# #T_30d2a_row4_col1 {
#   background-color: rgba(200,200,200, .5);
#   color: black;
# }
# #T_30d2a_row4_col2 {
#   background-color: rgba(179,179,179, .5);
#   color: black;
# }
# #T_30d2a_row5_col0 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_30d2a_row5_col1, #T_30d2a_row6_col2 {
#   background-color: rgba(250,250,250, .5);
#   color: black;
# }
# #T_30d2a_row5_col2, #T_30d2a_row8_col2 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_30d2a_row6_col0 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_30d2a_row7_col0 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_30d2a_row8_col0 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_30d2a_row9_col0 {
#   background-color: rgba(208,208,208, .5);
#   color: black;
# }
# #T_30d2a_row9_col1 {
#   background-color: rgba(246,246,246, .5);
#   color: black;
# }
# #T_30d2a_row9_col2 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_30d2a_row10_col0 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_30d2a_row10_col1 {
#   background-color: rgba(245,245,245, .5);
#   color: black;
# }
# #T_30d2a_row10_col2 {
#   background-color: rgba(232,232,232, .5);
#   color: black;
# }
# #T_30d2a_row11_col0 {
#   background-color: rgba(140,140,140, .5);
#   color: black;
# }
# #T_30d2a_row11_col1 {
#   background-color: rgba(236,236,236, .5);
#   color: black;
# }
# #T_30d2a_row11_col2 {
#   background-color: rgba(217,217,217, .5);
#   color: black;
# }
# #T_30d2a_row12_col0 {
#   background-color: rgba(251,137,56, .5);
#   color: black;
# }
# #T_30d2a_row12_col1 {
#   background-color: rgba(244,115,30, .5);
#   color: black;
# }
# #T_30d2a_row12_col2 {
#   background-color: rgba(250,133,50, .5);
#   color: black;
# }
# </style>
# <table id="T_30d2a">
#   <caption>Les résultats des objets les plus courants séparés par projet.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30d2a_level0_col0" class="col_heading level0 col0" >Iqaasl</th>
#       <th id="T_30d2a_level0_col1" class="col_heading level0 col1" >Plastock</th>
#       <th id="T_30d2a_level0_col2" class="col_heading level0 col2" >Cumulé</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30d2a_level0_row0" class="row_heading level0 row0" >Fragments de plastique angulaires <5mm</th>
#       <td id="T_30d2a_row0_col0" class="data row0 col0" >0,00</td>
#       <td id="T_30d2a_row0_col1" class="data row0 col1" >0,00</td>
#       <td id="T_30d2a_row0_col2" class="data row0 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row1" class="row_heading level0 row1" >Pellets industriels (gpi)</th>
#       <td id="T_30d2a_row1_col0" class="data row1 col0" >0,00</td>
#       <td id="T_30d2a_row1_col1" class="data row1 col1" >0,00</td>
#       <td id="T_30d2a_row1_col2" class="data row1 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row2" class="row_heading level0 row2" >Polystyrène < 5mm</th>
#       <td id="T_30d2a_row2_col0" class="data row2 col0" >0,00</td>
#       <td id="T_30d2a_row2_col1" class="data row2 col1" >0,00</td>
#       <td id="T_30d2a_row2_col2" class="data row2 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row3" class="row_heading level0 row3" >Mégots et filtres à cigarettes</th>
#       <td id="T_30d2a_row3_col0" class="data row3 col0" >0,47</td>
#       <td id="T_30d2a_row3_col1" class="data row3 col1" >0,15</td>
#       <td id="T_30d2a_row3_col2" class="data row3 col2" >0,30</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row4" class="row_heading level0 row4" >Emballages de bonbons, de snacks</th>
#       <td id="T_30d2a_row4_col0" class="data row4 col0" >0,22</td>
#       <td id="T_30d2a_row4_col1" class="data row4 col1" >0,15</td>
#       <td id="T_30d2a_row4_col2" class="data row4 col2" >0,18</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row5" class="row_heading level0 row5" >Bâtonnets de sucette</th>
#       <td id="T_30d2a_row5_col0" class="data row5 col0" >0,03</td>
#       <td id="T_30d2a_row5_col1" class="data row5 col1" >0,02</td>
#       <td id="T_30d2a_row5_col2" class="data row5 col2" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row6" class="row_heading level0 row6" >Pailles et agitateurs</th>
#       <td id="T_30d2a_row6_col0" class="data row6 col0" >0,04</td>
#       <td id="T_30d2a_row6_col1" class="data row6 col1" >0,00</td>
#       <td id="T_30d2a_row6_col2" class="data row6 col2" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row7" class="row_heading level0 row7" >Bâche, feuille plastique industrielle</th>
#       <td id="T_30d2a_row7_col0" class="data row7 col0" >0,09</td>
#       <td id="T_30d2a_row7_col1" class="data row7 col1" >0,00</td>
#       <td id="T_30d2a_row7_col2" class="data row7 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row8" class="row_heading level0 row8" >Mousse de plastique pour l'isolation thermique</th>
#       <td id="T_30d2a_row8_col0" class="data row8 col0" >0,10</td>
#       <td id="T_30d2a_row8_col1" class="data row8 col1" >0,00</td>
#       <td id="T_30d2a_row8_col2" class="data row8 col2" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row9" class="row_heading level0 row9" >Coton-tige</th>
#       <td id="T_30d2a_row9_col0" class="data row9 col0" >0,13</td>
#       <td id="T_30d2a_row9_col1" class="data row9 col1" >0,03</td>
#       <td id="T_30d2a_row9_col2" class="data row9 col2" >0,08</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row10" class="row_heading level0 row10" >Couvercles en plastique bouteille:  g21, g22, g23, g24</th>
#       <td id="T_30d2a_row10_col0" class="data row10 col0" >0,11</td>
#       <td id="T_30d2a_row10_col1" class="data row10 col1" >0,04</td>
#       <td id="T_30d2a_row10_col2" class="data row10 col2" >0,08</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row11" class="row_heading level0 row11" >Fragments de polystyrène expansé: g81, g82, g83</th>
#       <td id="T_30d2a_row11_col0" class="data row11 col0" >0,24</td>
#       <td id="T_30d2a_row11_col1" class="data row11 col1" >0,07</td>
#       <td id="T_30d2a_row11_col2" class="data row11 col2" >0,11</td>
#     </tr>
#     <tr>
#       <th id="T_30d2a_level0_row12" class="row_heading level0 row12" >Fragments de plastique: g80, g79, g78, g77, g76, g75</th>
#       <td id="T_30d2a_row12_col0" class="data row12 col0" >0,68</td>
#       <td id="T_30d2a_row12_col1" class="data row12 col1" >0,72</td>
#       <td id="T_30d2a_row12_col2" class="data row12 col2" >0,69</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = 'resources/images/most_common_combined.jpg'
make_exportable(t, file_name)

# %% [markdown]
# ## Effets des variables environnementales
#
# Les enquêtes comprennent des classements ordinaux pour les attributs suivants :
#
# 1. distance au parking, du plus proche au plus éloigné (1-4)
# 2. utilisation : faible, moyenne, élevée
# 3. substrat : sable fin à roches (1-4)
# 4. situation : campagne ou urbain
#
# Il y a également une cinquième variable appelée "orientation" qui donne l'orientation cardinale de la plage par rapport au lac. Si vous regardez les résultats de l'ACP, l'orientation est la seule variable à conserver son poids sur les cinq dimensions.
#
# Ces variables sont également corrélées. D'après le tableau ci-dessous, il y a une corrélation positive entre la fréquence et la situation. De plus, il y a une corrélation négative entre la distance et l'utilisation.
#
# ### Méthodes d'Analyse des corrélation
#
#     Coefficient de Corrélation de Spearman :
#         Il s'agit d'une mesure non paramétrique de la corrélation de rang. Il évalue dans quelle mesure la relation entre deux variables peut être décrite à l'aide d'une fonction monotone.
#         Convient aux données ordinales car il dépend du rang des valeurs plutôt que de leurs magnitudes réelles.

# %%
# the independent variables are in asl_beaches file
beach_data = pd.read_csv("data/end_pipe/asl_beaches.csv").set_index('Plage')

# they can be merged on the Plage column and the index
env_plastock = ti_work.merge(beach_data[['frequentation', 'situation', 'orientation', 'distance']], left_on='Plage', right_index=True)

# check the ranked correlation betwen the ordinal variables
corr_table = env_plastock[env_plastock.code.isin(com_mc.index)].groupby(['loc_date', 'city', 'substrat','frequentation', 'situation', 'orientation', 'distance'], as_index=False).pcs_m.sum()
corr_table[['frequentation', 'situation', 'distance', 'substrat']].corr(method='spearman')
# Out:
#                frequentation  situation  distance  substrat
# frequentation       1.000000   0.360269 -0.191261 -0.299496
# situation           0.360269   1.000000  0.154778 -0.203255
# distance           -0.191261   0.154778  1.000000 -0.110149
# substrat           -0.299496  -0.203255 -0.110149  1.000000

# %%
env_plastock[env_plastock.slug == 'versoix-p'][['loc_date', 'substrat']].substrat.unique()
# Out:
# array([3])

# %% [markdown]
# ### Gérer les covariables.
# Cela signifie que nous utilisons deux techniques pour traiter les variables corrélées :
#
# 1. __Termes d'Interaction :__ si l'effet d'une variable peut dépendre d'une autre (par exemple, l'effet des rues pourrait dépendre du niveau de densité des bâtiments), envisagez d'ajouter des termes d'interaction au modèle.
#
# 2. __Création d'une Variable Composite :__ combiner des covariables en une seule variable composite si elles représentent collectivement un phénomène sous-jacent unique. Cependant, cette approche simplifie le modèle et peut perdre certaines subtilités quant à la façon dont chaque variable affecte indépendamment la réponse.

# %% [markdown]
# ### Parameter estimation and predictions
#
# We consider the results of the PCA in the first chapter and the guidance from Marine Litter Baselines as a good starting point. The survey results and the magnitude of the environmental conditions will be related using two techniques:
#
# 1. Modèle linéaire généralisé (GLM) avec distribution binomiale négative
#
#     Cas d'utilisation : Cette approche est adaptée aux données de comptage, en particulier lorsqu'il y a une surdispersion (c'est-à-dire lorsque la variance dépasse la moyenne). La distribution binomiale négative gère cette surdispersion mieux qu'une distribution de Poisson.
#
#     Mise en œuvre :
#         Modélise les pcs/m en fonction des variables explicatives (densité de construction, densité forestière, emplacement).
#         Des outils tels que statsmodels ou bambi en Python peuvent être utilisés pour cette analyse.
#         statsmodels offre une approche fréquentiste plus traditionnelle, tandis que bambi propose une interface bayésienne.
#
#     Prédictions :
#         Fournit des estimations ponctuelles de la valeur attendue de pcs/m pour des conditions données.
#         Peut également fournir des mesures d'incertitude telles que des intervalles de confiance.
#
# 2. Approximation Bayésienne par Grille
#
#     Cas d'utilisation : Cette méthode est une approche manuelle de l'inférence bayésienne. Elle est particulièrement utile lorsque vous souhaitez incorporer des croyances antérieures et mettre à jour ces croyances avec des données observées.
#
#     Mise en œuvre :
#         Implique la définition d'une grille de valeurs de paramètres et le calcul de la vraisemblance des données observées à chaque point de cette grille.
#         En multipliant par la probabilité a priori et en normalisant, on obtient la distribution a posteriori.
#         Cela peut être fait pour chaque condition séparément ou pour toutes les conditions ensemble, bien que cela soit plus intensif en termes de calcul.
#
#     Prédictions :
#         Fournit une distribution de valeurs possibles de pcs/m, offrant une idée de la plage et de l'incertitude des prédictions.
#         Particulièrement utile lorsque la prise de décision nécessite de comprendre l'incertitude ou la variabilité des prédictions.

# %%
# the changes in G27 in relation to the different land use variables.
operations =  {'échantillon':'nunique', 'pcs_m':'median'}
def make_categorical_matrix(data: pd.DataFrame = None, feature_columns: list = None, operations: dict = operations):
    
    nd = data.groupby(feature_columns, as_index=False).agg(operations)
    #nd.rename(columns={'frequentation':'fréquentation'}, inplace=True)
    
    return nd
def name_the_new_distance(x, less='< 500 m', more = '>= 500 m'):
    if x == 1:
        return less
    else:
        return more

t_and_f = env_plastock.loc[:, ['loc_date', 'slug','date','code', 'pcs_m', 'frequentation', 'situation', 'distance', 'substrat']].copy()

# creation of composite variables
# the substrat and distance features are being combined
# the two lowest and the two highest of each group are being combined
# substrat is a matter of combining different granularities. They are being grouped as
# sand and gravel.
# distance is now grouped by locations either less than or equal to 500 meters
t_and_f.loc[t_and_f.substrat <= 2, 'substrat'] = 1
t_and_f.loc[t_and_f.substrat > 2, 'substrat'] = 2
t_and_f.loc[t_and_f.distance <= 2, 'distance'] = 1
t_and_f.loc[t_and_f.distance > 2, 'distance'] = 2

f_combi = t_and_f.copy()

f_combi.rename(columns={'frequentation':'fréquentation', 'loc_date': 'échantillon'}, inplace=True)

mask = (f_combi.code == 'G27')
f_comb = f_combi[mask].copy()
f_comb['distance'] = f_comb['distance'].apply(lambda x: name_the_new_distance(x))
f_comb['fréquentation'] = f_comb['fréquentation'].apply(lambda x: name_frequentation[x])
f_comb['situation'] = f_comb['situation'].apply(lambda x: name_situation[x])
f_comb['substrat'] = f_comb['substrat'].apply(lambda x: name_the_new_distance(x, less='Sable', more='Graviers'))

# f_freq = make_categorical_matrix(data=f_comb, feature_columns=['fréquentation', 'distance'])

# f_sit = make_categorical_matrix(data=f_comb, feature_columns =['situation', 'distance'])
f_freq_sub = make_categorical_matrix(data=f_comb, feature_columns=['fréquentation', 'substrat'])
f_freq_sit = make_categorical_matrix(data=f_comb, feature_columns=['fréquentation', 'situation'])

hue_order = ['Faible', 'Moyenne', 'Elevée']

# %%
fig, ax = plt.subplots(1, 2)
operations = {'échantillon':'nunique'}
feature_columns = ['fréquentation']
data = make_categorical_matrix(f_comb, feature_columns=feature_columns, operations=operations)
sns.barplot(data=data, x='fréquentation', y='échantillon', color='grey', order=hue_order, ax=ax[0], label='fréquentation', alpha=0.4, zorder=1)
sns.barplot(data=f_freq_sit, x='fréquentation', y='échantillon', hue='situation',   edgecolor='white', linewidth=2, palette='tab20', ax=ax[0], order=hue_order, alpha=0.5, zorder=2)

sns.ecdfplot(data=f_comb, x='pcs_m', ax=ax[1], hue='fréquentation', palette='tab20', hue_order=hue_order)
ax[1].set_xlim(-.2, 1)
plt.show()

# %%
fig, ax = plt.subplots(1, 2)
sns.barplot(data=data, x='fréquentation', y='échantillon', color='grey', order=hue_order, ax=ax[0], label='fréquentation', alpha=0.4, zorder=1)
sns.barplot(data=f_freq_sub, x='fréquentation', y='échantillon', hue='substrat',   hue_order=["Sable", "Graviers"], edgecolor='white', linewidth=2, palette='tab20', ax=ax[0], order=hue_order, alpha=0.5, zorder=2)

sns.ecdfplot(data=f_comb, x='pcs_m', ax=ax[1], hue='fréquentation', palette='tab20', hue_order=hue_order)
ax[1].set_xlim(-.2, 1)
plt.show()

# %%
no_combined = env_plastock.loc[:, ['loc_date', 'slug','date','code', 'pcs_m', 'frequentation', 'situation', 'distance', 'substrat']].copy()



no_combined.rename(columns={'frequentation':'fréquentation', 'loc_date': 'échantillon'}, inplace=True)
operations =  {'échantillon':'nunique', 'pcs_m':'median'}
mask = (no_combined.code == 'G27')
no_c = no_combined[mask].copy()
no_c['distance'] = no_c['distance'].apply(lambda x: name_distance[x])
no_c['fréquentation'] = no_c['fréquentation'].apply(lambda x: name_frequentation[x])
no_c['situation'] = no_c['situation'].apply(lambda x: name_situation[x])
no_c['substrat'] = no_c['substrat'].apply(lambda x: name_substrate[x])

no_c_sub = make_categorical_matrix(data=no_c, feature_columns=['fréquentation', 'substrat'])
no_c_sit = make_categorical_matrix(data=no_c, feature_columns=['fréquentation', 'situation'])

# %%
fig, ax = plt.subplots(1, 2)
operations = {'échantillon':'nunique'}
feature_columns = ['fréquentation']
data = make_categorical_matrix(no_c, feature_columns=feature_columns, operations=operations)
sns.barplot(data=data, x='fréquentation', y='échantillon', color='grey', order=hue_order, ax=ax[0], label='fréquentation', alpha=0.4, zorder=1)
sns.barplot(data=no_c_sit, x='fréquentation', y='échantillon', hue='situation',   edgecolor='white', linewidth=2, palette='tab20', ax=ax[0], order=hue_order, alpha=0.5, zorder=2)

sns.ecdfplot(data=no_c, x='pcs_m', ax=ax[1], hue='fréquentation', palette='tab20', hue_order=hue_order)
ax[1].set_xlim(-.2, 1)
plt.show()

# %%
fig, ax = plt.subplots(1, 2)
operations = {'échantillon':'nunique'}
feature_columns = ['fréquentation']
data = make_categorical_matrix(no_c, feature_columns=feature_columns, operations=operations)
sns.barplot(data=data, x='fréquentation', y='échantillon', color='grey', order=hue_order, ax=ax[0], label='fréquentation', alpha=0.4, zorder=1)
sns.barplot(data=no_c_sub, x='fréquentation', y='échantillon', hue='substrat',   edgecolor='white', linewidth=2, palette='tab20', ax=ax[0], order=hue_order, alpha=0.5, zorder=2)

sns.ecdfplot(data=no_c, x='pcs_m', ax=ax[1], hue='fréquentation', palette='tab20', hue_order=hue_order)
ax[1].set_xlim(-.2, 1)
plt.show()

# %% [markdown]
# ## Perspectives 2024.

# %% [markdown]
# ## Inventaire Plastock.

# %%
t = rc.translate_for_display(tiii.inventory, amap=language_maps['fr'], lan='fr')
t['objet'] = t.code.apply(lambda x: codes.loc[x, 'fr'])
t = t[[t.columns[0], t.columns[-1], *t.columns[1:-1]]]
t.set_index(['code', 'objet'], inplace=True)
t.index.name = None
t.style.set_table_styles(conf_.table_css_styles).format(**conf_.format_kwargs)
# Out:
# <style type="text/css">
# #T_5b78a tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_5b78a tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_5b78a tr {
#   font-size: 10px;
# }
# #T_5b78a th {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
#   width: auto;
# }
# #T_5b78a td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_5b78a caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# </style>
# <table id="T_5b78a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b78a_level0_col0" class="col_heading level0 col0" >quantité</th>
#       <th id="T_5b78a_level0_col1" class="col_heading level0 col1" >% du total</th>
#       <th id="T_5b78a_level0_col2" class="col_heading level0 col2" >pcs/m</th>
#       <th id="T_5b78a_level0_col3" class="col_heading level0 col3" >taux d'échec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >code</th>
#       <th class="index_name level1" >objet</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b78a_level0_row0" class="row_heading level0 row0" >Gfrags</th>
#       <th id="T_5b78a_level1_row0" class="row_heading level1 row0" >Fragments de plastique: G80, G79, G78, G75</th>
#       <td id="T_5b78a_row0_col0" class="data row0 col0" >11'221</td>
#       <td id="T_5b78a_row0_col1" class="data row0 col1" >0,41</td>
#       <td id="T_5b78a_row0_col2" class="data row0 col2" >0,72</td>
#       <td id="T_5b78a_row0_col3" class="data row0 col3" >0,97</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row1" class="row_heading level0 row1" >G27</th>
#       <th id="T_5b78a_level1_row1" class="row_heading level1 row1" >Mégots et filtres à cigarettes</th>
#       <td id="T_5b78a_row1_col0" class="data row1 col0" >3'089</td>
#       <td id="T_5b78a_row1_col1" class="data row1 col1" >0,11</td>
#       <td id="T_5b78a_row1_col2" class="data row1 col2" >0,15</td>
#       <td id="T_5b78a_row1_col3" class="data row1 col3" >0,79</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row2" class="row_heading level0 row2" >G30</th>
#       <th id="T_5b78a_level1_row2" class="row_heading level1 row2" >Emballages de bonbons, de snacks</th>
#       <td id="T_5b78a_row2_col0" class="data row2 col0" >2'080</td>
#       <td id="T_5b78a_row2_col1" class="data row2 col1" >0,08</td>
#       <td id="T_5b78a_row2_col2" class="data row2 col2" >0,15</td>
#       <td id="T_5b78a_row2_col3" class="data row2 col3" >0,74</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row3" class="row_heading level0 row3" >G106</th>
#       <th id="T_5b78a_level1_row3" class="row_heading level1 row3" >Fragments de plastique angulaires <5mm</th>
#       <td id="T_5b78a_row3_col0" class="data row3 col0" >1'926</td>
#       <td id="T_5b78a_row3_col1" class="data row3 col1" >0,07</td>
#       <td id="T_5b78a_row3_col2" class="data row3 col2" >0,00</td>
#       <td id="T_5b78a_row3_col3" class="data row3 col3" >0,41</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row4" class="row_heading level0 row4" >G112</th>
#       <th id="T_5b78a_level1_row4" class="row_heading level1 row4" >Pellets industriels (GPI)</th>
#       <td id="T_5b78a_row4_col0" class="data row4 col0" >1'526</td>
#       <td id="T_5b78a_row4_col1" class="data row4 col1" >0,06</td>
#       <td id="T_5b78a_row4_col2" class="data row4 col2" >0,00</td>
#       <td id="T_5b78a_row4_col3" class="data row4 col3" >0,36</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row5" class="row_heading level0 row5" >Gfoams</th>
#       <th id="T_5b78a_level1_row5" class="row_heading level1 row5" >Fragments de polystyrène expansé: G76, G81, G82, G83</th>
#       <td id="T_5b78a_row5_col0" class="data row5 col0" >1'399</td>
#       <td id="T_5b78a_row5_col1" class="data row5 col1" >0,05</td>
#       <td id="T_5b78a_row5_col2" class="data row5 col2" >0,07</td>
#       <td id="T_5b78a_row5_col3" class="data row5 col3" >0,72</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row6" class="row_heading level0 row6" >Gcaps</th>
#       <th id="T_5b78a_level1_row6" class="row_heading level1 row6" >Couvercles en plastique bouteille:  G21, G22, G23, G24</th>
#       <td id="T_5b78a_row6_col0" class="data row6 col0" >1'070</td>
#       <td id="T_5b78a_row6_col1" class="data row6 col1" >0,04</td>
#       <td id="T_5b78a_row6_col2" class="data row6 col2" >0,04</td>
#       <td id="T_5b78a_row6_col3" class="data row6 col3" >0,65</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row7" class="row_heading level0 row7" >G95</th>
#       <th id="T_5b78a_level1_row7" class="row_heading level1 row7" >Coton-tige</th>
#       <td id="T_5b78a_row7_col0" class="data row7 col0" >1'040</td>
#       <td id="T_5b78a_row7_col1" class="data row7 col1" >0,04</td>
#       <td id="T_5b78a_row7_col2" class="data row7 col2" >0,03</td>
#       <td id="T_5b78a_row7_col3" class="data row7 col3" >0,54</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row8" class="row_heading level0 row8" >G74</th>
#       <th id="T_5b78a_level1_row8" class="row_heading level1 row8" >Mousse de plastique pour l'isolation thermique</th>
#       <td id="T_5b78a_row8_col0" class="data row8 col0" >406</td>
#       <td id="T_5b78a_row8_col1" class="data row8 col1" >0,01</td>
#       <td id="T_5b78a_row8_col2" class="data row8 col2" >0,00</td>
#       <td id="T_5b78a_row8_col3" class="data row8 col3" >0,38</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row9" class="row_heading level0 row9" >G89</th>
#       <th id="T_5b78a_level1_row9" class="row_heading level1 row9" >Déchets de construction en plastique</th>
#       <td id="T_5b78a_row9_col0" class="data row9 col0" >380</td>
#       <td id="T_5b78a_row9_col1" class="data row9 col1" >0,01</td>
#       <td id="T_5b78a_row9_col2" class="data row9 col2" >0,00</td>
#       <td id="T_5b78a_row9_col3" class="data row9 col3" >0,24</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row10" class="row_heading level0 row10" >G31</th>
#       <th id="T_5b78a_level1_row10" class="row_heading level1 row10" >Bâtonnets de sucette</th>
#       <td id="T_5b78a_row10_col0" class="data row10 col0" >379</td>
#       <td id="T_5b78a_row10_col1" class="data row10 col1" >0,01</td>
#       <td id="T_5b78a_row10_col2" class="data row10 col2" >0,02</td>
#       <td id="T_5b78a_row10_col3" class="data row10 col3" >0,54</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row11" class="row_heading level0 row11" >G103</th>
#       <th id="T_5b78a_level1_row11" class="row_heading level1 row11" >Fragments de plastique arrondis <5mm</th>
#       <td id="T_5b78a_row11_col0" class="data row11 col0" >375</td>
#       <td id="T_5b78a_row11_col1" class="data row11 col1" >0,01</td>
#       <td id="T_5b78a_row11_col2" class="data row11 col2" >0,00</td>
#       <td id="T_5b78a_row11_col3" class="data row11 col3" >0,26</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row12" class="row_heading level0 row12" >G117</th>
#       <th id="T_5b78a_level1_row12" class="row_heading level1 row12" >Polystyrène < 5mm</th>
#       <td id="T_5b78a_row12_col0" class="data row12 col0" >311</td>
#       <td id="T_5b78a_row12_col1" class="data row12 col1" >0,01</td>
#       <td id="T_5b78a_row12_col2" class="data row12 col2" >0,00</td>
#       <td id="T_5b78a_row12_col3" class="data row12 col3" >0,34</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row13" class="row_heading level0 row13" >G70</th>
#       <th id="T_5b78a_level1_row13" class="row_heading level1 row13" >Cartouches de fusil de chasse</th>
#       <td id="T_5b78a_row13_col0" class="data row13 col0" >199</td>
#       <td id="T_5b78a_row13_col1" class="data row13 col1" >0,01</td>
#       <td id="T_5b78a_row13_col2" class="data row13 col2" >0,00</td>
#       <td id="T_5b78a_row13_col3" class="data row13 col3" >0,39</td>
#     </tr>
#     <tr>
#       <th id="T_5b78a_level0_row14" class="row_heading level0 row14" >G114</th>
#       <th id="T_5b78a_level1_row14" class="row_heading lev

# %%
# %watermark --iversions -b -r
# Out:
# Git repo: https://github.com/hammerdirt-analyst/plastock.git
#
# Git branch: dec4
#
# matplotlib: 3.7.1
# seaborn   : 0.12.2
# numpy     : 1.24.2
# pandas    : 2.0.0
