# %%
# %load_ext watermark
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from myst_nb import glue
from IPython.display import Markdown as md

from plastockconf import name_zones, name_particles, name_frequentation, name_situation
from plastockconf import particle_groups, name_substrate, name_distance, table_css_styles

from plastock import attribute_summary, attribute_summary_test, attribute_summary_grid, add_table_to_page

a_property =  {'color' : 'red'}
format_kwargs = dict(precision=2, thousands="'", decimal=",")
glue('blank_caption', " ", display=False)

section = 'A'
page = 2

# thes samples were not completed
drop_these = ['VD_Cul_2', 'VD_Vid_13', 'VD_Vid_8', 'VS_Bou_12']


work_data = pd.read_csv("data/end_pipe/long_form_micro.csv")
work_data = work_data[~work_data["echantillon"].isin(drop_these)].copy()
work_data.rename(columns={'echantillon':'échantillon', 'frequentation':'fréquentation'}, inplace=True)
beach_data = pd.read_csv("data/end_pipe/asl_beaches.csv")

# %% [markdown]
# # Microplastiques plage et attribut
#
# Les attributs sont les caractéristiques du lieu d'étude qui changent d'un lieu à l'autre. La manière dont le nombre de microplastiques observés évolue en fonction des attributs est l'une des préoccupations de cette étude.

# %%
table_no = 1
figure_no = 1

caption = 'Les données d\'analyse. Tous les tableaux et figures sont construits à partir de cet ensemble de données.'
rule = 'Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.'

t_0 = work_data.head().style.set_table_styles(table_css_styles)
table_0 = add_table_to_page(t_0, table_no, caption, section, page, rule, format_index='columns')
glue('tablea21', table_0, display=True)
# Out:
# <style type="text/css">
# #T_2ab99 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_2ab99 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_2ab99 tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_2ab99 th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_2ab99 td {
#   padding: 4px;
#   text-align: center;
# }
# #T_2ab99 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# </style>
# <table id="T_2ab99">
#   <caption><b>Table A2-1 :</b> Les données d'analyse. Tous les tableaux et figures sont construits à partir de cet ensemble de données. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ab99_level0_col0" class="col_heading level0 col0" >Plage</th>
#       <th id="T_2ab99_level0_col1" class="col_heading level0 col1" >Échantillon</th>
#       <th id="T_2ab99_level0_col2" class="col_heading level0 col2" >Orientation</th>
#       <th id="T_2ab99_level0_col3" class="col_heading level0 col3" >Position</th>
#       <th id="T_2ab99_level0_col4" class="col_heading level0 col4" >Substrat</th>
#       <th id="T_2ab99_level0_col5" class="col_heading level0 col5" >Fréquentation</th>
#       <th id="T_2ab99_level0_col6" class="col_heading level0 col6" >Situation</th>
#       <th id="T_2ab99_level0_col7" class="col_heading level0 col7" >Distance</th>
#       <th id="T_2ab99_level0_col8" class="col_heading level0 col8" >Objet</th>
#       <th id="T_2ab99_level0_col9" class="col_heading level0 col9" >Compte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ab99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ab99_row0_col0" class="data row0 col0" >Amphion</td>
#       <td id="T_2ab99_row0_col1" class="data row0 col1" >74_Amp_1</td>
#       <td id="T_2ab99_row0_col2" class="data row0 col2" >NE</td>
#       <td id="T_2ab99_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_2ab99_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_2ab99_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_2ab99_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_2ab99_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_2ab99_row0_col8" class="data row0 col8" >fibres</td>
#       <td id="T_2ab99_row0_col9" class="data row0 col9" >97</td>
#     </tr>
#     <tr>
#       <th id="T_2ab99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ab99_row1_col0" class="data row1 col0" >Amphion</td>
#       <td id="T_2ab99_row1_col1" class="data row1 col1" >74_Amp_10</td>
#       <td id="T_2ab99_row1_col2" class="data row1 col2" >NNE</td>
#       <td id="T_2ab99_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_2ab99_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_2ab99_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_2ab99_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_2ab99_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_2ab99_row1_col8" class="data row1 col8" >fibres</td>
#       <td id="T_2ab99_row1_col9" class="data row1 col9" >140</td>
#     </tr>
#     <tr>
#       <th id="T_2ab99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ab99_row2_col0" class="data row2 col0" >Amphion</td>
#       <td id="T_2ab99_row2_col1" class="data row2 col1" >74_Amp_2</td>
#       <td id="T_2ab99_row2_col2" class="data row2 col2" >NNE</td>
#       <td id="T_2ab99_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_2ab99_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_2ab99_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_2ab99_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_2ab99_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_2ab99_row2_col8" class="data row2 col8" >fibres</td>
#       <td id="T_2ab99_row2_col9" class="data row2 col9" >121</td>
#     </tr>
#     <tr>
#       <th id="T_2ab99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ab99_row3_col0" class="data row3 col0" >Amphion</td>
#       <td id="T_2ab99_row3_col1" class="data row3 col1" >74_Amp_3</td>
#       <td id="T_2ab99_row3_col2" class="data row3 col2" >NE</td>
#       <td id="T_2ab99_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_2ab99_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_2ab99_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_2ab99_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_2ab99_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_2ab99_row3_col8" class="data row3 col8" >fibres</td>
#       <td id="T_2ab99_row3_col9" class="data row3 col9" >31</td>
#     </tr>
#     <tr>
#       <th id="T_2ab99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ab99_row4_col0" class="data row4 col0" >Amphion</td>
#       <td id="T_2ab99_row4_col1" class="data row4 col1" >74_Amp_4</td>
#       <td id="T_2ab99_row4_col2" class="data row4 col2" >NNE</td>
#       <td id="T_2ab99_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_2ab99_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_2ab99_row4_col5" class="data row4 col5" >3</td>
#       <td id="T_2ab99_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_2ab99_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_2ab99_row4_col8" class="data row4 col8" >fibres</td>
#       <td id="T_2ab99_row4_col9" class="data row4 col9" >179</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Substrat
#
# Le substrat définit la surface de l'emplacement d'échantillonnage.

# %%
column_display = {
    "count":"échantillons",
    "mean": "moyenne",
    "std": "écart type",
    "échantillon":"échantillon"
}

# ananlysis of substrat
voi = "substrat"
vals = "compte"
groupbys = ['échantillon', voi]
labels = name_substrate


substrat_summary = attribute_summary(work_data, vals, voi, columns=column_display, labels=name_substrate)

caption = 'Le résumé des résultats du nombre de particules trouvées dans chaque échantillon pour chaque substrat.'
rule = 'Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.'
table_no += 1

table_one = add_table_to_page(substrat_summary, table_no, caption, section, page, rule)
glue('tablea22', table_one, display=True)
# Out:
# <style type="text/css">
# #T_187f5 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_187f5 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_187f5 tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_187f5 th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_187f5 td {
#   padding: 4px;
#   text-align: center;
# }
# #T_187f5 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# #T_187f5_row1_col1, #T_187f5_row2_col5, #T_187f5_row3_col5 {
#   color: red;
# }
# </style>
# <table id="T_187f5">
#   <caption><b>Table A2-2 :</b> Le résumé des résultats du nombre de particules trouvées dans chaque échantillon pour chaque substrat. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_187f5_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_187f5_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_187f5_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_187f5_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_187f5_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_187f5_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_187f5_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_187f5_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_187f5_level0_row0" class="row_heading level0 row0" >Cailloux</th>
#       <td id="T_187f5_row0_col0" class="data row0 col0" >46</td>
#       <td id="T_187f5_row0_col1" class="data row0 col1" >125,20</td>
#       <td id="T_187f5_row0_col2" class="data row0 col2" >107,16</td>
#       <td id="T_187f5_row0_col3" class="data row0 col3" >26</td>
#       <td id="T_187f5_row0_col4" class="data row0 col4" >57,50</td>
#       <td id="T_187f5_row0_col5" class="data row0 col5" >92,50</td>
#       <td id="T_187f5_row0_col6" class="data row0 col6" >155,75</td>
#       <td id="T_187f5_row0_col7" class="data row0 col7" >665</td>
#     </tr>
#     <tr>
#       <th id="T_187f5_level0_row1" class="row_heading level0 row1" >Graviers</th>
#       <td id="T_187f5_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_187f5_row1_col1" class="data row1 col1" >347,57</td>
#       <td id="T_187f5_row1_col2" class="data row1 col2" >630,60</td>
#       <td id="T_187f5_row1_col3" class="data row1 col3" >20</td>
#       <td id="T_187f5_row1_col4" class="data row1 col4" >68,00</td>
#       <td id="T_187f5_row1_col5" class="data row1 col5" >90,50</td>
#       <td id="T_187f5_row1_col6" class="data row1 col6" >245,00</td>
#       <td id="T_187f5_row1_col7" class="data row1 col7" >2'991</td>
#     </tr>
#     <tr>
#       <th id="T_187f5_level0_row2" class="row_heading level0 row2" >Sables fins</th>
#       <td id="T_187f5_row2_col0" class="data row2 col0" >111</td>
#       <td id="T_187f5_row2_col1" class="data row2 col1" >174,28</td>
#       <td id="T_187f5_row2_col2" class="data row2 col2" >154,68</td>
#       <td id="T_187f5_row2_col3" class="data row2 col3" >23</td>
#       <td id="T_187f5_row2_col4" class="data row2 col4" >90,50</td>
#       <td id="T_187f5_row2_col5" class="data row2 col5" >135,00</td>
#       <td id="T_187f5_row2_col6" class="data row2 col6" >203,00</td>
#       <td id="T_187f5_row2_col7" class="data row2 col7" >971</td>
#     </tr>
#     <tr>
#       <th id="T_187f5_level0_row3" class="row_heading level0 row3" >Sables grossiers</th>
#       <td id="T_187f5_row3_col0" class="data row3 col0" >28</td>
#       <td id="T_187f5_row3_col1" class="data row3 col1" >151,89</td>
#       <td id="T_187f5_row3_col2" class="data row3 col2" >136,76</td>
#       <td id="T_187f5_row3_col3" class="data row3 col3" >19</td>
#       <td id="T_187f5_row3_col4" class="data row3 col4" >56,50</td>
#       <td id="T_187f5_row3_col5" class="data row3 col5" >122,00</td>
#       <td id="T_187f5_row3_col6" class="data row3 col6" >174,50</td>
#       <td id="T_187f5_row3_col7" class="data row3 col7" >550</td>
#     </tr>
#   </tbody>
# </table>

# %%
attribute_summary_grid(work_data, vals, voi, 'fig-A21', labels=labels)

# %% [markdown]
# ```{glue:figure} fig-A21
# ---
# name: fig-A21
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# __Les plages substrat = cailloux:__

# %%
md(', '.join(work_data[work_data.substrat.isin([3])].Plage.unique()))
# Out:
# Hermance, Port Choiseul, Versoix, Cully, Pichette

# %% [markdown]
# __Les plages substrat = sables fins:__

# %%
md(', '.join(work_data[work_data.substrat.isin([1])].Plage.unique()))
# Out:
# Excenevex, Baby Plage, Grangettes, Préverenges, Rolle, Vidy, Bouveret

# %% [markdown]
# __Les plages substrat = sables grossiers:__

# %%
md(', '.join(work_data[work_data.substrat.isin([2])].Plage.unique()))
# Out:
# Meillerie, Tougues, Savonnière, Clarens, Crans, Gland, Lutry, Tolochenaz

# %% [markdown]
# ## Fréquentation

# %%
# ananlysis of frequentation
voi = "fréquentation"
vals = "compte"
groupbys = ['echantillon', voi]
labels = name_frequentation

freq = attribute_summary(work_data, vals, voi, columns=column_display, labels=labels)

caption = 'Le résumé des résultats du nombre de particules trouvées pour chaque niveau de fréquentation.'
table_no += 1

table_two = add_table_to_page(freq, table_no, caption, section, page, rule)
glue('tablea23', table_two, display=True)
# Out:
# <style type="text/css">
# #T_71558 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_71558 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_71558 tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_71558 th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_71558 td {
#   padding: 4px;
#   text-align: center;
# }
# #T_71558 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# #T_71558_row0_col5, #T_71558_row2_col1 {
#   color: red;
# }
# </style>
# <table id="T_71558">
#   <caption><b>Table A2-3 :</b> Le résumé des résultats du nombre de particules trouvées pour chaque niveau de fréquentation. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71558_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_71558_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_71558_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_71558_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_71558_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_71558_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_71558_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_71558_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71558_level0_row0" class="row_heading level0 row0" >Elevée</th>
#       <td id="T_71558_row0_col0" class="data row0 col0" >169</td>
#       <td id="T_71558_row0_col1" class="data row0 col1" >169,18</td>
#       <td id="T_71558_row0_col2" class="data row0 col2" >189,65</td>
#       <td id="T_71558_row0_col3" class="data row0 col3" >23</td>
#       <td id="T_71558_row0_col4" class="data row0 col4" >74,00</td>
#       <td id="T_71558_row0_col5" class="data row0 col5" >126,00</td>
#       <td id="T_71558_row0_col6" class="data row0 col6" >194,00</td>
#       <td id="T_71558_row0_col7" class="data row0 col7" >1'492</td>
#     </tr>
#     <tr>
#       <th id="T_71558_level0_row1" class="row_heading level0 row1" >Faible</th>
#       <td id="T_71558_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_71558_row1_col1" class="data row1 col1" >83,86</td>
#       <td id="T_71558_row1_col2" class="data row1 col2" >54,91</td>
#       <td id="T_71558_row1_col3" class="data row1 col3" >19</td>
#       <td id="T_71558_row1_col4" class="data row1 col4" >56,00</td>
#       <td id="T_71558_row1_col5" class="data row1 col5" >57,00</td>
#       <td id="T_71558_row1_col6" class="data row1 col6" >108,50</td>
#       <td id="T_71558_row1_col7" class="data row1 col7" >182</td>
#     </tr>
#     <tr>
#       <th id="T_71558_level0_row2" class="row_heading level0 row2" >Moyenne</th>
#       <td id="T_71558_row2_col0" class="data row2 col0" >37</td>
#       <td id="T_71558_row2_col1" class="data row2 col1" >267,84</td>
#       <td id="T_71558_row2_col2" class="data row2 col2" >497,49</td>
#       <td id="T_71558_row2_col3" class="data row2 col3" >20</td>
#       <td id="T_71558_row2_col4" class="data row2 col4" >72,00</td>
#       <td id="T_71558_row2_col5" class="data row2 col5" >117,00</td>
#       <td id="T_71558_row2_col6" class="data row2 col6" >209,00</td>
#       <td id="T_71558_row2_col7" class="data row2 col7" >2'991</td>
#     </tr>
#   </tbody>
# </table>

# %%
attribute_summary_grid(work_data, vals, voi, 'fig-A22', labels=labels)

# %% [markdown]
# ```{glue:figure} fig-A22
# ---
# name: fig-A22
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# __Les plages fréquentation = moyenne:__

# %%
md(', '.join(work_data[work_data['fréquentation'].isin([2])].Plage.unique()))
# Out:
# Anthy, Lugrin, Saint-Disdille, Aubonne, Gland, Grangettes, Pichette

# %% [markdown]
# __Les plages fréquentation = élevée:__

# %%
md(', '.join(work_data[work_data['fréquentation'].isin([3])].Plage.unique()))
# Out:
# Amphion, Excenevex, Tougues, Baby Plage, Hermance, Port Choiseul, Savonnière, Versoix, Clarens, Lutry, Préverenges, Rolle, Vidy, Bouveret

# %% [markdown]
# ## Situation

# %%
# ananlysis of situation
voi = "situation"
vals = "compte"
groupby = ['echantillon', voi]
labels = name_situation

sit = attribute_summary(work_data, vals, voi, columns=column_display, labels=labels)

caption = 'Le résumé des résultats du nombre de particules trouvées pour chaque situation: urbain, campagne.'
table_no += 1

table_three = add_table_to_page(sit, table_no, caption, section, page, rule)
glue('tablea24', table_three, display=True)
# Out:
# <style type="text/css">
# #T_6be23 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6be23 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6be23 tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_6be23 th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_6be23 td {
#   padding: 4px;
#   text-align: center;
# }
# #T_6be23 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# #T_6be23_row0_col1, #T_6be23_row0_col5 {
#   color: red;
# }
# </style>
# <table id="T_6be23">
#   <caption><b>Table A2-4 :</b> Le résumé des résultats du nombre de particules trouvées pour chaque situation: urbain, campagne. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6be23_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_6be23_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_6be23_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_6be23_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_6be23_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_6be23_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_6be23_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_6be23_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6be23_level0_row0" class="row_heading level0 row0" >Campagne</th>
#       <td id="T_6be23_row0_col0" class="data row0 col0" >138</td>
#       <td id="T_6be23_row0_col1" class="data row0 col1" >189,12</td>
#       <td id="T_6be23_row0_col2" class="data row0 col2" >287,68</td>
#       <td id="T_6be23_row0_col3" class="data row0 col3" >19</td>
#       <td id="T_6be23_row0_col4" class="data row0 col4" >78,00</td>
#       <td id="T_6be23_row0_col5" class="data row0 col5" >128,00</td>
#       <td id="T_6be23_row0_col6" class="data row0 col6" >200,00</td>
#       <td id="T_6be23_row0_col7" class="data row0 col7" >2'991</td>
#     </tr>
#     <tr>
#       <th id="T_6be23_level0_row1" class="row_heading level0 row1" >Urbain</th>
#       <td id="T_6be23_row1_col0" class="data row1 col0" >75</td>
#       <td id="T_6be23_row1_col1" class="data row1 col1" >173,21</td>
#       <td id="T_6be23_row1_col2" class="data row1 col2" >232,13</td>
#       <td id="T_6be23_row1_col3" class="data row1 col3" >23</td>
#       <td id="T_6be23_row1_col4" class="data row1 col4" >62,50</td>
#       <td id="T_6be23_row1_col5" class="data row1 col5" >105,00</td>
#       <td id="T_6be23_row1_col6" class="data row1 col6" >193,00</td>
#       <td id="T_6be23_row1_col7" class="data row1 col7" >1'492</td>
#     </tr>
#   </tbody>
# </table>

# %%
attribute_summary_grid(work_data, vals, voi, 'fig-A23', labels=labels)

# %% [markdown]
# ```{glue:figure} fig-A23
# ---
# name: fig-A23
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# __Les plages situation = campagne:__

# %%
md(', '.join(work_data[work_data.situation.isin([1])].Plage.unique()))
# Out:
# Amphion, Anthy, Excenevex, Lugrin, Saint-Disdille, Tougues, Savonnière, Versoix, Aubonne, Crans, Cully, Gland, Grangettes, Pichette, Préverenges, Tolochenaz, Bouveret

# %% [markdown]
# ## Distance

# %%
# ananlysis of distance
voi = "distance"
vals = "compte"
groupby = ['echantillon', voi]
labels = name_distance

dist = attribute_summary(work_data, vals, voi, columns=column_display, labels=labels)

caption = 'Le résumé des résultats du nombre de particules trouvées selon le distance du parking.'
table_no += 1

table_four = add_table_to_page(dist, table_no, caption, section, page, rule)
glue('tablea25', table_four, display=True)
# Out:
# <style type="text/css">
# #T_a37dc tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_a37dc tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_a37dc tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_a37dc th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_a37dc td {
#   padding: 4px;
#   text-align: center;
# }
# #T_a37dc caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# #T_a37dc_row0_col1, #T_a37dc_row0_col5, #T_a37dc_row2_col5 {
#   color: red;
# }
# </style>
# <table id="T_a37dc">
#   <caption><b>Table A2-5 :</b> Le résumé des résultats du nombre de particules trouvées selon le distance du parking. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a37dc_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_a37dc_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_a37dc_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_a37dc_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_a37dc_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_a37dc_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_a37dc_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_a37dc_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a37dc_level0_row0" class="row_heading level0 row0" >100 - 500 m</th>
#       <td id="T_a37dc_row0_col0" class="data row0 col0" >107</td>
#       <td id="T_a37dc_row0_col1" class="data row0 col1" >200,28</td>
#       <td id="T_a37dc_row0_col2" class="data row0 col2" >241,14</td>
#       <td id="T_a37dc_row0_col3" class="data row0 col3" >23</td>
#       <td id="T_a37dc_row0_col4" class="data row0 col4" >72,50</td>
#       <td id="T_a37dc_row0_col5" class="data row0 col5" >128,00</td>
#       <td id="T_a37dc_row0_col6" class="data row0 col6" >212,00</td>
#       <td id="T_a37dc_row0_col7" class="data row0 col7" >1'492</td>
#     </tr>
#     <tr>
#       <th id="T_a37dc_level0_row1" class="row_heading level0 row1" >500 - 1000 m</th>
#       <td id="T_a37dc_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a37dc_row1_col1" class="data row1 col1" >38,00</td>
#       <td id="T_a37dc_row1_col2" class="data row1 col2" >26,87</td>
#       <td id="T_a37dc_row1_col3" class="data row1 col3" >19</td>
#       <td id="T_a37dc_row1_col4" class="data row1 col4" >28,50</td>
#       <td id="T_a37dc_row1_col5" class="data row1 col5" >38,00</td>
#       <td id="T_a37dc_row1_col6" class="data row1 col6" >47,50</td>
#       <td id="T_a37dc_row1_col7" class="data row1 col7" >57</td>
#     </tr>
#     <tr>
#       <th id="T_a37dc_level0_row2" class="row_heading level0 row2" >< 100 m</th>
#       <td id="T_a37dc_row2_col0" class="data row2 col0" >92</td>
#       <td id="T_a37dc_row2_col1" class="data row2 col1" >178,73</td>
#       <td id="T_a37dc_row2_col2" class="data row2 col2" >314,01</td>
#       <td id="T_a37dc_row2_col3" class="data row2 col3" >20</td>
#       <td id="T_a37dc_row2_col4" class="data row2 col4" >80,25</td>
#       <td id="T_a37dc_row2_col5" class="data row2 col5" >126,00</td>
#       <td id="T_a37dc_row2_col6" class="data row2 col6" >192,50</td>
#       <td id="T_a37dc_row2_col7" class="data row2 col7" >2'991</td>
#     </tr>
#     <tr>
#       <th id="T_a37dc_level0_row3" class="row_heading level0 row3" >> 1000 m</th>
#       <td id="T_a37dc_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_a37dc_row3_col1" class="data row3 col1" >95,00</td>
#       <td id="T_a37dc_row3_col2" class="data row3 col2" >53,75</td>
#       <td id="T_a37dc_row3_col3" class="data row3 col3" >44</td>
#       <td id="T_a37dc_row3_col4" class="data row3 col4" >56,50</td>
#       <td id="T_a37dc_row3_col5" class="data row3 col5" >77,00</td>
#       <td id="T_a37dc_row3_col6" class="data row3 col6" >105,75</td>
#       <td id="T_a37dc_row3_col7" class="data row3 col7" >200</td>
#     </tr>
#   </tbody>
# </table>

# %%
attribute_summary_grid(work_data, vals, voi, 'fig-A24', labels=labels)

# %% [markdown]
# ```{glue:figure} fig-A24
# ---
# name: fig-A24
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# __Les plages distance = 100 - 500 m:__

# %%
md(', '.join(work_data[work_data.distance.isin([2])].Plage.unique()))
# Out:
# Lugrin, Tougues, Baby Plage, Hermance, Port Choiseul, Versoix, Grangettes, Lutry, Préverenges, Vidy, Bouveret

# %% [markdown]
# __Les plages distance = < 100 m:__

# %%
md(', '.join(work_data[work_data.distance.isin([1])].Plage.unique()))
# Out:
# Amphion, Anthy, Excenevex, Saint-Disdille, Savonnière, Clarens, Cully, Gland, Pichette, Rolle

# %% [markdown]
# ## Orientation

# %%
# ananlysis of orientation
voi = "orientation"
vals = "compte"
groupby = ['echantillon', voi]

voi = "orientation"
vals = "compte"
data_summary = attribute_summary_test(work_data, voi=voi, vals=vals)
data_summary[['count', 'max', 'min']] = data_summary[['count', 'max', 'min']].astype('int')
data_summary.rename(columns=column_display, inplace=True)

select_values = data_summary["moyenne"] > 180
test_one = data_summary.loc[select_values].index

select_values = data_summary["50%"] > 121
test_two = data_summary.loc[select_values].index

d_sum = data_summary.style.set_table_styles(table_css_styles).format(precision=2)
d_sum = d_sum.set_properties(subset = pd.IndexSlice[test_one,["moyenne"]], **a_property)

oriented = d_sum.set_properties(subset = pd.IndexSlice[test_two,["50%"]], **a_property)

caption = 'Le résumé des résultats du nombre de particules trouvées selon l\'orientation de la plage.'
table_no += 1

table_five = add_table_to_page(oriented, table_no, caption, section, page, rule, format_index='columns')
glue('tablea26', table_five, display=True)
# Out:
# <style type="text/css">
# #T_fffed tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_fffed tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_fffed tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_fffed th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_fffed td {
#   padding: 4px;
#   text-align: center;
# }
# #T_fffed caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# #T_fffed_row1_col5, #T_fffed_row3_col5, #T_fffed_row4_col1, #T_fffed_row5_col5, #T_fffed_row7_col1, #T_fffed_row7_col5, #T_fffed_row8_col1, #T_fffed_row11_col1, #T_fffed_row11_col5, #T_fffed_row13_col1, #T_fffed_row13_col5 {
#   color: red;
# }
# </style>
# <table id="T_fffed">
#   <caption><b>Table A2-6 :</b> Le résumé des résultats du nombre de particules trouvées selon l'orientation de la plage. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fffed_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_fffed_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_fffed_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_fffed_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_fffed_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_fffed_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_fffed_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_fffed_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fffed_level0_row0" class="row_heading level0 row0" >E</th>
#       <td id="T_fffed_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_fffed_row0_col1" class="data row0 col1" >40,00</td>
#       <td id="T_fffed_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_fffed_row0_col3" class="data row0 col3" >40</td>
#       <td id="T_fffed_row0_col4" class="data row0 col4" >40,00</td>
#       <td id="T_fffed_row0_col5" class="data row0 col5" >40,00</td>
#       <td id="T_fffed_row0_col6" class="data row0 col6" >40,00</td>
#       <td id="T_fffed_row0_col7" class="data row0 col7" >40</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row1" class="row_heading level0 row1" >ENE</th>
#       <td id="T_fffed_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_fffed_row1_col1" class="data row1 col1" >135,50</td>
#       <td id="T_fffed_row1_col2" class="data row1 col2" >65,76</td>
#       <td id="T_fffed_row1_col3" class="data row1 col3" >89</td>
#       <td id="T_fffed_row1_col4" class="data row1 col4" >112,25</td>
#       <td id="T_fffed_row1_col5" class="data row1 col5" >135,50</td>
#       <td id="T_fffed_row1_col6" class="data row1 col6" >158,75</td>
#       <td id="T_fffed_row1_col7" class="data row1 col7" >182</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row2" class="row_heading level0 row2" >ESE</th>
#       <td id="T_fffed_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_fffed_row2_col1" class="data row2 col1" >99,75</td>
#       <td id="T_fffed_row2_col2" class="data row2 col2" >34,93</td>
#       <td id="T_fffed_row2_col3" class="data row2 col3" >62</td>
#       <td id="T_fffed_row2_col4" class="data row2 col4" >83,00</td>
#       <td id="T_fffed_row2_col5" class="data row2 col5" >95,50</td>
#       <td id="T_fffed_row2_col6" class="data row2 col6" >112,25</td>
#       <td id="T_fffed_row2_col7" class="data row2 col7" >146</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row3" class="row_heading level0 row3" >N</th>
#       <td id="T_fffed_row3_col0" class="data row3 col0" >14</td>
#       <td id="T_fffed_row3_col1" class="data row3 col1" >170,00</td>
#       <td id="T_fffed_row3_col2" class="data row3 col2" >158,50</td>
#       <td id="T_fffed_row3_col3" class="data row3 col3" >27</td>
#       <td id="T_fffed_row3_col4" class="data row3 col4" >80,25</td>
#       <td id="T_fffed_row3_col5" class="data row3 col5" >136,50</td>
#       <td id="T_fffed_row3_col6" class="data row3 col6" >203,00</td>
#       <td id="T_fffed_row3_col7" class="data row3 col7" >665</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row4" class="row_heading level0 row4" >NE</th>
#       <td id="T_fffed_row4_col0" class="data row4 col0" >42</td>
#       <td id="T_fffed_row4_col1" class="data row4 col1" >194,24</td>
#       <td id="T_fffed_row4_col2" class="data row4 col2" >290,86</td>
#       <td id="T_fffed_row4_col3" class="data row4 col3" >31</td>
#       <td id="T_fffed_row4_col4" class="data row4 col4" >71,50</td>
#       <td id="T_fffed_row4_col5" class="data row4 col5" >115,00</td>
#       <td id="T_fffed_row4_col6" class="data row4 col6" >182,00</td>
#       <td id="T_fffed_row4_col7" class="data row4 col7" >1'492</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row5" class="row_heading level0 row5" >NNE</th>
#       <td id="T_fffed_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_fffed_row5_col1" class="data row5 col1" >122,67</td>
#       <td id="T_fffed_row5_col2" class="data row5 col2" >70,81</td>
#       <td id="T_fffed_row5_col3" class="data row5 col3" >23</td>
#       <td id="T_fffed_row5_col4" class="data row5 col4" >59,00</td>
#       <td id="T_fffed_row5_col5" class="data row5 col5" >126,00</td>
#       <td id="T_fffed_row5_col6" class="data row5 col6" >182,00</td>
#       <td id="T_fffed_row5_col7" class="data row5 col7" >225</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row6" class="row_heading level0 row6" >NNO</th>
#       <td id="T_fffed_row6_col0" class="data row6 col0" >10</td>
#       <td id="T_fffed_row6_col1" class="data row6 col1" >133,90</td>
#       <td id="T_fffed_row6_col2" class="data row6 col2" >89,98</td>
#       <td id="T_fffed_row6_col3" class="data row6 col3" >38</td>
#       <td id="T_fffed_row6_col4" class="data row6 col4" >71,25</td>
#       <td id="T_fffed_row6_col5" class="data row6 col5" >116,00</td>
#       <td id="T_fffed_row6_col6" class="data row6 col6" >182,75</td>
#       <td id="T_fffed_row6_col7" class="data row6 col7" >334</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row7" class="row_heading level0 row7" >NO</th>
#       <td id="T_fffed_row7_col0" class="data row7 col0" >25</td>
#       <td id="T_fffed_row7_col1" class="data row7 col1" >227,00</td>
#       <td id="T_fffed_row7_col2" class="data row7 col2" >200,16</td>
#       <td id="T_fffed_row7_col3" class="data row7 col3" >25</td>
#       <td id="T_fffed_row7_col4" class="data row7 col4" >99,00</td>
#       <td id="T_fffed_row7_col5" class="data row7 col5" >155,00</td>
#       <td id="T_fffed_row7_col6" class="data row7 col6" >288,00</td>
#       <td id="T_fffed_row7_col7" class="data row7 col7" >697</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row8" class="row_heading level0 row8" >O</th>
#       <td id="T_fffed_row8_col0" class="data row8 col0" >6</td>
#       <td id="T_fffed_row8_col1" class="data row8 col1" >247,83</td>
#       <td id="T_fffed_row8_col2" class="data row8 col2" >363,32</td>
#       <td id="T_fffed_row8_col3" class="data row8 col3" >37</td>
#       <td id="T_fffed_row8_col4" class="data row8 col4" >57,50</td>
#       <td id="T_fffed_row8_col5" class="data row8 col5" >82,00</td>
#       <td id="T_fffed_row8_col6" class="data row8 col6" >219,75</td>
#       <td id="T_fffed_row8_col7" class="data row8 col7" >971</td>
#     </tr>
#     <tr>
#       <th id="T_fffed_level0_row9" class="row_heading level0 row9" >ONO</th>
#       <td id="T_fffed_row9_col0" class="data row9 col0" >6</td>
#       <td id="T_fffed_row9_col1" class="data row9 col1" >120,67</td>
#       <td id="T_fffed_row9_col2" class="data row9 col2" >74,00</td>
#       <td id="T_fffed_row9_col3" class="data row9 col3" >44</td>
#       <td id="T_fffed_row9_col4" class="data row9 col4" >83,25</td>
#       <td id="T_fffed_row9_col5" class="data row9 col5" >98,00</td>
#       <td id="T_fffed_row9_col6" class="data row9 col6" >137,50</td>
#       <td id="T_fffed_row9_col7" class="data row9 c

# %%
# %watermark --iversions -b -r
# Out:
# Git repo: https://github.com/hammerdirt-analyst/plastock.git
#
# Git branch: feb5
#
# matplotlib: 3.8.2
# numpy     : 1.26.3
# seaborn   : 0.13.1
# pandas    : 2.0.3
