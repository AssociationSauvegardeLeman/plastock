# %%
import numpy as np
import pandas as pd
import datetime as dt

from plastockmethods import name_the_zones, name_the_particles, frequentation_name, situation_name
from plastockmethods import particle_groups, name_the_substrate, name_the_distance, table_css_styles

work_data = pd.read_csv("data/end_pipe/long_form_micro.csv")
wide_form = pd.read_csv("data/end_pipe/aggregated_micro_results.csv")
beach_data = pd.read_csv("data/end_pipe/asl_beaches.csv")

# %% [markdown]
# # Résultats par plage
#
# __Résultats agrégés par texture et échantillon__

# %%
caption = "Les données de l'enquête sont regroupées en trois groupes par échantillon. Fibres, fragments rigides, fragments souples."

work_data[work_data.echantillon == "74_Amp_2"].head().style.set_table_styles(table_css_styles).set_caption(caption)
# Out:
# <style type="text/css">
# #T_6e784 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6e784 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6e784 tr {
#   font-size: 14px;
# }
# #T_6e784 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_6e784 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
# }
# </style>
# <table id="T_6e784">
#   <caption>Les données de l'enquête sont regroupées en trois groupes par échantillon. Fibres, fragments rigides, fragments souples.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e784_level0_col0" class="col_heading level0 col0" >Plage</th>
#       <th id="T_6e784_level0_col1" class="col_heading level0 col1" >echantillon</th>
#       <th id="T_6e784_level0_col2" class="col_heading level0 col2" >orientation</th>
#       <th id="T_6e784_level0_col3" class="col_heading level0 col3" >position</th>
#       <th id="T_6e784_level0_col4" class="col_heading level0 col4" >substrat</th>
#       <th id="T_6e784_level0_col5" class="col_heading level0 col5" >frequentation</th>
#       <th id="T_6e784_level0_col6" class="col_heading level0 col6" >situation</th>
#       <th id="T_6e784_level0_col7" class="col_heading level0 col7" >distance</th>
#       <th id="T_6e784_level0_col8" class="col_heading level0 col8" >objet</th>
#       <th id="T_6e784_level0_col9" class="col_heading level0 col9" >compte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e784_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_6e784_row0_col0" class="data row0 col0" >Amphion</td>
#       <td id="T_6e784_row0_col1" class="data row0 col1" >74_Amp_2</td>
#       <td id="T_6e784_row0_col2" class="data row0 col2" >NNE</td>
#       <td id="T_6e784_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_6e784_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_6e784_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_6e784_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_6e784_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_6e784_row0_col8" class="data row0 col8" >fibres</td>
#       <td id="T_6e784_row0_col9" class="data row0 col9" >121</td>
#     </tr>
#     <tr>
#       <th id="T_6e784_level0_row1" class="row_heading level0 row1" >219</th>
#       <td id="T_6e784_row1_col0" class="data row1 col0" >Amphion</td>
#       <td id="T_6e784_row1_col1" class="data row1 col1" >74_Amp_2</td>
#       <td id="T_6e784_row1_col2" class="data row1 col2" >NNE</td>
#       <td id="T_6e784_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_6e784_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_6e784_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_6e784_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_6e784_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_6e784_row1_col8" class="data row1 col8" >fdure</td>
#       <td id="T_6e784_row1_col9" class="data row1 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6e784_level0_row2" class="row_heading level0 row2" >436</th>
#       <td id="T_6e784_row2_col0" class="data row2 col0" >Amphion</td>
#       <td id="T_6e784_row2_col1" class="data row2 col1" >74_Amp_2</td>
#       <td id="T_6e784_row2_col2" class="data row2 col2" >NNE</td>
#       <td id="T_6e784_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_6e784_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_6e784_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_6e784_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_6e784_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_6e784_row2_col8" class="data row2 col8" >souple</td>
#       <td id="T_6e784_row2_col9" class="data row2 col9" >12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Nombre cumulé d'échantillons et décompte par plage

# %%
location_summary = work_data.groupby("Plage", as_index=False).agg({"echantillon": "nunique", "compte":"sum"})
location_summary["poids echantillon"] = location_summary.echantillon/location_summary.echantillon.sum()
location_summary["poids compte"] = location_summary.compte/location_summary.compte.sum()
location_summary.set_index("Plage", inplace=True, drop=True)
df1 = location_summary.copy()
df1.index.name = None
a_property =  {'color' : 'red'}

select_values = df1["poids echantillon"] < df1["poids compte"]
test_one = df1.loc[select_values].index
caption = "Nombre cumulé d'échantillons et décompte par plage. Si le poids du comptage est supérieur au poids des échantillons, la ligne est sur fond jaune."
                        
df1.style.set_table_styles(table_css_styles).set_caption(caption).set_properties(subset = pd.IndexSlice[test_one,["poids echantillon", "poids compte"]], **a_property)
# Out:
# <style type="text/css">
# #T_8815e tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_8815e tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_8815e tr {
#   font-size: 14px;
# }
# #T_8815e th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_8815e caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
# }
# #T_8815e_row10_col2, #T_8815e_row10_col3, #T_8815e_row12_col2, #T_8815e_row12_col3, #T_8815e_row15_col2, #T_8815e_row15_col3, #T_8815e_row16_col2, #T_8815e_row16_col3, #T_8815e_row17_col2, #T_8815e_row17_col3, #T_8815e_row20_col2, #T_8815e_row20_col3 {
#   color: red;
# }
# </style>
# <table id="T_8815e">
#   <caption>Nombre cumulé d'échantillons et décompte par plage. Si le poids du comptage est supérieur au poids des échantillons, la ligne est sur fond jaune.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8815e_level0_col0" class="col_heading level0 col0" >echantillon</th>
#       <th id="T_8815e_level0_col1" class="col_heading level0 col1" >compte</th>
#       <th id="T_8815e_level0_col2" class="col_heading level0 col2" >poids echantillon</th>
#       <th id="T_8815e_level0_col3" class="col_heading level0 col3" >poids compte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8815e_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_8815e_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_8815e_row0_col1" class="data row0 col1" >1250</td>
#       <td id="T_8815e_row0_col2" class="data row0 col2" >0.046083</td>
#       <td id="T_8815e_row0_col3" class="data row0 col3" >0.031978</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_8815e_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_8815e_row1_col1" class="data row1 col1" >685</td>
#       <td id="T_8815e_row1_col2" class="data row1 col2" >0.027650</td>
#       <td id="T_8815e_row1_col3" class="data row1 col3" >0.017524</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_8815e_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_8815e_row2_col1" class="data row2 col1" >757</td>
#       <td id="T_8815e_row2_col2" class="data row2 col2" >0.036866</td>
#       <td id="T_8815e_row2_col3" class="data row2 col3" >0.019366</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_8815e_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_8815e_row3_col1" class="data row3 col1" >1288</td>
#       <td id="T_8815e_row3_col2" class="data row3 col2" >0.050691</td>
#       <td id="T_8815e_row3_col3" class="data row3 col3" >0.032950</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_8815e_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_8815e_row4_col1" class="data row4 col1" >2114</td>
#       <td id="T_8815e_row4_col2" class="data row4 col2" >0.055300</td>
#       <td id="T_8815e_row4_col3" class="data row4 col3" >0.054082</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_8815e_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_8815e_row5_col1" class="data row5 col1" >415</td>
#       <td id="T_8815e_row5_col2" class="data row5 col2" >0.027650</td>
#       <td id="T_8815e_row5_col3" class="data row5 col3" >0.010617</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_8815e_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_8815e_row6_col1" class="data row6 col1" >19</td>
#       <td id="T_8815e_row6_col2" class="data row6 col2" >0.004608</td>
#       <td id="T_8815e_row6_col3" class="data row6 col3" >0.000486</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_8815e_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_8815e_row7_col1" class="data row7 col1" >128</td>
#       <td id="T_8815e_row7_col2" class="data row7 col2" >0.009217</td>
#       <td id="T_8815e_row7_col3" class="data row7 col3" >0.003275</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_8815e_row8_col0" class="data row8 col0" >28</td>
#       <td id="T_8815e_row8_col1" class="data row8 col1" >3775</td>
#       <td id="T_8815e_row8_col2" class="data row8 col2" >0.129032</td>
#       <td id="T_8815e_row8_col3" class="data row8 col3" >0.096574</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_8815e_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_8815e_row9_col1" class="data row9 col1" >40</td>
#       <td id="T_8815e_row9_col2" class="data row9 col2" >0.004608</td>
#       <td id="T_8815e_row9_col3" class="data row9 col3" >0.001023</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_8815e_row10_col0" class="data row10 col0" >6</td>
#       <td id="T_8815e_row10_col1" class="data row10 col1" >2510</td>
#       <td id="T_8815e_row10_col2" class="data row10 col2" >0.027650</td>
#       <td id="T_8815e_row10_col3" class="data row10 col3" >0.064212</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_8815e_row11_col0" class="data row11 col0" >9</td>
#       <td id="T_8815e_row11_col1" class="data row11 col1" >1510</td>
#       <td id="T_8815e_row11_col2" class="data row11 col2" >0.041475</td>
#       <td id="T_8815e_row11_col3" class="data row11 col3" >0.038630</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row12" class="row_heading level0 row12" >Lugrin</th>
#       <td id="T_8815e_row12_col0" class="data row12 col0" >5</td>
#       <td id="T_8815e_row12_col1" class="data row12 col1" >1073</td>
#       <td id="T_8815e_row12_col2" class="data row12 col2" >0.023041</td>
#       <td id="T_8815e_row12_col3" class="data row12 col3" >0.027450</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row13" class="row_heading level0 row13" >Lutry</th>
#       <td id="T_8815e_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_8815e_row13_col1" class="data row13 col1" >1000</td>
#       <td id="T_8815e_row13_col2" class="data row13 col2" >0.032258</td>
#       <td id="T_8815e_row13_col3" class="data row13 col3" >0.025583</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row14" class="row_heading level0 row14" >Meillerie</th>
#       <td id="T_8815e_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_8815e_row14_col1" class="data row14 col1" >57</td>
#       <td id="T_8815e_row14_col2" class="data row14 col2" >0.004608</td>
#       <td id="T_8815e_row14_col3" class="data row14 col3" >0.001458</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row15" class="row_heading level0 row15" >Pichette</th>
#       <td id="T_8815e_row15_col0" class="data row15 col0" >5</td>
#       <td id="T_8815e_row15_col1" class="data row15 col1" >3766</td>
#       <td id="T_8815e_row15_col2" class="data row15 col2" >0.023041</td>
#       <td id="T_8815e_row15_col3" class="data row15 col3" >0.096344</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row16" class="row_heading level0 row16" >Port Choiseul</th>
#       <td id="T_8815e_row16_col0" class="data row16 col0" >9</td>
#       <td id="T_8815e_row16_col1" class="data row16 col1" >3929</td>
#       <td id="T_8815e_row16_col2" class="data row16 col2" >0.041475</td>
#       <td id="T_8815e_row16_col3" class="data row16 col3" >0.100514</td>
#     </tr>
#     <tr>
#       <th id="T_8815e_level0_row17" class="row_heading level0 row17" >Préverenges</th>
#       <td id="T_8815e_row17_col0" class="data row17 col0" >23</td>
#       <td id="T_8815e_row17_col1" class="data row17 col1" >4866</td>
#       <td id="T_8815e_row17_col2" class="data row17 col2" >0.105991</td>
#       <td id="T_8815e_row17_col3" class="data row17 co

# %% [markdown]
# ## Compte moyen par échantillon et plage

# %%
sample_totals = work_data.groupby(["Plage","echantillon"], as_index=False).compte.sum()
df2 = sample_totals.copy()
value_column = "moyenne"

sample_averages = df2.groupby("Plage", as_index=False).agg({"echantillon": "nunique", "compte":"mean"})
average_of_sample_totals = df2.compte.mean()
sample_averages.rename(columns={"compte":value_column}, inplace=True)

select_values = sample_averages[value_column] > average_of_sample_totals
test_two = sample_averages.loc[select_values].index
caption_one = "Nombre cumulé d'échantillons et total moyen de d'échantillon par plage."
caption_two = "Si le total moyen de l'échantillon pour la plage est supérieur à la moyenne par échantillon du projet, la ligne est sur fond jaune."
caption_three = f"Moyenne du projet: {round(average_of_sample_totals, 2)}"
caption = f'{caption_one} {caption_two} {caption_three}'

sa = sample_averages.style.set_table_styles(table_css_styles).set_caption(caption)
sa.set_properties(subset = pd.IndexSlice[test_two,[value_column]], **a_property)
# Out:
# <style type="text/css">
# #T_76058 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_76058 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_76058 tr {
#   font-size: 14px;
# }
# #T_76058 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_76058 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
# }
# #T_76058_row10_col2, #T_76058_row12_col2, #T_76058_row15_col2, #T_76058_row16_col2, #T_76058_row17_col2, #T_76058_row20_col2 {
#   color: red;
# }
# </style>
# <table id="T_76058">
#   <caption>Nombre cumulé d'échantillons et total moyen de d'échantillon par plage. Si le total moyen de l'échantillon pour la plage est supérieur à la moyenne par échantillon du projet, la ligne est sur fond jaune. Moyenne du projet: 180.13</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76058_level0_col0" class="col_heading level0 col0" >Plage</th>
#       <th id="T_76058_level0_col1" class="col_heading level0 col1" >echantillon</th>
#       <th id="T_76058_level0_col2" class="col_heading level0 col2" >moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76058_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76058_row0_col0" class="data row0 col0" >Amphion</td>
#       <td id="T_76058_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_76058_row0_col2" class="data row0 col2" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76058_row1_col0" class="data row1 col0" >Anthy</td>
#       <td id="T_76058_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_76058_row1_col2" class="data row1 col2" >114.166667</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76058_row2_col0" class="data row2 col0" >Aubonne</td>
#       <td id="T_76058_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_76058_row2_col2" class="data row2 col2" >94.625000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76058_row3_col0" class="data row3 col0" >Baby Plage</td>
#       <td id="T_76058_row3_col1" class="data row3 col1" >11</td>
#       <td id="T_76058_row3_col2" class="data row3 col2" >117.090909</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76058_row4_col0" class="data row4 col0" >Bouveret</td>
#       <td id="T_76058_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_76058_row4_col2" class="data row4 col2" >176.166667</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76058_row5_col0" class="data row5 col0" >Clarens</td>
#       <td id="T_76058_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_76058_row5_col2" class="data row5 col2" >69.166667</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76058_row6_col0" class="data row6 col0" >Crans</td>
#       <td id="T_76058_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_76058_row6_col2" class="data row6 col2" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76058_row7_col0" class="data row7 col0" >Cully</td>
#       <td id="T_76058_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_76058_row7_col2" class="data row7 col2" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76058_row8_col0" class="data row8 col0" >Excenevex</td>
#       <td id="T_76058_row8_col1" class="data row8 col1" >28</td>
#       <td id="T_76058_row8_col2" class="data row8 col2" >134.821429</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76058_row9_col0" class="data row9 col0" >Gland</td>
#       <td id="T_76058_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_76058_row9_col2" class="data row9 col2" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76058_row10_col0" class="data row10 col0" >Grangettes</td>
#       <td id="T_76058_row10_col1" class="data row10 col1" >6</td>
#       <td id="T_76058_row10_col2" class="data row10 col2" >418.333333</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_76058_row11_col0" class="data row11 col0" >Hermance</td>
#       <td id="T_76058_row11_col1" class="data row11 col1" >9</td>
#       <td id="T_76058_row11_col2" class="data row11 col2" >167.777778</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_76058_row12_col0" class="data row12 col0" >Lugrin</td>
#       <td id="T_76058_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_76058_row12_col2" class="data row12 col2" >214.600000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_76058_row13_col0" class="data row13 col0" >Lutry</td>
#       <td id="T_76058_row13_col1" class="data row13 col1" >7</td>
#       <td id="T_76058_row13_col2" class="data row13 col2" >142.857143</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_76058_row14_col0" class="data row14 col0" >Meillerie</td>
#       <td id="T_76058_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_76058_row14_col2" class="data row14 col2" >57.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_76058_row15_col0" class="data row15 col0" >Pichette</td>
#       <td id="T_76058_row15_col1" class="data row15 col1" >5</td>
#       <td id="T_76058_row15_col2" class="data row15 col2" >753.200000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_76058_row16_col0" class="data row16 col0" >Port Choiseul</td>
#       <td id="T_76058_row16_col1" class="data row16 col1" >9</td>
#       <td id="T_76058_row16_col2" class="data row16 col2" >436.555556</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_76058_row17_col0" class="data row17 col0" >Préverenges</td>
#       <td id="T_76058_row17_col1" class="data row17 col1" >23</td>
#       <td id="T_76058_row17_col2" class="data row17 col2" >211.565217</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_76058_row18_col0" class="data row18 col0" >Rolle</td>
#       <td id="T_76058_row18_col1" class="data row18 col1" >21</td>
#       <td id="T_76058_row18_col2" class="data row18 col2" >153.761905</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_76058_row19_col0" class="data row19 col0" >Saint-Disdille</td>
#       <td id="T_76058_row19_col1" class="data row19 col1" >6</td>
#       <td id="T_76058_row19_col2" class="data row19 col2" >179.833333</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_76058_row20_col0" class="data row20 col0" >Savonnière</td>
#       <td id="T_76058_row20_col1" class="data row20 col1" >8</td>
#       <td id="T_76058_row20_col2" class="data row20 col2" >259.500000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_76058_row21_col0" class="data row21 col0" >Tolochenaz</td>
#       <td id="T_76058_row21_col1" class="data row21 col1" >4</td>
#       <td id="T_76058_row21_col2" class="data row21 col2" >95.750000</td>
#     </tr>
#     <tr>
#       <th id="T_76058_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_76058_row22_col0" class="data row22 col0" >Tougues</td>

# %% [markdown]
# ### Nombre moyen par texture et plage

# %%
texture_totals = work_data.groupby(["Plage","echantillon", "objet"], as_index=False).compte.sum()
df3 = texture_totals.copy()

texture_averages = df3.groupby(["Plage", "objet"], as_index=False).agg({"compte":"mean"})
texture_averages.rename(columns={"compte":value_column}, inplace=True)
average_of_sample_textures = df3.groupby(["objet"], as_index=True).agg({"compte":"mean"})
average_of_sample_textures.rename(columns={"compte":value_column}, inplace=True)
average_of_sample_textures.index.name = None
caption = "La moyenne de l'échantillon de projet par type d'objet"
average_of_sample_textures.style.format(precision=2).set_table_styles(table_css_styles).set_caption(caption)
# Out:
# <style type="text/css">
# #T_ff0ed tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_ff0ed tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_ff0ed tr {
#   font-size: 14px;
# }
# #T_ff0ed th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_ff0ed caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
# }
# </style>
# <table id="T_ff0ed">
#   <caption>La moyenne de l'échantillon de projet par type d'objet</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff0ed_level0_col0" class="col_heading level0 col0" >moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff0ed_level0_row0" class="row_heading level0 row0" >fdure</th>
#       <td id="T_ff0ed_row0_col0" class="data row0 col0" >23.53</td>
#     </tr>
#     <tr>
#       <th id="T_ff0ed_level0_row1" class="row_heading level0 row1" >fibres</th>
#       <td id="T_ff0ed_row1_col0" class="data row1 col0" >137.83</td>
#     </tr>
#     <tr>
#       <th id="T_ff0ed_level0_row2" class="row_heading level0 row2" >souple</th>
#       <td id="T_ff0ed_row2_col0" class="data row2 col0" >18.78</td>
#     </tr>
#   </tbody>
# </table>

# %%
texture_averages = texture_averages.pivot(index="Plage", columns="objet").droplevel(0, axis=1)
texture_averages.index.name = None
texture_averages.rename(columns=particle_groups, inplace=True)

select_fdure_values = texture_averages["fragment rigide"] > average_of_sample_textures.loc["fdure", value_column]
select_souple_values = texture_averages["fragment souple"] > average_of_sample_textures.loc["souple", value_column]
select_fiber_vales = texture_averages["fibre"] > average_of_sample_textures.loc["fibres", value_column]
test_three = texture_averages.loc[select_fdure_values].index
test_four = texture_averages.loc[select_souple_values].index
test_five = texture_averages.loc[select_fiber_vales].index

caption_one = "Le nombre moyen par échantillon par plage."
caption = f"{caption_one} {caption_two}"

sa = texture_averages.style.set_table_styles(table_css_styles).set_caption(caption)
# sa.background_gradient(axis=None)
sa = sa.set_properties(subset = pd.IndexSlice[test_three,["fragment rigide"]], **a_property)
sa = sa.set_properties(subset = pd.IndexSlice[test_four,["fragment souple"]], **a_property)
sa = sa.set_properties(subset = pd.IndexSlice[test_five,["fibre"]], **a_property)

sa
# Out:
# <style type="text/css">
# #T_fb880 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_fb880 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_fb880 tr {
#   font-size: 14px;
# }
# #T_fb880 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_fb880 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
# }
# #T_fb880_row4_col1, #T_fb880_row10_col1, #T_fb880_row10_col2, #T_fb880_row11_col1, #T_fb880_row12_col1, #T_fb880_row12_col2, #T_fb880_row14_col0, #T_fb880_row15_col0, #T_fb880_row15_col1, #T_fb880_row16_col0, #T_fb880_row16_col1, #T_fb880_row17_col0, #T_fb880_row17_col1, #T_fb880_row17_col2, #T_fb880_row18_col0, #T_fb880_row19_col1, #T_fb880_row20_col1, #T_fb880_row20_col2 {
#   color: red;
# }
# </style>
# <table id="T_fb880">
#   <caption>Le nombre moyen par échantillon par plage. Si le total moyen de l'échantillon pour la plage est supérieur à la moyenne par échantillon du projet, la ligne est sur fond jaune.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >objet</th>
#       <th id="T_fb880_level0_col0" class="col_heading level0 col0" >fragment rigide</th>
#       <th id="T_fb880_level0_col1" class="col_heading level0 col1" >fibre</th>
#       <th id="T_fb880_level0_col2" class="col_heading level0 col2" >fragment souple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb880_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_fb880_row0_col0" class="data row0 col0" >7.900000</td>
#       <td id="T_fb880_row0_col1" class="data row0 col1" >110.000000</td>
#       <td id="T_fb880_row0_col2" class="data row0 col2" >7.100000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_fb880_row1_col0" class="data row1 col0" >9.166667</td>
#       <td id="T_fb880_row1_col1" class="data row1 col1" >91.666667</td>
#       <td id="T_fb880_row1_col2" class="data row1 col2" >13.333333</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_fb880_row2_col0" class="data row2 col0" >11.875000</td>
#       <td id="T_fb880_row2_col1" class="data row2 col1" >70.125000</td>
#       <td id="T_fb880_row2_col2" class="data row2 col2" >12.625000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_fb880_row3_col0" class="data row3 col0" >12.000000</td>
#       <td id="T_fb880_row3_col1" class="data row3 col1" >98.090909</td>
#       <td id="T_fb880_row3_col2" class="data row3 col2" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_fb880_row4_col0" class="data row4 col0" >13.750000</td>
#       <td id="T_fb880_row4_col1" class="data row4 col1" >147.250000</td>
#       <td id="T_fb880_row4_col2" class="data row4 col2" >15.166667</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_fb880_row5_col0" class="data row5 col0" >6.333333</td>
#       <td id="T_fb880_row5_col1" class="data row5 col1" >57.500000</td>
#       <td id="T_fb880_row5_col2" class="data row5 col2" >5.333333</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_fb880_row6_col0" class="data row6 col0" >2.000000</td>
#       <td id="T_fb880_row6_col1" class="data row6 col1" >17.000000</td>
#       <td id="T_fb880_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_fb880_row7_col0" class="data row7 col0" >5.500000</td>
#       <td id="T_fb880_row7_col1" class="data row7 col1" >58.500000</td>
#       <td id="T_fb880_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_fb880_row8_col0" class="data row8 col0" >19.392857</td>
#       <td id="T_fb880_row8_col1" class="data row8 col1" >97.142857</td>
#       <td id="T_fb880_row8_col2" class="data row8 col2" >18.285714</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_fb880_row9_col0" class="data row9 col0" >8.000000</td>
#       <td id="T_fb880_row9_col1" class="data row9 col1" >26.000000</td>
#       <td id="T_fb880_row9_col2" class="data row9 col2" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_fb880_row10_col0" class="data row10 col0" >7.833333</td>
#       <td id="T_fb880_row10_col1" class="data row10 col1" >234.166667</td>
#       <td id="T_fb880_row10_col2" class="data row10 col2" >176.333333</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_fb880_row11_col0" class="data row11 col0" >6.666667</td>
#       <td id="T_fb880_row11_col1" class="data row11 col1" >153.555556</td>
#       <td id="T_fb880_row11_col2" class="data row11 col2" >7.555556</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row12" class="row_heading level0 row12" >Lugrin</th>
#       <td id="T_fb880_row12_col0" class="data row12 col0" >9.800000</td>
#       <td id="T_fb880_row12_col1" class="data row12 col1" >184.600000</td>
#       <td id="T_fb880_row12_col2" class="data row12 col2" >20.200000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row13" class="row_heading level0 row13" >Lutry</th>
#       <td id="T_fb880_row13_col0" class="data row13 col0" >5.285714</td>
#       <td id="T_fb880_row13_col1" class="data row13 col1" >130.142857</td>
#       <td id="T_fb880_row13_col2" class="data row13 col2" >7.428571</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row14" class="row_heading level0 row14" >Meillerie</th>
#       <td id="T_fb880_row14_col0" class="data row14 col0" >26.000000</td>
#       <td id="T_fb880_row14_col1" class="data row14 col1" >26.000000</td>
#       <td id="T_fb880_row14_col2" class="data row14 col2" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row15" class="row_heading level0 row15" >Pichette</th>
#       <td id="T_fb880_row15_col0" class="data row15 col0" >103.600000</td>
#       <td id="T_fb880_row15_col1" class="data row15 col1" >632.400000</td>
#       <td id="T_fb880_row15_col2" class="data row15 col2" >17.200000</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row16" class="row_heading level0 row16" >Port Choiseul</th>
#       <td id="T_fb880_row16_col0" class="data row16 col0" >118.555556</td>
#       <td id="T_fb880_row16_col1" class="data row16 col1" >308.888889</td>
#       <td id="T_fb880_row16_col2" class="data row16 col2" >9.111111</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row17" class="row_heading level0 row17" >Préverenges</th>
#       <td id="T_fb880_row17_col0" class="data row17 col0" >30.391304</td>
#       <td id="T_fb880_row17_col1" class="data row17 col1" >142.217391</td>
#       <td id="T_fb880_row17_col2" class="data row17 col2" >38.956522</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row18" class="row_heading level0 row18" >Rolle</th>
#       <td id="T_fb880_row18_col0" class="data row18 col0" >40.714286</td>
#       <td id="T_fb880_row18_col1" class="data row18 col1" >109.857143</td>
#       <td id="T_fb880_row18_col2" class="data row18 col2" >3.190476</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row19" class="row_heading level0 row19" >Saint-Disdille</th>
#       <td id="T_fb880_row19_col0" class="data row19 col0" >20.166667</td>
#       <td id="T_fb880_row19_col1" class="data row19 col1" >150.833333</td>
#       <td id="T_fb880_row19_col2" class="data row19 col2" >8.833333</td>
#     </tr>
#     <tr>
#       <th id="T_fb880_level0_row20" class="row_heading level0 row20" >Savonnière</th>
#       <td id="T_fb880_row20_col0" class="data row20 col0" >20.500000</td>
#       <td id="T_fb880_row20_col1" class="data row20 col1" >203.250000</td>
#       <td id="T_fb880_row20_col2" class="data

# %% [markdown]
# ## Comptes moyenne par position

# %%
position_totals = work_data.groupby(["Plage","echantillon", "position"], as_index=False).compte.sum()
position_totals["position"] = position_totals.position.apply(lambda x: name_the_zones[x])
# position_totals["objet"] = position_totals.objet.apply(lambda x: particle_groups[x])
df4 = position_totals.groupby(["Plage","position"], as_index=False).compte.mean()

df4 = df4.pivot(index="Plage", columns=["position"])
df4.index.name = None
df4.columns
df4.fillna(0, inplace=True)

def select_a_set_of_values(data, column_one, threshold_data):
    
    return data.loc[data[column_one] > threshold_data]

position_columns = list(name_the_zones.values())
fragment_columns = list(particle_groups.values())

args = [("compte", x) for x in position_columns]
print(args[0])


suple_water_line = select_a_set_of_values(df4, args[0], average_of_sample_totals).index
fibre_water_line = select_a_set_of_values(df4, args[1], average_of_sample_totals).index

sax = df4.style.set_table_styles(table_css_styles).set_caption(caption).format(precision=2)
 
sax = sax.set_properties(subset = pd.IndexSlice[suple_water_line,args[0]], **a_property)
sax = sax.set_properties(subset = pd.IndexSlice[fibre_water_line,args[1]], **a_property)

sax
# Out:
# ('compte', "ligne-d'eau")
# <style type="text/css">
# #T_414db tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_414db tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_414db tr {
#   font-size: 14px;
# }
# #T_414db th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_414db caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
# }
# #T_414db_row4_col1, #T_414db_row10_col0, #T_414db_row10_col1, #T_414db_row11_col1, #T_414db_row12_col1, #T_414db_row13_col1, #T_414db_row15_col1, #T_414db_row16_col1, #T_414db_row17_col0, #T_414db_row17_col1, #T_414db_row20_col1 {
#   color: red;
# }
# </style>
# <table id="T_414db">
#   <caption>Le nombre moyen par échantillon par plage. Si le total moyen de l'échantillon pour la plage est supérieur à la moyenne par échantillon du projet, la ligne est sur fond jaune.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_414db_level0_col0" class="col_heading level0 col0" colspan="2">compte</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >position</th>
#       <th id="T_414db_level1_col0" class="col_heading level1 col0" >ligne-d'eau</th>
#       <th id="T_414db_level1_col1" class="col_heading level1 col1" >plage-seche</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_414db_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_414db_row0_col0" class="data row0 col0" >111.50</td>
#       <td id="T_414db_row0_col1" class="data row0 col1" >134.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_414db_row1_col0" class="data row1 col0" >55.33</td>
#       <td id="T_414db_row1_col1" class="data row1 col1" >173.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_414db_row2_col0" class="data row2 col0" >62.80</td>
#       <td id="T_414db_row2_col1" class="data row2 col1" >147.67</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_414db_row3_col0" class="data row3 col0" >69.00</td>
#       <td id="T_414db_row3_col1" class="data row3 col1" >157.17</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_414db_row4_col0" class="data row4 col0" >90.86</td>
#       <td id="T_414db_row4_col1" class="data row4 col1" >295.60</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_414db_row5_col0" class="data row5 col0" >54.25</td>
#       <td id="T_414db_row5_col1" class="data row5 col1" >99.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_414db_row6_col0" class="data row6 col0" >19.00</td>
#       <td id="T_414db_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_414db_row7_col0" class="data row7 col0" >128.00</td>
#       <td id="T_414db_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_414db_row8_col0" class="data row8 col0" >102.29</td>
#       <td id="T_414db_row8_col1" class="data row8 col1" >145.67</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_414db_row9_col0" class="data row9 col0" >40.00</td>
#       <td id="T_414db_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_414db_row10_col0" class="data row10 col0" >419.75</td>
#       <td id="T_414db_row10_col1" class="data row10 col1" >415.50</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_414db_row11_col0" class="data row11 col0" >66.50</td>
#       <td id="T_414db_row11_col1" class="data row11 col1" >248.80</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row12" class="row_heading level0 row12" >Lugrin</th>
#       <td id="T_414db_row12_col0" class="data row12 col0" >111.00</td>
#       <td id="T_414db_row12_col1" class="data row12 col1" >370.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row13" class="row_heading level0 row13" >Lutry</th>
#       <td id="T_414db_row13_col0" class="data row13 col0" >77.00</td>
#       <td id="T_414db_row13_col1" class="data row13 col1" >230.67</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row14" class="row_heading level0 row14" >Meillerie</th>
#       <td id="T_414db_row14_col0" class="data row14 col0" >57.00</td>
#       <td id="T_414db_row14_col1" class="data row14 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row15" class="row_heading level0 row15" >Pichette</th>
#       <td id="T_414db_row15_col0" class="data row15 col0" >72.00</td>
#       <td id="T_414db_row15_col1" class="data row15 col1" >1775.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row16" class="row_heading level0 row16" >Port Choiseul</th>
#       <td id="T_414db_row16_col0" class="data row16 col0" >64.00</td>
#       <td id="T_414db_row16_col1" class="data row16 col1" >1181.67</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row17" class="row_heading level0 row17" >Préverenges</th>
#       <td id="T_414db_row17_col0" class="data row17 col0" >242.30</td>
#       <td id="T_414db_row17_col1" class="data row17 col1" >187.92</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row18" class="row_heading level0 row18" >Rolle</th>
#       <td id="T_414db_row18_col0" class="data row18 col0" >125.10</td>
#       <td id="T_414db_row18_col1" class="data row18 col1" >179.82</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row19" class="row_heading level0 row19" >Saint-Disdille</th>
#       <td id="T_414db_row19_col0" class="data row19 col0" >179.83</td>
#       <td id="T_414db_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row20" class="row_heading level0 row20" >Savonnière</th>
#       <td id="T_414db_row20_col0" class="data row20 col0" >130.00</td>
#       <td id="T_414db_row20_col1" class="data row20 col1" >337.20</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row21" class="row_heading level0 row21" >Tolochenaz</th>
#       <td id="T_414db_row21_col0" class="data row21 col0" >95.75</td>
#       <td id="T_414db_row21_col1" class="data row21 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row22" class="row_heading level0 row22" >Tougues</th>
#       <td id="T_414db_row22_col0" class="data row22 col0" >67.67</td>
#       <td id="T_414db_row22_col1" class="data row22 col1" >154.40</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row23" class="row_heading level0 row23" >Versoix</th>
#       <td id="T_414db_row23_col0" class="data row23 col0" >99.33</td>
#       <td id="T_414db_row23_col1" class="data row23 col1" >101.00</td>
#     </tr>
#     <tr>
#       <th id="T_414db_level0_row24" class="row_heading level0 row24" >Vidy</th>
#       <td id="T_414db_row24_col0" class="data row24 col0" >78.17</td>
#       <td id="T_414db_row24_col1" class="data row24 col1" >156.29</td>
#     </tr>
#   </tbody>
# </table>

# %%
position_totals = work_data.groupby(["Plage","echantillon", "position", "objet"], as_index=False).compte.sum()
position_totals["position"] = position_totals.position.apply(lambda x: name_the_zones[x])
position_totals["objet"] = position_totals.objet.apply(lambda x: particle_groups[x])
df4 = position_totals.groupby(["Plage","position", "objet"], as_index=False).compte.mean()

df4 = df4.pivot(index="Plage", columns=["position", "objet"])
df4.index.name = None
df4.columns
df4.fillna(0, inplace=True)

def select_a_set_of_values(data, column_one, search_index, search_value, average_of_sample_textures):
    
    return data.loc[data[column_one] > average_of_sample_textures.loc[search_index, search_value]]

args_one = [("compte", position_columns[0], x) for x in fragment_columns]
args_two = [("compte", position_columns[1], x) for x in fragment_columns]

args_0 = select_a_set_of_values(df4, args_one[0], list(particle_groups.keys())[0], value_column).index
args_1 = select_a_set_of_values(df4, args_one[1], list(particle_groups.keys())[1], value_column).index
args_2  = select_a_set_of_values(df4, args_one[2], list(particle_groups.keys())[2], value_column).index

args_2_0 = select_a_set_of_values(df4, args_two[0], list(particle_groups.keys())[0], value_column).index
args_2_1 = select_a_set_of_values(df4, args_two[1], list(particle_groups.keys())[1], value_column).index
args_2_2 = select_a_set_of_values(df4, args_two[2], list(particle_groups.keys())[2], value_column).index

sax = df4.style.set_table_styles(table_css_styles).set_caption(caption).format(precision=2)
  
sax = sax.set_properties(subset = pd.IndexSlice[args_2, args_one[2]],)
sax = sax.set_properties(subset = pd.IndexSlice[args_1,args_one[1]],)
sax = sax.set_properties(subset = pd.IndexSlice[args_0,args_one[0]], **a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_2_2, args_two[2]], **a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_2_1,args_two[1]],**a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_2_0,args_two[0]], **a_property)

sax
# Out:
# <style type="text/css">
# #T_35255 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_35255 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_35255 tr {
#   font-size: 14px;
# }
# #T_35255 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_35255 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
# }
# #T_35255_row1_col3, #T_35255_row1_col5, #T_35255_row2_col5, #T_35255_row4_col3, #T_35255_row4_col5, #T_35255_row8_col4, #T_35255_row8_col5, #T_35255_row10_col0, #T_35255_row10_col3, #T_35255_row10_col5, #T_35255_row11_col3, #T_35255_row12_col3, #T_35255_row12_col5, #T_35255_row13_col3, #T_35255_row15_col3, #T_35255_row15_col4, #T_35255_row15_col5, #T_35255_row16_col3, #T_35255_row16_col4, #T_35255_row16_col5, #T_35255_row17_col3, #T_35255_row18_col4, #T_35255_row19_col0, #T_35255_row20_col3, #T_35255_row20_col4, #T_35255_row20_col5, #T_35255_row24_col4, #T_35255_row24_col5 {
#   color: red;
# }
# </style>
# <table id="T_35255">
#   <caption>Le nombre moyen par échantillon par plage. Si le total moyen de l'échantillon pour la plage est supérieur à la moyenne par échantillon du projet, la ligne est sur fond jaune.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35255_level0_col0" class="col_heading level0 col0" colspan="6">compte</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >position</th>
#       <th id="T_35255_level1_col0" class="col_heading level1 col0" colspan="3">ligne-d'eau</th>
#       <th id="T_35255_level1_col3" class="col_heading level1 col3" colspan="3">plage-seche</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >objet</th>
#       <th id="T_35255_level2_col0" class="col_heading level2 col0" >fibre</th>
#       <th id="T_35255_level2_col1" class="col_heading level2 col1" >fragment rigide</th>
#       <th id="T_35255_level2_col2" class="col_heading level2 col2" >fragment souple</th>
#       <th id="T_35255_level2_col3" class="col_heading level2 col3" >fibre</th>
#       <th id="T_35255_level2_col4" class="col_heading level2 col4" >fragment rigide</th>
#       <th id="T_35255_level2_col5" class="col_heading level2 col5" >fragment souple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35255_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_35255_row0_col0" class="data row0 col0" >107.00</td>
#       <td id="T_35255_row0_col1" class="data row0 col1" >1.25</td>
#       <td id="T_35255_row0_col2" class="data row0 col2" >3.25</td>
#       <td id="T_35255_row0_col3" class="data row0 col3" >112.00</td>
#       <td id="T_35255_row0_col4" class="data row0 col4" >12.33</td>
#       <td id="T_35255_row0_col5" class="data row0 col5" >9.67</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_35255_row1_col0" class="data row1 col0" >41.00</td>
#       <td id="T_35255_row1_col1" class="data row1 col1" >7.33</td>
#       <td id="T_35255_row1_col2" class="data row1 col2" >7.00</td>
#       <td id="T_35255_row1_col3" class="data row1 col3" >142.33</td>
#       <td id="T_35255_row1_col4" class="data row1 col4" >11.00</td>
#       <td id="T_35255_row1_col5" class="data row1 col5" >19.67</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_35255_row2_col0" class="data row2 col0" >49.60</td>
#       <td id="T_35255_row2_col1" class="data row2 col1" >12.60</td>
#       <td id="T_35255_row2_col2" class="data row2 col2" >0.60</td>
#       <td id="T_35255_row2_col3" class="data row2 col3" >104.33</td>
#       <td id="T_35255_row2_col4" class="data row2 col4" >10.67</td>
#       <td id="T_35255_row2_col5" class="data row2 col5" >32.67</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_35255_row3_col0" class="data row3 col0" >63.00</td>
#       <td id="T_35255_row3_col1" class="data row3 col1" >6.00</td>
#       <td id="T_35255_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_35255_row3_col3" class="data row3 col3" >127.33</td>
#       <td id="T_35255_row3_col4" class="data row3 col4" >17.00</td>
#       <td id="T_35255_row3_col5" class="data row3 col5" >12.83</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_35255_row4_col0" class="data row4 col0" >75.43</td>
#       <td id="T_35255_row4_col1" class="data row4 col1" >15.14</td>
#       <td id="T_35255_row4_col2" class="data row4 col2" >0.29</td>
#       <td id="T_35255_row4_col3" class="data row4 col3" >247.80</td>
#       <td id="T_35255_row4_col4" class="data row4 col4" >11.80</td>
#       <td id="T_35255_row4_col5" class="data row4 col5" >36.00</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_35255_row5_col0" class="data row5 col0" >48.75</td>
#       <td id="T_35255_row5_col1" class="data row5 col1" >4.75</td>
#       <td id="T_35255_row5_col2" class="data row5 col2" >0.75</td>
#       <td id="T_35255_row5_col3" class="data row5 col3" >75.00</td>
#       <td id="T_35255_row5_col4" class="data row5 col4" >9.50</td>
#       <td id="T_35255_row5_col5" class="data row5 col5" >14.50</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_35255_row6_col0" class="data row6 col0" >17.00</td>
#       <td id="T_35255_row6_col1" class="data row6 col1" >2.00</td>
#       <td id="T_35255_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_35255_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_35255_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_35255_row6_col5" class="data row6 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_35255_row7_col0" class="data row7 col0" >117.00</td>
#       <td id="T_35255_row7_col1" class="data row7 col1" >11.00</td>
#       <td id="T_35255_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_35255_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_35255_row7_col4" class="data row7 col4" >0.00</td>
#       <td id="T_35255_row7_col5" class="data row7 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_35255_row8_col0" class="data row8 col0" >90.86</td>
#       <td id="T_35255_row8_col1" class="data row8 col1" >4.43</td>
#       <td id="T_35255_row8_col2" class="data row8 col2" >7.00</td>
#       <td id="T_35255_row8_col3" class="data row8 col3" >99.24</td>
#       <td id="T_35255_row8_col4" class="data row8 col4" >24.38</td>
#       <td id="T_35255_row8_col5" class="data row8 col5" >22.05</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_35255_row9_col0" class="data row9 col0" >26.00</td>
#       <td id="T_35255_row9_col1" class="data row9 col1" >8.00</td>
#       <td id="T_35255_row9_col2" class="data row9 col2" >6.00</td>
#       <td id="T_35255_row9_col3" class="data row9 col3" >0.00</td>
#       <td id="T_35255_row9_col4" class="data row9 col4" >0.00</td>
#       <td id="T_35255_row9_col5" class="data row9 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_35255_row10_col0" class="data row10 col0" >163.75</td>
#       <td id="T_35255_row10_col1" class="data row10 col1" >10.00</td>
#       <td id="T_35255_row10_col2" class="data row10 col2" >246.00</td>
#       <td id="T_35255_row10_col3" class="data row10 col3" >375.00</td>
#       <td id="T_35255_row10_col4" class="data row10 col4" >3.50</td>
#       <td id="T_35255_row10_col5" class="data row10 col5" >37.00</td>
#     </tr>
#     <tr>
#       <th id="T_35255_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_35255_row11_col0" class="data row11 col0" >62.25</td>
#       <td id="T_35255_row11_col1" class="data row11 col1" >4.25</td>

# %% [markdown]
# ### Distributions
