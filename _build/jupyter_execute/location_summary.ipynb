# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from myst_nb import glue 

from plastockmethods import name_the_zones, name_the_particles, frequentation_name, situation_name
from plastockmethods import particle_groups, name_the_substrate, name_the_distance, table_css_styles

def translate_describe(x, value_column):
    described = x.to_dict()
    described.pop("count")
    described["moyenne"] = described.pop("mean")
    described["écart-type"] = described.pop("std")
    df = pd.DataFrame(described.items())
    df.set_index(0, inplace=True)
    df.rename(columns={1:value_column}, inplace=True)
    df.index.name = None
    
    
    return df

work_data = pd.read_csv("data/end_pipe/long_form_micro.csv")
wide_form = pd.read_csv("data/end_pipe/aggregated_micro_results.csv")
beach_data = pd.read_csv("data/end_pipe/asl_beaches.csv")

# %% [markdown]
# # Résultats par plage et position
#
# __Résultats agrégés par texture, position et échantillon__

# %%
caption = "Les données sont regroupées en trois groupes par échantillon: 1. fibres, 2. fragments rigides, 3. fragments souples."

work_data[work_data.echantillon == "74_Amp_2"].head().style.set_table_styles(table_css_styles).set_caption(caption)
# Out:
# <style type="text/css">
# #T_ab49e tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_ab49e tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_ab49e tr {
#   font-size: 14px;
# }
# #T_ab49e th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_ab49e caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# </style>
# <table id="T_ab49e">
#   <caption>Les données sont regroupées en trois groupes par échantillon: 1. fibres, 2. fragments rigides, 3. fragments souples.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab49e_level0_col0" class="col_heading level0 col0" >Plage</th>
#       <th id="T_ab49e_level0_col1" class="col_heading level0 col1" >echantillon</th>
#       <th id="T_ab49e_level0_col2" class="col_heading level0 col2" >orientation</th>
#       <th id="T_ab49e_level0_col3" class="col_heading level0 col3" >position</th>
#       <th id="T_ab49e_level0_col4" class="col_heading level0 col4" >substrat</th>
#       <th id="T_ab49e_level0_col5" class="col_heading level0 col5" >frequentation</th>
#       <th id="T_ab49e_level0_col6" class="col_heading level0 col6" >situation</th>
#       <th id="T_ab49e_level0_col7" class="col_heading level0 col7" >distance</th>
#       <th id="T_ab49e_level0_col8" class="col_heading level0 col8" >objet</th>
#       <th id="T_ab49e_level0_col9" class="col_heading level0 col9" >compte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab49e_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ab49e_row0_col0" class="data row0 col0" >Amphion</td>
#       <td id="T_ab49e_row0_col1" class="data row0 col1" >74_Amp_2</td>
#       <td id="T_ab49e_row0_col2" class="data row0 col2" >NNE</td>
#       <td id="T_ab49e_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_ab49e_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_ab49e_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_ab49e_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_ab49e_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_ab49e_row0_col8" class="data row0 col8" >fibres</td>
#       <td id="T_ab49e_row0_col9" class="data row0 col9" >121</td>
#     </tr>
#     <tr>
#       <th id="T_ab49e_level0_row1" class="row_heading level0 row1" >219</th>
#       <td id="T_ab49e_row1_col0" class="data row1 col0" >Amphion</td>
#       <td id="T_ab49e_row1_col1" class="data row1 col1" >74_Amp_2</td>
#       <td id="T_ab49e_row1_col2" class="data row1 col2" >NNE</td>
#       <td id="T_ab49e_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_ab49e_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_ab49e_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_ab49e_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_ab49e_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_ab49e_row1_col8" class="data row1 col8" >fdure</td>
#       <td id="T_ab49e_row1_col9" class="data row1 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ab49e_level0_row2" class="row_heading level0 row2" >436</th>
#       <td id="T_ab49e_row2_col0" class="data row2 col0" >Amphion</td>
#       <td id="T_ab49e_row2_col1" class="data row2 col1" >74_Amp_2</td>
#       <td id="T_ab49e_row2_col2" class="data row2 col2" >NNE</td>
#       <td id="T_ab49e_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_ab49e_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_ab49e_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_ab49e_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_ab49e_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_ab49e_row2_col8" class="data row2 col8" >souple</td>
#       <td id="T_ab49e_row2_col9" class="data row2 col9" >12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Nombre cumulé d'échantillons et décompte par plage

# %%
location_summary = work_data.groupby("Plage", as_index=False).agg({"echantillon": "nunique", "compte":"sum"})
location_summary["poids echantillon"] = location_summary.echantillon/location_summary.echantillon.sum()
location_summary["poids compte"] = location_summary.compte/location_summary.compte.sum()
# location_summary.set_index("Plage", inplace=True, drop=True)
df1 = location_summary.copy()
df1.set_index("Plage", inplace=True, drop=True)
df1.index.name = None
a_property =  {'color' : 'red'}

select_values = df1["poids echantillon"] < df1["poids compte"]
test_one = df1.loc[select_values].index
caption = "Nombre cumulé d'échantillons et le total par plage. Les plages où le poids du comptage est supérieur au poids des échantillons sont en rouge."
                        
df1.style.set_table_styles(table_css_styles).format(precision=2).set_caption(caption).set_properties(subset = pd.IndexSlice[test_one,["poids echantillon", "poids compte"]], **a_property)
# Out:
# <style type="text/css">
# #T_3b355 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_3b355 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_3b355 tr {
#   font-size: 14px;
# }
# #T_3b355 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_3b355 caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# #T_3b355_row10_col2, #T_3b355_row10_col3, #T_3b355_row12_col2, #T_3b355_row12_col3, #T_3b355_row15_col2, #T_3b355_row15_col3, #T_3b355_row16_col2, #T_3b355_row16_col3, #T_3b355_row17_col2, #T_3b355_row17_col3, #T_3b355_row20_col2, #T_3b355_row20_col3 {
#   color: red;
# }
# </style>
# <table id="T_3b355">
#   <caption>Nombre cumulé d'échantillons et le total par plage. Les plages où le poids du comptage est supérieur au poids des échantillons sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b355_level0_col0" class="col_heading level0 col0" >echantillon</th>
#       <th id="T_3b355_level0_col1" class="col_heading level0 col1" >compte</th>
#       <th id="T_3b355_level0_col2" class="col_heading level0 col2" >poids echantillon</th>
#       <th id="T_3b355_level0_col3" class="col_heading level0 col3" >poids compte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b355_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_3b355_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_3b355_row0_col1" class="data row0 col1" >1250</td>
#       <td id="T_3b355_row0_col2" class="data row0 col2" >0.05</td>
#       <td id="T_3b355_row0_col3" class="data row0 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_3b355_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_3b355_row1_col1" class="data row1 col1" >685</td>
#       <td id="T_3b355_row1_col2" class="data row1 col2" >0.03</td>
#       <td id="T_3b355_row1_col3" class="data row1 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_3b355_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_3b355_row2_col1" class="data row2 col1" >757</td>
#       <td id="T_3b355_row2_col2" class="data row2 col2" >0.04</td>
#       <td id="T_3b355_row2_col3" class="data row2 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_3b355_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_3b355_row3_col1" class="data row3 col1" >1288</td>
#       <td id="T_3b355_row3_col2" class="data row3 col2" >0.05</td>
#       <td id="T_3b355_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_3b355_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_3b355_row4_col1" class="data row4 col1" >2114</td>
#       <td id="T_3b355_row4_col2" class="data row4 col2" >0.06</td>
#       <td id="T_3b355_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_3b355_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_3b355_row5_col1" class="data row5 col1" >415</td>
#       <td id="T_3b355_row5_col2" class="data row5 col2" >0.03</td>
#       <td id="T_3b355_row5_col3" class="data row5 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_3b355_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_3b355_row6_col1" class="data row6 col1" >19</td>
#       <td id="T_3b355_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_3b355_row6_col3" class="data row6 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_3b355_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_3b355_row7_col1" class="data row7 col1" >128</td>
#       <td id="T_3b355_row7_col2" class="data row7 col2" >0.01</td>
#       <td id="T_3b355_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_3b355_row8_col0" class="data row8 col0" >28</td>
#       <td id="T_3b355_row8_col1" class="data row8 col1" >3775</td>
#       <td id="T_3b355_row8_col2" class="data row8 col2" >0.13</td>
#       <td id="T_3b355_row8_col3" class="data row8 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_3b355_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_3b355_row9_col1" class="data row9 col1" >40</td>
#       <td id="T_3b355_row9_col2" class="data row9 col2" >0.00</td>
#       <td id="T_3b355_row9_col3" class="data row9 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_3b355_row10_col0" class="data row10 col0" >6</td>
#       <td id="T_3b355_row10_col1" class="data row10 col1" >2510</td>
#       <td id="T_3b355_row10_col2" class="data row10 col2" >0.03</td>
#       <td id="T_3b355_row10_col3" class="data row10 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_3b355_row11_col0" class="data row11 col0" >9</td>
#       <td id="T_3b355_row11_col1" class="data row11 col1" >1510</td>
#       <td id="T_3b355_row11_col2" class="data row11 col2" >0.04</td>
#       <td id="T_3b355_row11_col3" class="data row11 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row12" class="row_heading level0 row12" >Lugrin</th>
#       <td id="T_3b355_row12_col0" class="data row12 col0" >5</td>
#       <td id="T_3b355_row12_col1" class="data row12 col1" >1073</td>
#       <td id="T_3b355_row12_col2" class="data row12 col2" >0.02</td>
#       <td id="T_3b355_row12_col3" class="data row12 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row13" class="row_heading level0 row13" >Lutry</th>
#       <td id="T_3b355_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_3b355_row13_col1" class="data row13 col1" >1000</td>
#       <td id="T_3b355_row13_col2" class="data row13 col2" >0.03</td>
#       <td id="T_3b355_row13_col3" class="data row13 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row14" class="row_heading level0 row14" >Meillerie</th>
#       <td id="T_3b355_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_3b355_row14_col1" class="data row14 col1" >57</td>
#       <td id="T_3b355_row14_col2" class="data row14 col2" >0.00</td>
#       <td id="T_3b355_row14_col3" class="data row14 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row15" class="row_heading level0 row15" >Pichette</th>
#       <td id="T_3b355_row15_col0" class="data row15 col0" >5</td>
#       <td id="T_3b355_row15_col1" class="data row15 col1" >3766</td>
#       <td id="T_3b355_row15_col2" class="data row15 col2" >0.02</td>
#       <td id="T_3b355_row15_col3" class="data row15 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row16" class="row_heading level0 row16" >Port Choiseul</th>
#       <td id="T_3b355_row16_col0" class="data row16 col0" >9</td>
#       <td id="T_3b355_row16_col1" class="data row16 col1" >3929</td>
#       <td id="T_3b355_row16_col2" class="data row16 col2" >0.04</td>
#       <td id="T_3b355_row16_col3" class="data row16 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row17" class="row_heading level0 row17" >Préverenges</th>
#       <td id="T_3b355_row17_col0" class="data row17 col0" >23</td>
#       <td id="T_3b355_row17_col1" class="data row17 col1" >4866</td>
#       <td id="T_3b355_row17_col2" class="data row17 col2" >0.11</td>
#       <td id="T_3b355_row17_col3" class="data row17 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_3b355_level0_row18" class="row_heading level0 row18" >Rolle</th>
#       <td

# %%
bar_plots = pd.melt(location_summary, id_vars="Plage", value_vars=["poids echantillon", "poids compte"])
fig, ax = plt.subplots()
sns.barplot(data=bar_plots, x="Plage", y="value", hue="variable", ax=ax)
ax.legend(loc="upper left")
ax.tick_params(axis="x", labelrotation=90, labelright=True, labelsize=12 )
plt.show()

# %%
attribute_columns = ["Plage", "orientation", "position", "substrat", "frequentation", "situation", "distance"]
percent_of_samples = df1.loc[select_values].echantillon.sum()/location_summary.echantillon.sum()
attributes_of_samples = work_data[work_data.Plage.isin(test_one)].drop_duplicates(["Plage"])


def translate_columns(data, columns, keys):
    
    for i, column in enumerate(columns):
        
        data[column] = data[column].apply(lambda x: keys[i][x])
    
    return data

attribute_keys = [name_the_zones, name_the_substrate, frequentation_name, situation_name, name_the_distance]
caption = "Les plages et leurs attributs où le poids du comptage est supérieur au poids des échantillons."    

display_df = translate_columns(attributes_of_samples, attribute_columns[2:], attribute_keys)
display_df[attribute_columns].style.set_table_styles(table_css_styles).set_caption(caption)
# Out:
# <style type="text/css">
# #T_e1d70 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_e1d70 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_e1d70 tr {
#   font-size: 14px;
# }
# #T_e1d70 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_e1d70 caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# </style>
# <table id="T_e1d70">
#   <caption>Les plages et leurs attributs où le poids du comptage est supérieur au poids des échantillons.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1d70_level0_col0" class="col_heading level0 col0" >Plage</th>
#       <th id="T_e1d70_level0_col1" class="col_heading level0 col1" >orientation</th>
#       <th id="T_e1d70_level0_col2" class="col_heading level0 col2" >position</th>
#       <th id="T_e1d70_level0_col3" class="col_heading level0 col3" >substrat</th>
#       <th id="T_e1d70_level0_col4" class="col_heading level0 col4" >frequentation</th>
#       <th id="T_e1d70_level0_col5" class="col_heading level0 col5" >situation</th>
#       <th id="T_e1d70_level0_col6" class="col_heading level0 col6" >distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1d70_level0_row0" class="row_heading level0 row0" >44</th>
#       <td id="T_e1d70_row0_col0" class="data row0 col0" >Lugrin</td>
#       <td id="T_e1d70_row0_col1" class="data row0 col1" >NNE</td>
#       <td id="T_e1d70_row0_col2" class="data row0 col2" >ligne-d'eau</td>
#       <td id="T_e1d70_row0_col3" class="data row0 col3" >galet</td>
#       <td id="T_e1d70_row0_col4" class="data row0 col4" >moyenne</td>
#       <td id="T_e1d70_row0_col5" class="data row0 col5" >campagne</td>
#       <td id="T_e1d70_row0_col6" class="data row0 col6" >100 - 500m</td>
#     </tr>
#     <tr>
#       <th id="T_e1d70_level0_row1" class="row_heading level0 row1" >87</th>
#       <td id="T_e1d70_row1_col0" class="data row1 col0" >Port Choiseul</td>
#       <td id="T_e1d70_row1_col1" class="data row1 col1" >NE</td>
#       <td id="T_e1d70_row1_col2" class="data row1 col2" >ligne-d'eau</td>
#       <td id="T_e1d70_row1_col3" class="data row1 col3" >gravier</td>
#       <td id="T_e1d70_row1_col4" class="data row1 col4" >élévée</td>
#       <td id="T_e1d70_row1_col5" class="data row1 col5" >urbain</td>
#       <td id="T_e1d70_row1_col6" class="data row1 col6" >100 - 500m</td>
#     </tr>
#     <tr>
#       <th id="T_e1d70_level0_row2" class="row_heading level0 row2" >96</th>
#       <td id="T_e1d70_row2_col0" class="data row2 col0" >Savonnière</td>
#       <td id="T_e1d70_row2_col1" class="data row2 col1" >NO</td>
#       <td id="T_e1d70_row2_col2" class="data row2 col2" >ligne-d'eau</td>
#       <td id="T_e1d70_row2_col3" class="data row2 col3" >galet</td>
#       <td id="T_e1d70_row2_col4" class="data row2 col4" >élévée</td>
#       <td id="T_e1d70_row2_col5" class="data row2 col5" >campagne</td>
#       <td id="T_e1d70_row2_col6" class="data row2 col6" >< 100m</td>
#     </tr>
#     <tr>
#       <th id="T_e1d70_level0_row3" class="row_heading level0 row3" >126</th>
#       <td id="T_e1d70_row3_col0" class="data row3 col0" >Grangettes</td>
#       <td id="T_e1d70_row3_col1" class="data row3 col1" >NO</td>
#       <td id="T_e1d70_row3_col2" class="data row3 col2" >ligne-d'eau</td>
#       <td id="T_e1d70_row3_col3" class="data row3 col3" >sable fin</td>
#       <td id="T_e1d70_row3_col4" class="data row3 col4" >moyenne</td>
#       <td id="T_e1d70_row3_col5" class="data row3 col5" >campagne</td>
#       <td id="T_e1d70_row3_col6" class="data row3 col6" >100 - 500m</td>
#     </tr>
#     <tr>
#       <th id="T_e1d70_level0_row4" class="row_heading level0 row4" >139</th>
#       <td id="T_e1d70_row4_col0" class="data row4 col0" >Pichette</td>
#       <td id="T_e1d70_row4_col1" class="data row4 col1" >SSE</td>
#       <td id="T_e1d70_row4_col2" class="data row4 col2" >ligne-d'eau</td>
#       <td id="T_e1d70_row4_col3" class="data row4 col3" >gravier</td>
#       <td id="T_e1d70_row4_col4" class="data row4 col4" >moyenne</td>
#       <td id="T_e1d70_row4_col5" class="data row4 col5" >campagne</td>
#       <td id="T_e1d70_row4_col6" class="data row4 col6" >< 100m</td>
#     </tr>
#     <tr>
#       <th id="T_e1d70_level0_row5" class="row_heading level0 row5" >144</th>
#       <td id="T_e1d70_row5_col0" class="data row5 col0" >Préverenges</td>
#       <td id="T_e1d70_row5_col1" class="data row5 col1" >SO</td>
#       <td id="T_e1d70_row5_col2" class="data row5 col2" >ligne-d'eau</td>
#       <td id="T_e1d70_row5_col3" class="data row5 col3" >sable fin</td>
#       <td id="T_e1d70_row5_col4" class="data row5 col4" >élévée</td>
#       <td id="T_e1d70_row5_col5" class="data row5 col5" >campagne</td>
#       <td id="T_e1d70_row5_col6" class="data row5 col6" >100 - 500m</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Compte moyen par échantillon et plage

# %%
sample_totals = work_data.groupby(["Plage","echantillon"], as_index=False).compte.sum()
df2 = sample_totals.copy()
value_column = "moyenne"

summary_comptes = sample_totals.compte.describe()

summary_comptes_display =  translate_describe(summary_comptes, "compte").style.set_table_styles(table_css_styles).format(precision=2)
summary_comptes_display.set_caption("Valeurs récapitulatives des totaux des échantillons.")
# Out:
# <style type="text/css">
# #T_47701 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_47701 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_47701 tr {
#   font-size: 14px;
# }
# #T_47701 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_47701 caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# </style>
# <table id="T_47701">
#   <caption>Valeurs récapitulatives des totaux des échantillons.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47701_level0_col0" class="col_heading level0 col0" >compte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47701_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_47701_row0_col0" class="data row0 col0" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_47701_level0_row1" class="row_heading level0 row1" >25%</th>
#       <td id="T_47701_row1_col0" class="data row1 col0" >70.00</td>
#     </tr>
#     <tr>
#       <th id="T_47701_level0_row2" class="row_heading level0 row2" >50%</th>
#       <td id="T_47701_row2_col0" class="data row2 col0" >121.00</td>
#     </tr>
#     <tr>
#       <th id="T_47701_level0_row3" class="row_heading level0 row3" >75%</th>
#       <td id="T_47701_row3_col0" class="data row3 col0" >198.00</td>
#     </tr>
#     <tr>
#       <th id="T_47701_level0_row4" class="row_heading level0 row4" >max</th>
#       <td id="T_47701_row4_col0" class="data row4 col0" >2991.00</td>
#     </tr>
#     <tr>
#       <th id="T_47701_level0_row5" class="row_heading level0 row5" >moyenne</th>
#       <td id="T_47701_row5_col0" class="data row5 col0" >180.13</td>
#     </tr>
#     <tr>
#       <th id="T_47701_level0_row6" class="row_heading level0 row6" >écart-type</th>
#       <td id="T_47701_row6_col0" class="data row6 col0" >267.62</td>
#     </tr>
#   </tbody>
# </table>

# %%
sample_averages = df2.groupby("Plage", as_index=False).agg({"echantillon": "nunique", "compte":"mean"})
average_of_sample_totals = df2.compte.mean()
sample_averages.rename(columns={"compte":value_column}, inplace=True)
sample_averages.set_index("Plage", inplace=True, drop=True)
sample_averages.index.name = None

select_values = sample_averages[value_column] > average_of_sample_totals
test_two = sample_averages.loc[select_values].index
caption_one = "Nombre cumulé d'échantillons et total moyen de d'échantillon par plage."
caption_two = " Les plages dont la moyenne des résultats est supérieur à la moyenne par échantillon du projet sont en rouge."
caption_three = f"Moyenne du projet: {round(average_of_sample_totals, 2)}"
caption = f'{caption_one} {caption_two} {caption_three}'

sa = sample_averages.style.set_table_styles(table_css_styles).set_caption(caption).format(precision=2)
sa.set_properties(subset = pd.IndexSlice[test_two,[value_column]], **a_property)
# Out:
# <style type="text/css">
# #T_75b1f tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_75b1f tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_75b1f tr {
#   font-size: 14px;
# }
# #T_75b1f th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_75b1f caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# #T_75b1f_row10_col1, #T_75b1f_row12_col1, #T_75b1f_row15_col1, #T_75b1f_row16_col1, #T_75b1f_row17_col1, #T_75b1f_row20_col1 {
#   color: red;
# }
# </style>
# <table id="T_75b1f">
#   <caption>Nombre cumulé d'échantillons et total moyen de d'échantillon par plage.  Les plages dont la moyenne des résultats est supérieur à la moyenne par échantillon du projet sont en rouge. Moyenne du projet: 180.13</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75b1f_level0_col0" class="col_heading level0 col0" >echantillon</th>
#       <th id="T_75b1f_level0_col1" class="col_heading level0 col1" >moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75b1f_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_75b1f_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_75b1f_row0_col1" class="data row0 col1" >125.00</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_75b1f_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_75b1f_row1_col1" class="data row1 col1" >114.17</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_75b1f_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_75b1f_row2_col1" class="data row2 col1" >94.62</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_75b1f_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_75b1f_row3_col1" class="data row3 col1" >117.09</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_75b1f_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_75b1f_row4_col1" class="data row4 col1" >176.17</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_75b1f_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_75b1f_row5_col1" class="data row5 col1" >69.17</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_75b1f_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_75b1f_row6_col1" class="data row6 col1" >19.00</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_75b1f_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_75b1f_row7_col1" class="data row7 col1" >64.00</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_75b1f_row8_col0" class="data row8 col0" >28</td>
#       <td id="T_75b1f_row8_col1" class="data row8 col1" >134.82</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_75b1f_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_75b1f_row9_col1" class="data row9 col1" >40.00</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_75b1f_row10_col0" class="data row10 col0" >6</td>
#       <td id="T_75b1f_row10_col1" class="data row10 col1" >418.33</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_75b1f_row11_col0" class="data row11 col0" >9</td>
#       <td id="T_75b1f_row11_col1" class="data row11 col1" >167.78</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row12" class="row_heading level0 row12" >Lugrin</th>
#       <td id="T_75b1f_row12_col0" class="data row12 col0" >5</td>
#       <td id="T_75b1f_row12_col1" class="data row12 col1" >214.60</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row13" class="row_heading level0 row13" >Lutry</th>
#       <td id="T_75b1f_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_75b1f_row13_col1" class="data row13 col1" >142.86</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row14" class="row_heading level0 row14" >Meillerie</th>
#       <td id="T_75b1f_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_75b1f_row14_col1" class="data row14 col1" >57.00</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row15" class="row_heading level0 row15" >Pichette</th>
#       <td id="T_75b1f_row15_col0" class="data row15 col0" >5</td>
#       <td id="T_75b1f_row15_col1" class="data row15 col1" >753.20</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row16" class="row_heading level0 row16" >Port Choiseul</th>
#       <td id="T_75b1f_row16_col0" class="data row16 col0" >9</td>
#       <td id="T_75b1f_row16_col1" class="data row16 col1" >436.56</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row17" class="row_heading level0 row17" >Préverenges</th>
#       <td id="T_75b1f_row17_col0" class="data row17 col0" >23</td>
#       <td id="T_75b1f_row17_col1" class="data row17 col1" >211.57</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row18" class="row_heading level0 row18" >Rolle</th>
#       <td id="T_75b1f_row18_col0" class="data row18 col0" >21</td>
#       <td id="T_75b1f_row18_col1" class="data row18 col1" >153.76</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row19" class="row_heading level0 row19" >Saint-Disdille</th>
#       <td id="T_75b1f_row19_col0" class="data row19 col0" >6</td>
#       <td id="T_75b1f_row19_col1" class="data row19 col1" >179.83</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row20" class="row_heading level0 row20" >Savonnière</th>
#       <td id="T_75b1f_row20_col0" class="data row20 col0" >8</td>
#       <td id="T_75b1f_row20_col1" class="data row20 col1" >259.50</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row21" class="row_heading level0 row21" >Tolochenaz</th>
#       <td id="T_75b1f_row21_col0" class="data row21 col0" >4</td>
#       <td id="T_75b1f_row21_col1" class="data row21 col1" >95.75</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row22" class="row_heading level0 row22" >Tougues</th>
#       <td id="T_75b1f_row22_col0" class="data row22 col0" >11</td>
#       <td id="T_75b1f_row22_col1" class="data row22 col1" >107.09</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row23" class="row_heading level0 row23" >Versoix</th>
#       <td id="T_75b1f_row23_col0" class="data row23 col0" >4</td>
#       <td id="T_75b1f_row23_col1" class="data row23 col1" >99.75</td>
#     </tr>
#     <tr>
#       <th id="T_75b1f_level0_row24" class="row_heading level0 row24" >Vidy</th>
#       <td id="T_75b1f_row24_col0" class="data row24 col0" >13</td>
#       <td id="T_75b1f_row24_col1" class="data row24 col1" >120.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(2,2, figsize=(7,7))

sns.scatterplot(data=sample_totals, x="echantillon", y="compte", ax=ax[0,0])
ax[0,0].tick_params(labelbottom=False, bottom=False)
ax[0,0].set_ylim(-1, 1500)
ax[0,0].set_title("Total par échantillon", loc="left")

sns.boxplot(data=sample_totals, y="compte", dodge=False, width=.9, ax=ax[0,1])
ax[0,1].set_ylim(-1, 1500)
ax[0,1].set_title("boîte de Tukey", loc="left")

sns.histplot(data=sample_totals, x="compte", ax=ax[1,0], stat="probability")
ax[1,0].set_xlim(-1, 1500)
ax[1,0].yaxis.set_major_formatter('{x:.2f}')
ax[1,0].set_ylabel("probabilité")
ax[1,0].set_title("Histogramme", loc="left")

sns.ecdfplot(data=sample_totals, x="compte", ax=ax[1,1])
ax[1,1].set_xlim(-1, 1500)
ax[1,1].set_ylabel("probabilité")
ax[1,1].set_title("Fonction de répartition", loc="left")
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Comptes moyenne par position

# %%
position_totals = work_data.groupby(["Plage","echantillon", "position"], as_index=False).compte.sum()
position_totals["position"] = position_totals.position.apply(lambda x: name_the_zones[x])
# position_totals["objet"] = position_totals.objet.apply(lambda x: particle_groups[x])
df4 = position_totals.groupby(["Plage","position"], as_index=False).compte.mean()

df4 = df4.pivot(index="Plage", columns=["position"])
df4.index.name = None
df4.columns
df4.fillna(0, inplace=True)

caption_one = "Le résultat moyen de d’échantillon par position."
caption_two = "Les plages dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge."
caption_three = f"Moyenne du projet: {round(average_of_sample_totals, 2)}"
caption = f"{caption_one} {caption_two} {caption_three}"

def select_a_set_of_values(data, column_one, threshold_data):
    
    return data.loc[data[column_one] > threshold_data]

position_columns = list(name_the_zones.values())
fragment_columns = list(particle_groups.values())

args = [("compte", x) for x in position_columns]



water_line = select_a_set_of_values(df4, args[0], average_of_sample_totals).index
plage_seche = select_a_set_of_values(df4, args[1], average_of_sample_totals).index

sax = df4.style.set_table_styles(table_css_styles).set_caption(caption).format(precision=2)
 
sax = sax.set_properties(subset = pd.IndexSlice[water_line,args[0]], **a_property)
sax = sax.set_properties(subset = pd.IndexSlice[plage_seche,args[1]], **a_property)

position_sample_totals = position_totals.groupby(["echantillon", "Plage", "position"], as_index=False).compte.sum()

summary_ligne_deau = position_sample_totals[position_sample_totals.position == "ligne-d'eau"].compte.describe()
summary_plage_seche = position_sample_totals[position_sample_totals.position == "plage-seche"].compte.describe()

ligne_deau_display =  translate_describe(summary_ligne_deau, "compte ligne d'eau").style.set_table_styles(table_css_styles).format(precision=2)
plage_seche_display =  translate_describe(summary_plage_seche, "compte plage-seche").style.set_table_styles(table_css_styles).format(precision=2)

glue("summary_ligne_deau", ligne_deau_display, display=False)
glue("summary_plage_seche", plage_seche_display, display=False)

# %% [markdown]
# |Ligne d'eau|Plage seche|
# |:----------:|:----------:|
# |{glue:}`summary_ligne_deau`|{glue:}`summary_plage_seche`|

# %%
sax
# Out:
# <style type="text/css">
# #T_25999 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_25999 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_25999 tr {
#   font-size: 14px;
# }
# #T_25999 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_25999 caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# #T_25999_row4_col1, #T_25999_row10_col0, #T_25999_row10_col1, #T_25999_row11_col1, #T_25999_row12_col1, #T_25999_row13_col1, #T_25999_row15_col1, #T_25999_row16_col1, #T_25999_row17_col0, #T_25999_row17_col1, #T_25999_row20_col1 {
#   color: red;
# }
# </style>
# <table id="T_25999">
#   <caption>Le résultat moyen de d’échantillon par position. Les plages dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge. Moyenne du projet: 180.13</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25999_level0_col0" class="col_heading level0 col0" colspan="2">compte</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >position</th>
#       <th id="T_25999_level1_col0" class="col_heading level1 col0" >ligne-d'eau</th>
#       <th id="T_25999_level1_col1" class="col_heading level1 col1" >plage-seche</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25999_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_25999_row0_col0" class="data row0 col0" >111.50</td>
#       <td id="T_25999_row0_col1" class="data row0 col1" >134.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_25999_row1_col0" class="data row1 col0" >55.33</td>
#       <td id="T_25999_row1_col1" class="data row1 col1" >173.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_25999_row2_col0" class="data row2 col0" >62.80</td>
#       <td id="T_25999_row2_col1" class="data row2 col1" >147.67</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_25999_row3_col0" class="data row3 col0" >69.00</td>
#       <td id="T_25999_row3_col1" class="data row3 col1" >157.17</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_25999_row4_col0" class="data row4 col0" >90.86</td>
#       <td id="T_25999_row4_col1" class="data row4 col1" >295.60</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_25999_row5_col0" class="data row5 col0" >54.25</td>
#       <td id="T_25999_row5_col1" class="data row5 col1" >99.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_25999_row6_col0" class="data row6 col0" >19.00</td>
#       <td id="T_25999_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_25999_row7_col0" class="data row7 col0" >128.00</td>
#       <td id="T_25999_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_25999_row8_col0" class="data row8 col0" >102.29</td>
#       <td id="T_25999_row8_col1" class="data row8 col1" >145.67</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_25999_row9_col0" class="data row9 col0" >40.00</td>
#       <td id="T_25999_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_25999_row10_col0" class="data row10 col0" >419.75</td>
#       <td id="T_25999_row10_col1" class="data row10 col1" >415.50</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_25999_row11_col0" class="data row11 col0" >66.50</td>
#       <td id="T_25999_row11_col1" class="data row11 col1" >248.80</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row12" class="row_heading level0 row12" >Lugrin</th>
#       <td id="T_25999_row12_col0" class="data row12 col0" >111.00</td>
#       <td id="T_25999_row12_col1" class="data row12 col1" >370.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row13" class="row_heading level0 row13" >Lutry</th>
#       <td id="T_25999_row13_col0" class="data row13 col0" >77.00</td>
#       <td id="T_25999_row13_col1" class="data row13 col1" >230.67</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row14" class="row_heading level0 row14" >Meillerie</th>
#       <td id="T_25999_row14_col0" class="data row14 col0" >57.00</td>
#       <td id="T_25999_row14_col1" class="data row14 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row15" class="row_heading level0 row15" >Pichette</th>
#       <td id="T_25999_row15_col0" class="data row15 col0" >72.00</td>
#       <td id="T_25999_row15_col1" class="data row15 col1" >1775.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row16" class="row_heading level0 row16" >Port Choiseul</th>
#       <td id="T_25999_row16_col0" class="data row16 col0" >64.00</td>
#       <td id="T_25999_row16_col1" class="data row16 col1" >1181.67</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row17" class="row_heading level0 row17" >Préverenges</th>
#       <td id="T_25999_row17_col0" class="data row17 col0" >242.30</td>
#       <td id="T_25999_row17_col1" class="data row17 col1" >187.92</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row18" class="row_heading level0 row18" >Rolle</th>
#       <td id="T_25999_row18_col0" class="data row18 col0" >125.10</td>
#       <td id="T_25999_row18_col1" class="data row18 col1" >179.82</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row19" class="row_heading level0 row19" >Saint-Disdille</th>
#       <td id="T_25999_row19_col0" class="data row19 col0" >179.83</td>
#       <td id="T_25999_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row20" class="row_heading level0 row20" >Savonnière</th>
#       <td id="T_25999_row20_col0" class="data row20 col0" >130.00</td>
#       <td id="T_25999_row20_col1" class="data row20 col1" >337.20</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row21" class="row_heading level0 row21" >Tolochenaz</th>
#       <td id="T_25999_row21_col0" class="data row21 col0" >95.75</td>
#       <td id="T_25999_row21_col1" class="data row21 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row22" class="row_heading level0 row22" >Tougues</th>
#       <td id="T_25999_row22_col0" class="data row22 col0" >67.67</td>
#       <td id="T_25999_row22_col1" class="data row22 col1" >154.40</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row23" class="row_heading level0 row23" >Versoix</th>
#       <td id="T_25999_row23_col0" class="data row23 col0" >99.33</td>
#       <td id="T_25999_row23_col1" class="data row23 col1" >101.00</td>
#     </tr>
#     <tr>
#       <th id="T_25999_level0_row24" class="row_heading level0 row24" >Vidy</th>
#       <td id="T_25999_row24_col0" class="data row24 col0" >78.17</td>
#       <td id="T_25999_row24_col1" class="data row24 col1" >156.29</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(2,2, figsize=(7,7))

d_position = position_totals.groupby(["echantillon", "position"], as_index=False).compte.sum()

sns.scatterplot(data=d_position, x="echantillon", y="compte", hue="position", ax=ax[0,0])
ax[0,0].tick_params(labelbottom=False, bottom=False)
ax[0,0].set_ylim(-1, 1000)
ax[0,0].set_title("Total par échantillon", loc="left")
ax[0,0].legend().remove()

sns.boxplot(data=d_position, x="position", y="compte", hue="position", dodge=False, width=.9, ax=ax[0,1])
ax[0,1].set_ylim(-1, 1000)
ax[0,1].set_title("Boîte de Tukey", loc="left")
ax[0,1].set_xlabel("")
ax[0,1].legend().remove()

sns.histplot(data=d_position, x="compte", hue="position", ax=ax[1,0], multiple="stack", stat="probability")
ax[1,0].set_xlim(-10, 1000)
ax[1,0].yaxis.set_major_formatter('{x:.2f}')
ax[1,0].set_ylabel("probabilité")
ax[1,0].set_title("Histogramme", loc="left")



sns.ecdfplot(data=d_position, x="compte", hue="position", ax=ax[1,1])
ax[1,1].set_xlim(-1, 1000)
ax[1,1].set_ylabel("probabilité")
ax[1,1].set_title("Fonction de répartition", loc="left")

plt.tight_layout()


plt.show()

# %% [markdown]
# ### Nombre moyen par texture et plage

# %%
texture_totals = work_data.groupby(["Plage","echantillon", "objet"], as_index=False).compte.sum()
df3 = texture_totals.copy()

texture_averages = df3.groupby(["Plage", "objet"], as_index=False).agg({"compte":"mean"})
texture_averages.rename(columns={"compte":value_column}, inplace=True)
average_of_sample_textures = df3.groupby(["objet"], as_index=True).agg({"compte":"mean"})
average_of_sample_textures.rename(columns={"compte":value_column}, inplace=True)
average_of_sample_textures.index.name = None
caption = "La moyenne de l'échantillon du projet par type d'objet"
average_of_sample_textures.style.format(precision=2).set_table_styles(table_css_styles).set_caption(caption)
# Out:
# <style type="text/css">
# #T_b5333 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_b5333 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_b5333 tr {
#   font-size: 14px;
# }
# #T_b5333 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_b5333 caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# </style>
# <table id="T_b5333">
#   <caption>La moyenne de l'échantillon du projet par type d'objet</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5333_level0_col0" class="col_heading level0 col0" >moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5333_level0_row0" class="row_heading level0 row0" >fdure</th>
#       <td id="T_b5333_row0_col0" class="data row0 col0" >23.53</td>
#     </tr>
#     <tr>
#       <th id="T_b5333_level0_row1" class="row_heading level0 row1" >fibres</th>
#       <td id="T_b5333_row1_col0" class="data row1 col0" >137.83</td>
#     </tr>
#     <tr>
#       <th id="T_b5333_level0_row2" class="row_heading level0 row2" >souple</th>
#       <td id="T_b5333_row2_col0" class="data row2 col0" >18.78</td>
#     </tr>
#   </tbody>
# </table>

# %%
tex_dure = texture_totals[texture_totals.objet=="fdure"].compte.describe()
rigid_display = translate_describe(tex_dure, "fragments rigides").style.set_table_styles(table_css_styles).format(precision=2)

tex_souple = texture_totals[texture_totals.objet=="souple"].compte.describe()
souple_display = translate_describe(tex_dure, "fragments souple").style.set_table_styles(table_css_styles).format(precision=2)

tex_fibres = texture_totals[texture_totals.objet=="fibre"].compte.describe()
fibres_display = translate_describe(tex_dure, "fibres").style.set_table_styles(table_css_styles).format(precision=2)

# %%
glue("rigid_display", rigid_display, display=False)
glue("souple_display", souple_display, display=False)
glue("fibres_display", fibres_display, display=False)

# %% [markdown]
# |Fragments rigides|Fragments souples|Fibres|
# |:----------------:|:----------------:|:----------:|
# |{glue:}`rigid_display`|{glue:}`souple_display`|{glue:}`fibres_display`|

# %%
texture_averages = texture_averages.pivot(index="Plage", columns="objet").droplevel(0, axis=1)
texture_averages.index.name = None
texture_averages.rename(columns=particle_groups, inplace=True)

select_fdure_values = texture_averages["fragment rigide"] > average_of_sample_textures.loc["fdure", value_column]
select_souple_values = texture_averages["fragment souple"] > average_of_sample_textures.loc["souple", value_column]
select_fiber_vales = texture_averages["fibre"] > average_of_sample_textures.loc["fibres", value_column]


test_three = texture_averages.loc[select_fdure_values].index
test_four = texture_averages.loc[select_souple_values].index
test_five = texture_averages.loc[select_fiber_vales].index

caption_one = "Le nombre moyen par échantillon par plage et texture."
caption = f"{caption_one} {caption_two}"

sa = texture_averages.style.set_table_styles(table_css_styles).set_caption(caption).format(precision=2)
# sa.background_gradient(axis=None)
sa = sa.set_properties(subset = pd.IndexSlice[test_three,["fragment rigide"]], **a_property)
sa = sa.set_properties(subset = pd.IndexSlice[test_four,["fragment souple"]], **a_property)
sa = sa.set_properties(subset = pd.IndexSlice[test_five,["fibre"]], **a_property)

sa
# Out:
# <style type="text/css">
# #T_0e693 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_0e693 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_0e693 tr {
#   font-size: 14px;
# }
# #T_0e693 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_0e693 caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# #T_0e693_row4_col1, #T_0e693_row10_col1, #T_0e693_row10_col2, #T_0e693_row11_col1, #T_0e693_row12_col1, #T_0e693_row12_col2, #T_0e693_row14_col0, #T_0e693_row15_col0, #T_0e693_row15_col1, #T_0e693_row16_col0, #T_0e693_row16_col1, #T_0e693_row17_col0, #T_0e693_row17_col1, #T_0e693_row17_col2, #T_0e693_row18_col0, #T_0e693_row19_col1, #T_0e693_row20_col1, #T_0e693_row20_col2 {
#   color: red;
# }
# </style>
# <table id="T_0e693">
#   <caption>Le nombre moyen par échantillon par plage et texture. Les plages dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >objet</th>
#       <th id="T_0e693_level0_col0" class="col_heading level0 col0" >fragment rigide</th>
#       <th id="T_0e693_level0_col1" class="col_heading level0 col1" >fibre</th>
#       <th id="T_0e693_level0_col2" class="col_heading level0 col2" >fragment souple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e693_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_0e693_row0_col0" class="data row0 col0" >7.90</td>
#       <td id="T_0e693_row0_col1" class="data row0 col1" >110.00</td>
#       <td id="T_0e693_row0_col2" class="data row0 col2" >7.10</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_0e693_row1_col0" class="data row1 col0" >9.17</td>
#       <td id="T_0e693_row1_col1" class="data row1 col1" >91.67</td>
#       <td id="T_0e693_row1_col2" class="data row1 col2" >13.33</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_0e693_row2_col0" class="data row2 col0" >11.88</td>
#       <td id="T_0e693_row2_col1" class="data row2 col1" >70.12</td>
#       <td id="T_0e693_row2_col2" class="data row2 col2" >12.62</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_0e693_row3_col0" class="data row3 col0" >12.00</td>
#       <td id="T_0e693_row3_col1" class="data row3 col1" >98.09</td>
#       <td id="T_0e693_row3_col2" class="data row3 col2" >7.00</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_0e693_row4_col0" class="data row4 col0" >13.75</td>
#       <td id="T_0e693_row4_col1" class="data row4 col1" >147.25</td>
#       <td id="T_0e693_row4_col2" class="data row4 col2" >15.17</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_0e693_row5_col0" class="data row5 col0" >6.33</td>
#       <td id="T_0e693_row5_col1" class="data row5 col1" >57.50</td>
#       <td id="T_0e693_row5_col2" class="data row5 col2" >5.33</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_0e693_row6_col0" class="data row6 col0" >2.00</td>
#       <td id="T_0e693_row6_col1" class="data row6 col1" >17.00</td>
#       <td id="T_0e693_row6_col2" class="data row6 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_0e693_row7_col0" class="data row7 col0" >5.50</td>
#       <td id="T_0e693_row7_col1" class="data row7 col1" >58.50</td>
#       <td id="T_0e693_row7_col2" class="data row7 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_0e693_row8_col0" class="data row8 col0" >19.39</td>
#       <td id="T_0e693_row8_col1" class="data row8 col1" >97.14</td>
#       <td id="T_0e693_row8_col2" class="data row8 col2" >18.29</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_0e693_row9_col0" class="data row9 col0" >8.00</td>
#       <td id="T_0e693_row9_col1" class="data row9 col1" >26.00</td>
#       <td id="T_0e693_row9_col2" class="data row9 col2" >6.00</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_0e693_row10_col0" class="data row10 col0" >7.83</td>
#       <td id="T_0e693_row10_col1" class="data row10 col1" >234.17</td>
#       <td id="T_0e693_row10_col2" class="data row10 col2" >176.33</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_0e693_row11_col0" class="data row11 col0" >6.67</td>
#       <td id="T_0e693_row11_col1" class="data row11 col1" >153.56</td>
#       <td id="T_0e693_row11_col2" class="data row11 col2" >7.56</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row12" class="row_heading level0 row12" >Lugrin</th>
#       <td id="T_0e693_row12_col0" class="data row12 col0" >9.80</td>
#       <td id="T_0e693_row12_col1" class="data row12 col1" >184.60</td>
#       <td id="T_0e693_row12_col2" class="data row12 col2" >20.20</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row13" class="row_heading level0 row13" >Lutry</th>
#       <td id="T_0e693_row13_col0" class="data row13 col0" >5.29</td>
#       <td id="T_0e693_row13_col1" class="data row13 col1" >130.14</td>
#       <td id="T_0e693_row13_col2" class="data row13 col2" >7.43</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row14" class="row_heading level0 row14" >Meillerie</th>
#       <td id="T_0e693_row14_col0" class="data row14 col0" >26.00</td>
#       <td id="T_0e693_row14_col1" class="data row14 col1" >26.00</td>
#       <td id="T_0e693_row14_col2" class="data row14 col2" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row15" class="row_heading level0 row15" >Pichette</th>
#       <td id="T_0e693_row15_col0" class="data row15 col0" >103.60</td>
#       <td id="T_0e693_row15_col1" class="data row15 col1" >632.40</td>
#       <td id="T_0e693_row15_col2" class="data row15 col2" >17.20</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row16" class="row_heading level0 row16" >Port Choiseul</th>
#       <td id="T_0e693_row16_col0" class="data row16 col0" >118.56</td>
#       <td id="T_0e693_row16_col1" class="data row16 col1" >308.89</td>
#       <td id="T_0e693_row16_col2" class="data row16 col2" >9.11</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row17" class="row_heading level0 row17" >Préverenges</th>
#       <td id="T_0e693_row17_col0" class="data row17 col0" >30.39</td>
#       <td id="T_0e693_row17_col1" class="data row17 col1" >142.22</td>
#       <td id="T_0e693_row17_col2" class="data row17 col2" >38.96</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row18" class="row_heading level0 row18" >Rolle</th>
#       <td id="T_0e693_row18_col0" class="data row18 col0" >40.71</td>
#       <td id="T_0e693_row18_col1" class="data row18 col1" >109.86</td>
#       <td id="T_0e693_row18_col2" class="data row18 col2" >3.19</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row19" class="row_heading level0 row19" >Saint-Disdille</th>
#       <td id="T_0e693_row19_col0" class="data row19 col0" >20.17</td>
#       <td id="T_0e693_row19_col1" class="data row19 col1" >150.83</td>
#       <td id="T_0e693_row19_col2" class="data row19 col2" >8.83</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row20" class="row_heading level0 row20" >Savonnière</th>
#       <td id="T_0e693_row20_col0" class="data row20 col0" >20.50</td>
#       <td id="T_0e693_row20_col1" class="data row20 col1" >203.25</td>
#       <td id="T_0e693_row20_col2" class="data row20 col2" >35.75</td>
#     </tr>
#     <tr>
#       <th id="T_0e693_level0_row21" class="row_heading level0 row21" >Tolochenaz</th>
#       <td id="T_0e693_row21_col0" class="data row21 col0" >4.25</td>
#       <td id="T_0e693_row21_col1" class="data row21 col1"

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8))

d_position = position_totals.groupby(["echantillon", "position"], as_index=False).compte.sum()

sns.scatterplot(data=df3, x="echantillon", y="compte", hue="objet", ax=ax[0,0])
ax[0,0].tick_params(labelbottom=False, bottom=False)
ax[0,0].set_ylim(-1, 1000)
ax[0,0].set_title("Total par échantillon", loc="left")
# ax[0,0].legend().remove()

sns.boxplot(data=df3, x="objet", y="compte", hue="objet", dodge=False, width=.9, ax=ax[0,1])
ax[0,1].set_ylim(-1, 1000)
ax[0,1].set_title("Boîte de Tukey", loc="left")
ax[0,1].set_xlabel("")
ax[0,1].legend().remove()

sns.histplot(data=df3, x="compte", hue="objet", ax=ax[1,0], multiple="stack", stat="probability")
ax[1,0].set_xlim(-10, 600)
ax[1,0].yaxis.set_major_formatter('{x:.2f}')
ax[1,0].set_ylabel("probabilité")
ax[1,0].set_title("Histogramme", loc="left")



sns.ecdfplot(data=df3, x="compte", hue="objet", ax=ax[1,1])
ax[1,1].set_xlim(-1, 600)
ax[1,1].set_ylabel("probabilité")
ax[1,1].set_title("Fonction de répartition", loc="left")

plt.tight_layout()


plt.show()

# %% [markdown]
# ### Nombre moyen par texture et position

# %%
position_totals = work_data.groupby(["Plage","echantillon", "position", "objet"], as_index=False).compte.sum()
position_totals["position"] = position_totals.position.apply(lambda x: name_the_zones[x])
position_totals["objet"] = position_totals.objet.apply(lambda x: particle_groups[x])


# summaries

leau_dure = position_totals[(position_totals.position == "ligne-d'eau") & (position_totals.objet == "fragment rigide")].compte.describe()
leau_souple = position_totals[(position_totals.position == "ligne-d'eau") & (position_totals.objet == "fragment souple")].compte.describe()
leau_fibre = position_totals[(position_totals.position == "ligne-d'eau") & (position_totals.objet == "fibre")].compte.describe()

leau_dure_d = translate_describe(leau_dure, "Fragments rigides").style.set_table_styles(table_css_styles).format(precision=2)
leau_souple_d = translate_describe(leau_souple, "Fragments souples").style.set_table_styles(table_css_styles).format(precision=2)
leau_fibre_d = translate_describe(leau_fibre, "Fibres").style.set_table_styles(table_css_styles).format(precision=2)
glue("leau_dure_display", leau_dure_d, display=False)
glue("leau_souple_display", leau_souple_d, display=False)
glue("leau_fibre_display", leau_fibre_d, display=False)

# %% [markdown]
# |ligne d'eau|ligne d'eau|ligne d'eau|
# |:----------:|:----------:|:----------:|
# |{glue:}`leau_dure_display`|{glue:}`leau_souple_display`|{glue:}`leau_fibre_display`|

# %%
plage_dure = position_totals[(position_totals.position == "plage-seche") & (position_totals.objet == "fragment rigide")].compte.describe()
plage_souple = position_totals[(position_totals.position == "plage-seche") & (position_totals.objet == "fragment souple")].compte.describe()
plage_fibre = position_totals[(position_totals.position == "plage-seche") & (position_totals.objet == "fibre")].compte.describe()

plage_dure_d = translate_describe(plage_dure, "Fragments rigides").style.set_table_styles(table_css_styles).format(precision=2)
plage_souple_d = translate_describe(plage_souple, "Fragments souples").style.set_table_styles(table_css_styles).format(precision=2)
plage_fibre_d = translate_describe(plage_fibre, "Fibres").style.set_table_styles(table_css_styles).format(precision=2)
glue("plage_dure_display", plage_dure_d, display=False)
glue("plage_souple_display", plage_souple_d, display=False)
glue("plage_fibre_display", plage_fibre_d, display=False)

# %% [markdown]
# |plage-seche|plage-seche|plage-seche|
# |:----------:|:----------:|:----------:|
# |{glue:}`plage_dure_display`|{glue:}`plage_souple_display`|{glue:}`plage_fibre_display`|

# %%
df4 = position_totals.groupby(["Plage","position", "objet"], as_index=False).compte.mean()

df4 = df4.pivot(index="Plage", columns=["position", "objet"])
df4.index.name = None
df4.columns
# df4.fillna(0, inplace=True)

def select_a_set_of_values(data, column_one, search_index, search_value, average_of_sample_textures):
    
    return data.loc[data[column_one] > average_of_sample_textures.loc[search_index, search_value]]

args_one = [("compte", position_columns[0], x) for x in fragment_columns]
args_two = [("compte", position_columns[1], x) for x in fragment_columns]

args_0 = select_a_set_of_values(df4, args_one[0], list(particle_groups.keys())[0], value_column, average_of_sample_textures).index
args_1 = select_a_set_of_values(df4, args_one[1], list(particle_groups.keys())[1], value_column, average_of_sample_textures).index
args_2  = select_a_set_of_values(df4, args_one[2], list(particle_groups.keys())[2], value_column, average_of_sample_textures).index

args_2_0 = select_a_set_of_values(df4, args_two[0], list(particle_groups.keys())[0], value_column, average_of_sample_textures).index
args_2_1 = select_a_set_of_values(df4, args_two[1], list(particle_groups.keys())[1], value_column, average_of_sample_textures).index
args_2_2 = select_a_set_of_values(df4, args_two[2], list(particle_groups.keys())[2], value_column, average_of_sample_textures).index

sax = df4.style.set_table_styles(table_css_styles).set_caption(caption).format(precision=2)
  
sax = sax.set_properties(subset = pd.IndexSlice[args_2, args_one[2]],**a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_1,args_one[1]],**a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_0,args_one[0]], **a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_2_2, args_two[2]], **a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_2_1,args_two[1]],**a_property)
sax = sax.set_properties(subset = pd.IndexSlice[args_2_0,args_two[0]], **a_property)

sax
# Out:
# <style type="text/css">
# #T_457cc tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_457cc tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_457cc tr {
#   font-size: 14px;
# }
# #T_457cc th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_457cc caption {
#   caption-side: bottom;
#   font-size: 16px;
#   text-align: left;
#   margin-top: 15px;
# }
# #T_457cc_row1_col3, #T_457cc_row1_col5, #T_457cc_row2_col5, #T_457cc_row4_col3, #T_457cc_row4_col5, #T_457cc_row8_col4, #T_457cc_row8_col5, #T_457cc_row10_col0, #T_457cc_row10_col2, #T_457cc_row10_col3, #T_457cc_row10_col5, #T_457cc_row11_col3, #T_457cc_row12_col3, #T_457cc_row12_col5, #T_457cc_row13_col3, #T_457cc_row14_col1, #T_457cc_row15_col3, #T_457cc_row15_col4, #T_457cc_row15_col5, #T_457cc_row16_col3, #T_457cc_row16_col4, #T_457cc_row16_col5, #T_457cc_row17_col1, #T_457cc_row17_col2, #T_457cc_row17_col3, #T_457cc_row18_col1, #T_457cc_row18_col4, #T_457cc_row19_col0, #T_457cc_row20_col3, #T_457cc_row20_col4, #T_457cc_row20_col5, #T_457cc_row24_col4, #T_457cc_row24_col5 {
#   color: red;
# }
# </style>
# <table id="T_457cc">
#   <caption>Le nombre moyen par échantillon par plage et texture. Les plages dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_457cc_level0_col0" class="col_heading level0 col0" colspan="6">compte</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >position</th>
#       <th id="T_457cc_level1_col0" class="col_heading level1 col0" colspan="3">ligne-d'eau</th>
#       <th id="T_457cc_level1_col3" class="col_heading level1 col3" colspan="3">plage-seche</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >objet</th>
#       <th id="T_457cc_level2_col0" class="col_heading level2 col0" >fibre</th>
#       <th id="T_457cc_level2_col1" class="col_heading level2 col1" >fragment rigide</th>
#       <th id="T_457cc_level2_col2" class="col_heading level2 col2" >fragment souple</th>
#       <th id="T_457cc_level2_col3" class="col_heading level2 col3" >fibre</th>
#       <th id="T_457cc_level2_col4" class="col_heading level2 col4" >fragment rigide</th>
#       <th id="T_457cc_level2_col5" class="col_heading level2 col5" >fragment souple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_457cc_level0_row0" class="row_heading level0 row0" >Amphion</th>
#       <td id="T_457cc_row0_col0" class="data row0 col0" >107.00</td>
#       <td id="T_457cc_row0_col1" class="data row0 col1" >1.25</td>
#       <td id="T_457cc_row0_col2" class="data row0 col2" >3.25</td>
#       <td id="T_457cc_row0_col3" class="data row0 col3" >112.00</td>
#       <td id="T_457cc_row0_col4" class="data row0 col4" >12.33</td>
#       <td id="T_457cc_row0_col5" class="data row0 col5" >9.67</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row1" class="row_heading level0 row1" >Anthy</th>
#       <td id="T_457cc_row1_col0" class="data row1 col0" >41.00</td>
#       <td id="T_457cc_row1_col1" class="data row1 col1" >7.33</td>
#       <td id="T_457cc_row1_col2" class="data row1 col2" >7.00</td>
#       <td id="T_457cc_row1_col3" class="data row1 col3" >142.33</td>
#       <td id="T_457cc_row1_col4" class="data row1 col4" >11.00</td>
#       <td id="T_457cc_row1_col5" class="data row1 col5" >19.67</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row2" class="row_heading level0 row2" >Aubonne</th>
#       <td id="T_457cc_row2_col0" class="data row2 col0" >49.60</td>
#       <td id="T_457cc_row2_col1" class="data row2 col1" >12.60</td>
#       <td id="T_457cc_row2_col2" class="data row2 col2" >0.60</td>
#       <td id="T_457cc_row2_col3" class="data row2 col3" >104.33</td>
#       <td id="T_457cc_row2_col4" class="data row2 col4" >10.67</td>
#       <td id="T_457cc_row2_col5" class="data row2 col5" >32.67</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row3" class="row_heading level0 row3" >Baby Plage</th>
#       <td id="T_457cc_row3_col0" class="data row3 col0" >63.00</td>
#       <td id="T_457cc_row3_col1" class="data row3 col1" >6.00</td>
#       <td id="T_457cc_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_457cc_row3_col3" class="data row3 col3" >127.33</td>
#       <td id="T_457cc_row3_col4" class="data row3 col4" >17.00</td>
#       <td id="T_457cc_row3_col5" class="data row3 col5" >12.83</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row4" class="row_heading level0 row4" >Bouveret</th>
#       <td id="T_457cc_row4_col0" class="data row4 col0" >75.43</td>
#       <td id="T_457cc_row4_col1" class="data row4 col1" >15.14</td>
#       <td id="T_457cc_row4_col2" class="data row4 col2" >0.29</td>
#       <td id="T_457cc_row4_col3" class="data row4 col3" >247.80</td>
#       <td id="T_457cc_row4_col4" class="data row4 col4" >11.80</td>
#       <td id="T_457cc_row4_col5" class="data row4 col5" >36.00</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row5" class="row_heading level0 row5" >Clarens</th>
#       <td id="T_457cc_row5_col0" class="data row5 col0" >48.75</td>
#       <td id="T_457cc_row5_col1" class="data row5 col1" >4.75</td>
#       <td id="T_457cc_row5_col2" class="data row5 col2" >0.75</td>
#       <td id="T_457cc_row5_col3" class="data row5 col3" >75.00</td>
#       <td id="T_457cc_row5_col4" class="data row5 col4" >9.50</td>
#       <td id="T_457cc_row5_col5" class="data row5 col5" >14.50</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row6" class="row_heading level0 row6" >Crans</th>
#       <td id="T_457cc_row6_col0" class="data row6 col0" >17.00</td>
#       <td id="T_457cc_row6_col1" class="data row6 col1" >2.00</td>
#       <td id="T_457cc_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_457cc_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_457cc_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_457cc_row6_col5" class="data row6 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row7" class="row_heading level0 row7" >Cully</th>
#       <td id="T_457cc_row7_col0" class="data row7 col0" >117.00</td>
#       <td id="T_457cc_row7_col1" class="data row7 col1" >11.00</td>
#       <td id="T_457cc_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_457cc_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_457cc_row7_col4" class="data row7 col4" >0.00</td>
#       <td id="T_457cc_row7_col5" class="data row7 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row8" class="row_heading level0 row8" >Excenevex</th>
#       <td id="T_457cc_row8_col0" class="data row8 col0" >90.86</td>
#       <td id="T_457cc_row8_col1" class="data row8 col1" >4.43</td>
#       <td id="T_457cc_row8_col2" class="data row8 col2" >7.00</td>
#       <td id="T_457cc_row8_col3" class="data row8 col3" >99.24</td>
#       <td id="T_457cc_row8_col4" class="data row8 col4" >24.38</td>
#       <td id="T_457cc_row8_col5" class="data row8 col5" >22.05</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row9" class="row_heading level0 row9" >Gland</th>
#       <td id="T_457cc_row9_col0" class="data row9 col0" >26.00</td>
#       <td id="T_457cc_row9_col1" class="data row9 col1" >8.00</td>
#       <td id="T_457cc_row9_col2" class="data row9 col2" >6.00</td>
#       <td id="T_457cc_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_457cc_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_457cc_row9_col5" class="data row9 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row10" class="row_heading level0 row10" >Grangettes</th>
#       <td id="T_457cc_row10_col0" class="data row10 col0" >163.75</td>
#       <td id="T_457cc_row10_col1" class="data row10 col1" >10.00</td>
#       <td id="T_457cc_row10_col2" class="data row10 col2" >246.00</td>
#       <td id="T_457cc_row10_col3" class="data row10 col3" >375.00</td>
#       <td id="T_457cc_row10_col4" class="data row10 col4" >3.50</td>
#       <td id="T_457cc_row10_col5" class="data row10 col5" >37.00</td>
#     </tr>
#     <tr>
#       <th id="T_457cc_level0_row11" class="row_heading level0 row11" >Hermance</th>
#       <td id="T_457cc_row11_col0" class="data row11 c

# %% [markdown]
# ### Distributions

# %%
fig, ax = plt.subplots(1)

sns.boxplot(data=position_totals, x="position", y="compte", hue="objet", ax=ax)
# sns.boxplot(data=position_totals, x="objet", y="compte", hue="objet",ax=ax[1])

ax.set_ylim(-10, 1000)
ax.set_xlabel("")

plt.show()
