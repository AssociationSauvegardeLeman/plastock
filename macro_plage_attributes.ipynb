# %%
# %load_ext watermark
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from myst_nb import glue
from IPython.display import Markdown as md
from slugify import slugify

from plastockconf import name_zones, name_particles, name_frequentation, name_situation
from plastockconf import particle_groups, name_substrate, name_distance, table_css_styles

from plastock import attribute_summary, attribute_summary_test, attribute_summary_grid, add_table_to_page


glue('blank_caption', " ", display=False)
a_property =  {'color' : 'red'}
page = 4
table_no = 1

# new_data = pd.read_csv("data/end_pipe/macro_current.csv")
beach_data = pd.read_csv("data/end_pipe/asl_beaches.csv").set_index('Plage')
work_data = pd.read_csv('data/end_pipe/macro_data_msquared.csv')
work_data = work_data[['Plage', 'échantillon', 'area', 'date','code','quantité','substrat', 'pcs/m²', 'region']].merge(beach_data[["frequentation", "situation", "distance", "orientation"]], left_on = "Plage", right_index=True)
work_data["fréquentation"] = work_data['frequentation']
work_data.drop('frequentation', inplace=True, axis=1)# ne

# %% [markdown]
# (macro-attributes)=
# # Macroplastiques plage et attribut
#
# ```{note}
#
# 1. Pour les déchets la variable "position" n'est pas prise en compte. Cela signifie que les déchets par mètre carré sont considérés comme la somme de la surface de la position 1 et de la surface de la position 2 pour chaque échantillon.
#
# 2. Les plages qui avaient plus d'un substrat, c'est-à-dire un substrat pour la position 1 et un autre pour la position 2, ont été converties en 1 substrat pour la plage utilisant le substrat de la position 2. La position 2 est la plus grande surface des deux positions.
#
# Pour plus de détails sur la manière dont cela se fait et pourquoi, voir ([data_processing](data_processing))
#
# ```

# %% [markdown]
# ## Substrat

# %%
column_display = {
    "count":"échantillons",
    "mean": "moyenne",
    "std": "écart type",
    "échantillon":"échantillon"
    
}

# ananlysis of substrat
voi = "substrat"
vals = "pcs/m²"
groupbys = ['échantillon', voi]
labels = name_substrate

event_total = work_data.groupby(["échantillon", voi], as_index=False)[vals].sum()

substrat_summary = attribute_summary(event_total, vals, voi, columns=column_display, labels=name_substrate)


event_total['échantillon'] = event_total["échantillon"].astype(str)

caption = 'Le résumé des résultats du nombre de déchets trouvées par m² dans chaque échantillon pour chaque substrat.'
section = 'A'
rule = 'Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.'

table_one = add_table_to_page(substrat_summary, table_no, caption, section, page, rule)
glue('tablea41', table_one, display=True)
# Out:
# <style type="text/css">
# #T_eb750 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_eb750 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_eb750 tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_eb750 th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_eb750 td {
#   padding: 4px;
#   text-align: center;
# }
# #T_eb750 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# </style>
# <table id="T_eb750">
#   <caption><b>Table A4-1 :</b> Le résumé des résultats du nombre de déchets trouvées par m² dans chaque échantillon pour chaque substrat. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb750_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_eb750_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_eb750_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_eb750_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_eb750_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_eb750_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_eb750_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_eb750_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb750_level0_row0" class="row_heading level0 row0" >Cailloux</th>
#       <td id="T_eb750_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_eb750_row0_col1" class="data row0 col1" >0,65</td>
#       <td id="T_eb750_row0_col2" class="data row0 col2" >0,62</td>
#       <td id="T_eb750_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_eb750_row0_col4" class="data row0 col4" >0,13</td>
#       <td id="T_eb750_row0_col5" class="data row0 col5" >0,43</td>
#       <td id="T_eb750_row0_col6" class="data row0 col6" >1,13</td>
#       <td id="T_eb750_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_eb750_level0_row1" class="row_heading level0 row1" >Graviers</th>
#       <td id="T_eb750_row1_col0" class="data row1 col0" >16</td>
#       <td id="T_eb750_row1_col1" class="data row1 col1" >0,31</td>
#       <td id="T_eb750_row1_col2" class="data row1 col2" >0,36</td>
#       <td id="T_eb750_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_eb750_row1_col4" class="data row1 col4" >0,10</td>
#       <td id="T_eb750_row1_col5" class="data row1 col5" >0,20</td>
#       <td id="T_eb750_row1_col6" class="data row1 col6" >0,29</td>
#       <td id="T_eb750_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_eb750_level0_row2" class="row_heading level0 row2" >Sables fins</th>
#       <td id="T_eb750_row2_col0" class="data row2 col0" >27</td>
#       <td id="T_eb750_row2_col1" class="data row2 col1" >1,02</td>
#       <td id="T_eb750_row2_col2" class="data row2 col2" >0,86</td>
#       <td id="T_eb750_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_eb750_row2_col4" class="data row2 col4" >0,44</td>
#       <td id="T_eb750_row2_col5" class="data row2 col5" >0,70</td>
#       <td id="T_eb750_row2_col6" class="data row2 col6" >1,32</td>
#       <td id="T_eb750_row2_col7" class="data row2 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_eb750_level0_row3" class="row_heading level0 row3" >Sables grossiers</th>
#       <td id="T_eb750_row3_col0" class="data row3 col0" >31</td>
#       <td id="T_eb750_row3_col1" class="data row3 col1" >0,52</td>
#       <td id="T_eb750_row3_col2" class="data row3 col2" >0,46</td>
#       <td id="T_eb750_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_eb750_row3_col4" class="data row3 col4" >0,23</td>
#       <td id="T_eb750_row3_col5" class="data row3 col5" >0,41</td>
#       <td id="T_eb750_row3_col6" class="data row3 col6" >0,59</td>
#       <td id="T_eb750_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
hue_order = list(name_substrate.values())
attribute_summary_grid(event_total, vals, voi, 'fig-a41', labels=labels, xlim=5, ylim=5,object_column='pcs/m²', hue_order=hue_order)

# %% [markdown]
# ```{glue:figure} fig-a41
# ---
# name: fig-a41
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# ### Les plages substrat = sables fins

# %%
md(', '.join(work_data[work_data.substrat.isin([1])].Plage.unique()))
# Out:
# Baby Plage, Bouveret, Excenevex, Grangettes, Préverenges, Rolle, Vidy

# %% [markdown]
# ## Fréquentation

# %%
# ananlysis of fréquentation
voi = "fréquentation"
vals = "pcs/m²"
groupbys = ['échantillon', voi]
labels = name_frequentation

event_total = work_data.groupby(["échantillon", "date", voi], as_index=False)[vals].sum()
table_no += 1
caption = 'Le résumé des résultats du nombre de déchets trouvées par m² dans chaque échantillon pour chaque niveau de fréquentation.'
event_total['échantillon'] = event_total["échantillon"].astype(str)

substrat_summary = attribute_summary(event_total, vals, voi, columns=column_display, labels=labels)
table_two = add_table_to_page(substrat_summary, table_no, caption, section, page, rule)
glue('tablea42', table_two, display=True)
# Out:
# <style type="text/css">
# #T_adcac tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_adcac tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_adcac tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_adcac th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_adcac td {
#   padding: 4px;
#   text-align: center;
# }
# #T_adcac caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# </style>
# <table id="T_adcac">
#   <caption><b>Table A4-2 :</b> Le résumé des résultats du nombre de déchets trouvées par m² dans chaque échantillon pour chaque niveau de fréquentation. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adcac_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_adcac_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_adcac_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_adcac_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_adcac_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_adcac_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_adcac_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_adcac_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adcac_level0_row0" class="row_heading level0 row0" >Elevée</th>
#       <td id="T_adcac_row0_col0" class="data row0 col0" >55</td>
#       <td id="T_adcac_row0_col1" class="data row0 col1" >0,64</td>
#       <td id="T_adcac_row0_col2" class="data row0 col2" >0,51</td>
#       <td id="T_adcac_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_adcac_row0_col4" class="data row0 col4" >0,27</td>
#       <td id="T_adcac_row0_col5" class="data row0 col5" >0,52</td>
#       <td id="T_adcac_row0_col6" class="data row0 col6" >0,84</td>
#       <td id="T_adcac_row0_col7" class="data row0 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_adcac_level0_row1" class="row_heading level0 row1" >Faible</th>
#       <td id="T_adcac_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_adcac_row1_col1" class="data row1 col1" >0,27</td>
#       <td id="T_adcac_row1_col2" class="data row1 col2" >0,18</td>
#       <td id="T_adcac_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_adcac_row1_col4" class="data row1 col4" >0,13</td>
#       <td id="T_adcac_row1_col5" class="data row1 col5" >0,26</td>
#       <td id="T_adcac_row1_col6" class="data row1 col6" >0,34</td>
#       <td id="T_adcac_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_adcac_level0_row2" class="row_heading level0 row2" >Moyenne</th>
#       <td id="T_adcac_row2_col0" class="data row2 col0" >28</td>
#       <td id="T_adcac_row2_col1" class="data row2 col1" >0,89</td>
#       <td id="T_adcac_row2_col2" class="data row2 col2" >0,95</td>
#       <td id="T_adcac_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_adcac_row2_col4" class="data row2 col4" >0,13</td>
#       <td id="T_adcac_row2_col5" class="data row2 col5" >0,53</td>
#       <td id="T_adcac_row2_col6" class="data row2 col6" >1,39</td>
#       <td id="T_adcac_row2_col7" class="data row2 col7" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
attribute_summary_grid(event_total, vals, voi, 'fig-a42', labels=labels, xlim=5, ylim=5, object_column='pcs/m²')

# %% [markdown]
# ```{glue:figure} fig-a42
# ---
# name: fig-a42
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# (freq_plages)=
# ### Les plages fréquentation = moyenne

# %%
md(', '.join(work_data[work_data['fréquentation'].isin([2])].Plage.unique()))
# Out:
# Anthy, Aubonne, Gland, Grangettes, Lugrin, Pichette, Saint-Disdille

# %% [markdown]
# ### Les plages fréquentation = élevée

# %%
md(', '.join(work_data[work_data['fréquentation'].isin([3])].Plage.unique()))
# Out:
# Amphion, Baby Plage, Bouveret, Clarens, Excenevex, Hermance, Lutry, Port Choiseul, Préverenges, Rolle, Savonnière, Tougues, Versoix, Vidy

# %% [markdown]
# ## Situation

# %%
# ananlysis of situation
voi = "situation"
vals = "pcs/m²"
groupby = ['échantillon', voi]
labels = name_situation

event_total = work_data.groupby(["échantillon", "Plage","date", voi], as_index=False)[vals].sum()
table_no += 1

caption = 'Le résumé des résultats du nombre de déchets trouvées par m²dans chaque échantillon pour chaque situation: urbain, campagne.'
event_total['échantillon'] = event_total["échantillon"].astype(str)

sit = attribute_summary(event_total, vals, voi, columns=column_display, labels=labels)
table_three = add_table_to_page(sit, table_no, caption, section, page, rule)
glue('tablea43', table_three, display=True)
# Out:
# <style type="text/css">
# #T_e971f tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_e971f tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_e971f tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_e971f th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_e971f td {
#   padding: 4px;
#   text-align: center;
# }
# #T_e971f caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# </style>
# <table id="T_e971f">
#   <caption><b>Table A4-3 :</b> Le résumé des résultats du nombre de déchets trouvées par m²dans chaque échantillon pour chaque situation: urbain, campagne. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e971f_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_e971f_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_e971f_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_e971f_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_e971f_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_e971f_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_e971f_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_e971f_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e971f_level0_row0" class="row_heading level0 row0" >Campagne</th>
#       <td id="T_e971f_row0_col0" class="data row0 col0" >67</td>
#       <td id="T_e971f_row0_col1" class="data row0 col1" >0,70</td>
#       <td id="T_e971f_row0_col2" class="data row0 col2" >0,75</td>
#       <td id="T_e971f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e971f_row0_col4" class="data row0 col4" >0,15</td>
#       <td id="T_e971f_row0_col5" class="data row0 col5" >0,32</td>
#       <td id="T_e971f_row0_col6" class="data row0 col6" >1,09</td>
#       <td id="T_e971f_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e971f_level0_row1" class="row_heading level0 row1" >Urbain</th>
#       <td id="T_e971f_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_e971f_row1_col1" class="data row1 col1" >0,56</td>
#       <td id="T_e971f_row1_col2" class="data row1 col2" >0,39</td>
#       <td id="T_e971f_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_e971f_row1_col4" class="data row1 col4" >0,36</td>
#       <td id="T_e971f_row1_col5" class="data row1 col5" >0,51</td>
#       <td id="T_e971f_row1_col6" class="data row1 col6" >0,66</td>
#       <td id="T_e971f_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
attribute_summary_grid(event_total, vals, voi, 'fig-a43', labels=labels, xlim=5, ylim=5, object_column='pcs/m²')

# %% [markdown]
# ```{glue:figure} fig-a43
# ---
# name: fig-a43
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# (sit_plages)=
# ### Les plages situation = campagne

# %%
md(', '.join(work_data[work_data.situation.isin([1])].Plage.unique()))
# Out:
# Amphion, Anthy, Aubonne, Bouveret, Crans, Cully, Excenevex, Gland, Grangettes, Lugrin, Pichette, Préverenges, Saint-Disdille, Savonnière, Tolochenaz, Tougues, Versoix

# %% [markdown]
# ### Les plages situation = urbain

# %%
md(', '.join(work_data[work_data.situation.isin([2])].Plage.unique()))
# Out:
# Baby Plage, Clarens, Hermance, Lutry, Meillerie, Port Choiseul, Rolle, Vidy

# %% [markdown]
# ## Distance

# %%
# ananlysis of distance
voi = "distance"
vals = "pcs/m²"
groupby = ['échantillon', voi]
labels = name_distance

event_total = work_data.groupby(["échantillon", "Plage","date", voi], as_index=False)[vals].sum()

table_no += 1

caption = 'Le résumé des résultats du nombre de déchets trouvées par m²dans chaque échantillon selon la distance du parking.'
event_total['échantillon'] = event_total["échantillon"].astype(str)
dist = attribute_summary(event_total, vals, voi, columns=column_display, labels=labels)
table_three = add_table_to_page(dist, table_no, caption, section, page, rule)
glue('tablea44', table_three, display=True)
# Out:
# <style type="text/css">
# #T_59a36 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_59a36 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_59a36 tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_59a36 th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_59a36 td {
#   padding: 4px;
#   text-align: center;
# }
# #T_59a36 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# </style>
# <table id="T_59a36">
#   <caption><b>Table A4-4 :</b> Le résumé des résultats du nombre de déchets trouvées par m²dans chaque échantillon selon la distance du parking. Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59a36_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_59a36_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_59a36_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_59a36_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_59a36_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_59a36_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_59a36_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_59a36_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59a36_level0_row0" class="row_heading level0 row0" >100 - 500 m</th>
#       <td id="T_59a36_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_59a36_row0_col1" class="data row0 col1" >0,80</td>
#       <td id="T_59a36_row0_col2" class="data row0 col2" >0,76</td>
#       <td id="T_59a36_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_59a36_row0_col4" class="data row0 col4" >0,31</td>
#       <td id="T_59a36_row0_col5" class="data row0 col5" >0,56</td>
#       <td id="T_59a36_row0_col6" class="data row0 col6" >0,97</td>
#       <td id="T_59a36_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_59a36_level0_row1" class="row_heading level0 row1" >500 - 1000 m</th>
#       <td id="T_59a36_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_59a36_row1_col1" class="data row1 col1" >0,40</td>
#       <td id="T_59a36_row1_col2" class="data row1 col2" >0,16</td>
#       <td id="T_59a36_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_59a36_row1_col4" class="data row1 col4" >0,31</td>
#       <td id="T_59a36_row1_col5" class="data row1 col5" >0,38</td>
#       <td id="T_59a36_row1_col6" class="data row1 col6" >0,50</td>
#       <td id="T_59a36_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_59a36_level0_row2" class="row_heading level0 row2" >< 100 m</th>
#       <td id="T_59a36_row2_col0" class="data row2 col0" >39</td>
#       <td id="T_59a36_row2_col1" class="data row2 col1" >0,64</td>
#       <td id="T_59a36_row2_col2" class="data row2 col2" >0,60</td>
#       <td id="T_59a36_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_59a36_row2_col4" class="data row2 col4" >0,13</td>
#       <td id="T_59a36_row2_col5" class="data row2 col5" >0,40</td>
#       <td id="T_59a36_row2_col6" class="data row2 col6" >1,02</td>
#       <td id="T_59a36_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_59a36_level0_row3" class="row_heading level0 row3" >> 1000 m</th>
#       <td id="T_59a36_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_59a36_row3_col1" class="data row3 col1" >0,14</td>
#       <td id="T_59a36_row3_col2" class="data row3 col2" >0,07</td>
#       <td id="T_59a36_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_59a36_row3_col4" class="data row3 col4" >0,10</td>
#       <td id="T_59a36_row3_col5" class="data row3 col5" >0,14</td>
#       <td id="T_59a36_row3_col6" class="data row3 col6" >0,16</td>
#       <td id="T_59a36_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
attribute_summary_grid(event_total, vals, voi, 'fig-a44', labels=labels, xlim=5, ylim=5, object_column='pcs/m²')

# %% [markdown]
# ```{glue:figure} fig-a44
# ---
# name: fig-a44
# ---
# {glue:text}`blank_caption`
# ```

# %% [markdown]
# (dist_plage)=
# ### Les plages distance = 100 - 500 m

# %%
md(', '.join(work_data[work_data.distance.isin([2])].Plage.unique()))
# Out:
# Baby Plage, Bouveret, Grangettes, Hermance, Lugrin, Lutry, Port Choiseul, Préverenges, Tougues, Versoix, Vidy

# %% [markdown]
# ### Les plages distance = < 100 m

# %%
md(', '.join(work_data[work_data.distance.isin([1])].Plage.unique()))
# Out:
# Amphion, Anthy, Clarens, Cully, Excenevex, Gland, Pichette, Rolle, Saint-Disdille, Savonnière

# %% [markdown]
# ## Orientation

# %%
# ananlysis of substrat
voi = "orientation"
vals = "pcs/m²"
groupby = ['échantillon', voi]

data_summary = attribute_summary_test(work_data, voi=voi, vals=vals)
data_summary[['count', 'max', 'min']] = data_summary[['count', 'max', 'min']].astype('int')
data_summary.rename(columns=column_display, inplace=True)

select_values = data_summary["moyenne"] > 1.45
test_one = data_summary.loc[select_values].index

select_values = data_summary["50%"] > .78
test_two = data_summary.loc[select_values].index

d_sum = data_summary.style.set_table_styles(table_css_styles)
d_sum = d_sum.set_properties(subset = pd.IndexSlice[test_one,["moyenne"]], **a_property)
d_sum = d_sum.set_properties(subset = pd.IndexSlice[test_two,["50%"]], **a_property)

table_no += 1

caption = 'Le résumé des résultats du nombre de déchets trouvées par m² dans chaque échantillon selon l\'orientation de la plage'

table_five = add_table_to_page(d_sum, table_no, caption, section, page, rule, format_index='columns')
glue('tablea45', table_five, display=True)
# Out:
# <style type="text/css">
# #T_50e48 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_50e48 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_50e48 tr {
#   font-size: 14px;
#   padding: 6px;
# }
# #T_50e48 th:nth-child(1) {
#   background-color: #FFF;
#   white-space: nowrap;
#   word-break: keep-all;
# }
# #T_50e48 td {
#   padding: 4px;
#   text-align: center;
# }
# #T_50e48 caption {
#   caption-side: bottom;
#   font-size: 14px;
#   text-align: left;
#   margin-top: 14px;
# }
# #T_50e48_row0_col5, #T_50e48_row2_col5, #T_50e48_row3_col5 {
#   color: red;
# }
# </style>
# <table id="T_50e48">
#   <caption><b>Table A4-5 :</b> Le résumé des résultats du nombre de déchets trouvées par m² dans chaque échantillon selon l'orientation de la plage Les attributs dont la moyenne des résultats est supérieure à la moyenne du projet sont en rouge.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50e48_level0_col0" class="col_heading level0 col0" >Échantillons</th>
#       <th id="T_50e48_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#       <th id="T_50e48_level0_col2" class="col_heading level0 col2" >Écart type</th>
#       <th id="T_50e48_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_50e48_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_50e48_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_50e48_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_50e48_level0_col7" class="col_heading level0 col7" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50e48_level0_row0" class="row_heading level0 row0" >E</th>
#       <td id="T_50e48_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_50e48_row0_col1" class="data row0 col1" >1,14</td>
#       <td id="T_50e48_row0_col2" class="data row0 col2" >0,68</td>
#       <td id="T_50e48_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_50e48_row0_col4" class="data row0 col4" >0,70</td>
#       <td id="T_50e48_row0_col5" class="data row0 col5" >1,12</td>
#       <td id="T_50e48_row0_col6" class="data row0 col6" >1,57</td>
#       <td id="T_50e48_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row1" class="row_heading level0 row1" >ESE</th>
#       <td id="T_50e48_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_50e48_row1_col1" class="data row1 col1" >0,26</td>
#       <td id="T_50e48_row1_col2" class="data row1 col2" >0,03</td>
#       <td id="T_50e48_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_50e48_row1_col4" class="data row1 col4" >0,25</td>
#       <td id="T_50e48_row1_col5" class="data row1 col5" >0,26</td>
#       <td id="T_50e48_row1_col6" class="data row1 col6" >0,27</td>
#       <td id="T_50e48_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row2" class="row_heading level0 row2" >N</th>
#       <td id="T_50e48_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_50e48_row2_col1" class="data row2 col1" >0,90</td>
#       <td id="T_50e48_row2_col2" class="data row2 col2" >0,56</td>
#       <td id="T_50e48_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_50e48_row2_col4" class="data row2 col4" >0,42</td>
#       <td id="T_50e48_row2_col5" class="data row2 col5" >0,89</td>
#       <td id="T_50e48_row2_col6" class="data row2 col6" >1,31</td>
#       <td id="T_50e48_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row3" class="row_heading level0 row3" >NE</th>
#       <td id="T_50e48_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_50e48_row3_col1" class="data row3 col1" >0,88</td>
#       <td id="T_50e48_row3_col2" class="data row3 col2" >0,56</td>
#       <td id="T_50e48_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_50e48_row3_col4" class="data row3 col4" >0,54</td>
#       <td id="T_50e48_row3_col5" class="data row3 col5" >0,87</td>
#       <td id="T_50e48_row3_col6" class="data row3 col6" >1,19</td>
#       <td id="T_50e48_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row4" class="row_heading level0 row4" >NNE</th>
#       <td id="T_50e48_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_50e48_row4_col1" class="data row4 col1" >0,64</td>
#       <td id="T_50e48_row4_col2" class="data row4 col2" >0,25</td>
#       <td id="T_50e48_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_50e48_row4_col4" class="data row4 col4" >0,48</td>
#       <td id="T_50e48_row4_col5" class="data row4 col5" >0,58</td>
#       <td id="T_50e48_row4_col6" class="data row4 col6" >0,71</td>
#       <td id="T_50e48_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row5" class="row_heading level0 row5" >NNO</th>
#       <td id="T_50e48_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_50e48_row5_col1" class="data row5 col1" >0,13</td>
#       <td id="T_50e48_row5_col2" class="data row5 col2" >0,06</td>
#       <td id="T_50e48_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_50e48_row5_col4" class="data row5 col4" >0,11</td>
#       <td id="T_50e48_row5_col5" class="data row5 col5" >0,13</td>
#       <td id="T_50e48_row5_col6" class="data row5 col6" >0,15</td>
#       <td id="T_50e48_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row6" class="row_heading level0 row6" >NO</th>
#       <td id="T_50e48_row6_col0" class="data row6 col0" >12</td>
#       <td id="T_50e48_row6_col1" class="data row6 col1" >1,10</td>
#       <td id="T_50e48_row6_col2" class="data row6 col2" >1,20</td>
#       <td id="T_50e48_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_50e48_row6_col4" class="data row6 col4" >0,23</td>
#       <td id="T_50e48_row6_col5" class="data row6 col5" >0,48</td>
#       <td id="T_50e48_row6_col6" class="data row6 col6" >2,14</td>
#       <td id="T_50e48_row6_col7" class="data row6 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row7" class="row_heading level0 row7" >ONO</th>
#       <td id="T_50e48_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_50e48_row7_col1" class="data row7 col1" >0,83</td>
#       <td id="T_50e48_row7_col2" class="data row7 col2" >0,86</td>
#       <td id="T_50e48_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_50e48_row7_col4" class="data row7 col4" >0,14</td>
#       <td id="T_50e48_row7_col5" class="data row7 col5" >0,45</td>
#       <td id="T_50e48_row7_col6" class="data row7 col6" >1,57</td>
#       <td id="T_50e48_row7_col7" class="data row7 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row8" class="row_heading level0 row8" >OSO</th>
#       <td id="T_50e48_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_50e48_row8_col1" class="data row8 col1" >0,14</td>
#       <td id="T_50e48_row8_col2" class="data row8 col2" >0,13</td>
#       <td id="T_50e48_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_50e48_row8_col4" class="data row8 col4" >0,06</td>
#       <td id="T_50e48_row8_col5" class="data row8 col5" >0,08</td>
#       <td id="T_50e48_row8_col6" class="data row8 col6" >0,16</td>
#       <td id="T_50e48_row8_col7" class="data row8 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row9" class="row_heading level0 row9" >SE</th>
#       <td id="T_50e48_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_50e48_row9_col1" class="data row9 col1" >0,15</td>
#       <td id="T_50e48_row9_col2" class="data row9 col2" >0,08</td>
#       <td id="T_50e48_row9_col3" class="data row9 col3" >0</td>
#       <td id="T_50e48_row9_col4" class="data row9 col4" >0,10</td>
#       <td id="T_50e48_row9_col5" class="data row9 col5" >0,13</td>
#       <td id="T_50e48_row9_col6" class="data row9 col6" >0,18</td>
#       <td id="T_50e48_row9_col7" class="data row9 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_50e48_level0_row10" class="row_heading level0 row10" >SO</th>
#       <td id="T_50e48_row10_col0" class="data row10 col0" >12</td>
#       <td id="T_50e48_row10_col1" class="data row10 col1" >0,51</t

# %%
# %watermark --iversions -b -r
# Out:
# Git repo: https://github.com/hammerdirt-analyst/plastock.git
#
# Git branch: feb5
#
# matplotlib: 3.8.2
# seaborn   : 0.13.1
# pandas    : 2.0.3
# numpy     : 1.26.3
